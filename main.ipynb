# %%
# !pip install bpemb timm
# Out:
# Collecting bpemb
#   Downloading bpemb-0.3.6-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.15)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (from bpemb) (4.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from bpemb) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from bpemb) (2.32.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from bpemb) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from bpemb) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.20.1+cu124)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm) (0.28.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm) (0.5.3)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim->bpemb) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim->bpemb) (7.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->bpemb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->bpemb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->bpemb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->bpemb) (2025.1.31)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->timm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->timm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->timm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->timm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->timm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->timm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm) (11.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim->bpemb) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Downloading bpemb-0.3.6-py3-none-any.whl (20 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bpemb
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bpemb-0.3.6 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !unzip /content/drive/MyDrive/Pneumothorax.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Pneumothorax/masks/5912_train_0_.png
#   inflating: /content/Pneumothorax/masks/5913_train_0_.png
#   inflating: /content/Pneumothorax/masks/5914_train_0_.png
#   inflating: /content/Pneumothorax/masks/5915_train_0_.png
#   inflating: /content/Pneumothorax/masks/5916_train_0_.png
#   inflating: /content/Pneumothorax/masks/5917_train_0_.png
#   inflating: /content/Pneumothorax/masks/5918_train_0_.png
#   inflating: /content/Pneumothorax/masks/5919_train_0_.png
#   inflating: /content/Pneumothorax/masks/591_test_0_.png
#   inflating: /content/Pneumothorax/masks/591_train_1_.png
#   inflating: /content/Pneumothorax/masks/5920_train_0_.png
#   inflating: /content/Pneumothorax/masks/5921_train_1_.png
#   inflating: /content/Pneumothorax/masks/5922_train_0_.png
#   inflating: /content/Pneumothorax/masks/5923_train_0_.png
#   inflating: /content/Pneumothorax/masks/5924_train_0_.png
#   inflating: /content/Pneumothorax/masks/5925_train_0_.png
#   inflating: /content/Pneumothorax/masks/5926_train_0_.png
#   inflating: /content/Pneumothorax/masks/5927_train_0_.png
#   inflating: /content/Pneumothorax/masks/5928_train_0_.png
#   inflating: /content/Pneumothorax/masks/5929_train_0_.png
#   inflating: /content/Pneumothorax/masks/592_test_0_.png
#   inflating: /content/Pneumothorax/masks/592_train_0_.png
#   inflating: /content/Pneumothorax/masks/5930_train_0_.png
#   inflating: /content/Pneumothorax/masks/5931_train_0_.png
#   inflating: /content/Pneumothorax/masks/5932_train_0_.png
#   inflating: /content/Pneumothorax/masks/5933_train_0_.png
#   inflating: /content/Pneumothorax/masks/5934_train_0_.png
#   inflating: /content/Pneumothorax/masks/5935_train_0_.png
#   inflating: /content/Pneumothorax/masks/5936_train_0_.png
#   inflating: /content/Pneumothorax/masks/5937_train_0_.png
#   inflating: /content/Pneumothorax/masks/5938_train_0_.png
#   inflating: /content/Pneumothorax/masks/5939_train_0_.png
#   inflating: /content/Pneumothorax/masks/593_test_0_.png
#   inflating: /content/Pneumothorax/masks/593_train_1_.png
#   inflating: /content/Pneumothorax/masks/5940_train_0_.png
#   inflating: /content/Pneumothorax/masks/5941_train_0_.png
#   inflating: /content/Pneumothorax/masks/5942_train_1_.png
#   inflating: /content/Pneumothorax/masks/5943_train_0_.png
#   inflating: /content/Pneumothorax/masks/5944_train_0_.png
#   inflating: /content/Pneumothorax/masks/5945_train_0_.png
#   inflating: /content/Pneumothorax/masks/5946_train_0_.png
#   inflating: /content/Pneumothorax/masks/5947_train_0_.png
#   inflating: /content/Pneumothorax/masks/5948_train_0_.png
#   inflating: /content/Pneumothorax/masks/5949_train_0_.png
#   inflating: /content/Pneumothorax/masks/594_test_0_.png
#   inflating: /content/Pneumothorax/masks/594_train_0_.png
#   inflating: /content/Pneumothorax/masks/5950_train_0_.png
#   inflating: /content/Pneumothorax/masks/5951_train_0_.png
#   inflating: /content/Pneumothorax/masks/5952_train_0_.png
#   inflating: /content/Pneumothorax/masks/5953_train_0_.png
#   inflating: /content/Pneumothorax/masks/5954_train_0_.png
#   inflating: /content/Pneumothorax/masks/5955_train_0_.png
#   inflating: /content/Pneumothorax/masks/5956_train_0_.png
#   inflating: /content/Pneumothorax/masks/5957_train_0_.png
#   inflating: /content/Pneumothorax/masks/5958_train_0_.png
#   inflating: /content/Pneumothorax/masks/5959_train_0_.png
#   inflating: /content/Pneumothorax/masks/595_test_1_.png
#   inflating: /content/Pneumothorax/masks/595_train_1_.png
#   inflating: /content/Pneumothorax/masks/5960_train_0_.png
#   inflating: /content/Pneumothorax/masks/5961_train_0_.png
#   inflating: /content/Pneumothorax/masks/5962_train_0_.png
#   inflating: /content/Pneumothorax/masks/5963_train_0_.png
#   inflating: /content/Pneumothorax/masks/5964_train_0_.png
#   inflating: /content/Pneumothorax/masks/5965_train_0_.png
#   inflating: /content/Pneumothorax/masks/5966_train_0_.png
#   inflating: /content/Pneumothorax/masks/5967_train_0_.png
#   inflating: /content/Pneumothorax/masks/5968_train_0_.png
#   inflating: /content/Pneumothorax/masks/5969_train_0_.png
#   inflating: /content/Pneumothorax/masks/596_test_0_.png
#   inflating: /content/Pneumothorax/masks/596_train_0_.png
#   inflating: /content/Pneumothorax/masks/5970_train_0_.png
#   inflating: /content/Pneumothorax/masks/5971_train_0_.png
#   inflating: /content/Pneumothorax/masks/5972_train_0_.png
#   inflating: /content/Pneumothorax/masks/5973_train_0_.png
#   inflating: /content/Pneumothorax/masks/5974_train_0_.png
#   inflating: /content/Pneumothorax/masks/5975_train_0_.png
#   inflating: /content/Pneumothorax/masks/5976_train_0_.png
#   inflating: /content/Pneumothorax/masks/5977_train_0_.png
#   inflating: /content/Pneumothorax/masks/5978_train_0_.png
#   inflating: /content/Pneumothorax/masks/5979_train_1_.png
#   inflating: /content/Pneumothorax/masks/597_test_0_.png
#   inflating: /content/Pneumothorax/masks/597_train_0_.png
#   inflating: /content/Pneumothorax/masks/5980_train_0_.png
#   inflating: /content/Pneumothorax/masks/5981_train_0_.png
#   inflating: /content/Pneumothorax/masks/5982_train_0_.png
#   inflating: /content/Pneumothorax/masks/5983_train_0_.png
#   inflating: /content/Pneumothorax/masks/5984_train_0_.png
#   inflating: /content/Pneumothorax/masks/5985_train_0_.png
#   inflating: /content/Pneumothorax/masks/5986_train_0_.png
#   inflating: /content/Pneumothorax/masks/5987_train_0_.png
#   inflating: /content/Pneumothorax/masks/5988_train_0_.png
#   inflating: /content/Pneumothorax/masks/5989_train_0_.png
#   inflating: /content/Pneumothorax/masks/598_test_1_.png
#   inflating: /content/Pneumothorax/masks/598_train_1_.png
#   inflating: /content/Pneumothorax/masks/5990_train_0_.png
#   inflating: /content/Pneumothorax/masks/5991_train_0_.png
#   inflating: /content/Pneumothorax/masks/5992_train_0_.png
#   inflating: /content/Pneumothorax/masks/5993_train_0_.png
#   inflating: /content/Pneumothorax/masks/5994_train_0_.png
#   inflating: /content/Pneumothorax/masks/5995_train_0_.png
#   inflating: /content/Pneumothorax/masks/5996_train_0_.png
#   inflating: /content/Pneumothorax/masks/5997_train_0_.png
#   inflating: /content/Pneumothorax/masks/5998_train_0_.png
#   inflating: /content/Pneumothorax/masks/5999_train_0_.png
#   inflating: /content/Pneumothorax/masks/599_test_0_.png
#   inflating: /content/Pneumothorax/masks/599_train_1_.png
#   inflating: /content/Pneumothorax/masks/59_test_0_.png
#   inflating: /content/Pneumothorax/masks/59_train_1_.png
#   inflating: /content/Pneumothorax/masks/5_test_0_.png
#   inflating: /content/Pneumothorax/masks/5_train_0_.png
#   inflating: /content/Pneumothorax/masks/6000_train_0_.png
#   inflating: /content/Pneumothorax/masks/6001_train_0_.png
#   inflating: /content/Pneumothorax/masks/6002_train_0_.png
#   inflating: /content/Pneumothorax/masks/6003_train_0_.png
#   inflating: /content/Pneumothorax/masks/6004_train_0_.png
#   inflating: /content/Pneumothorax/masks/6005_train_0_.png
#   inflating: /content/Pneumothorax/masks/6006_train_0_.png
#   inflating: /content/Pneumothorax/masks/6007_train_0_.png
#   inflating: /content/Pneumothorax/masks/6008_train_0_.png
#   inflating: /content/Pneumothorax/masks/6009_train_0_.png
#   inflating: /content/Pneumothorax/masks/600_test_0_.png
#   inflating: /content/Pneumothorax/masks/600_train_0_.png
#   inflating: /content/Pneumothorax/masks/6010_train_0_.png
#   inflating: /content/Pneumothorax/masks/6011_train_0_.png
#   inflating: /content/Pneumothorax/masks/6012_train_0_.png
#   inflating: /content/Pneumothorax/masks/6013_train_0_.png
#   inflating: /content/Pneumothorax/masks/6014_train_0_.png
#   inflating: /content/Pneumothorax/masks/6015_train_0_.png
#   inflating: /content/Pneumothorax/masks/6016_train_0_.png
#   inflating: /content/Pneumothorax/masks/6017_train_0_.png
#   inflating: /content/Pneumothorax/masks/6018_train_0_.png
#   inflating: /content/Pneumothorax/masks/6019_train_0_.png
#   inflating: /content/Pneumothorax/masks/601_test_0_.png
#   inflating: /content/Pneumothorax/masks/601_train_0_.png
#   inflating: /content/Pneumothorax/masks/6020_train_0_.png
#   inflating: /content/Pneumothorax/masks/6021_train_0_.png
#   inflating: /content/Pneumothorax/masks/6022_train_0_.png
#   inflating: /content/Pneumothorax/masks/6023_train_0_.png
#   inflating: /content/Pneumothorax/masks/6024_train_0_.png
#   inflating: /content/Pneumothorax/masks/6025_train_0_.png
#   inflating: /content/Pneumothorax/masks/6026_train_0_.png
#   inflating: /content/Pneumothorax/masks/6027_train_0_.png
#   inflating: /content/Pneumothorax/masks/6028_train_0_.png
#   inflating: /content/Pneumothorax/masks/6029_train_1_.png
#   inflating: /content/Pneumothorax/masks/602_test_0_.png
#   inflating: /content/Pneumothorax/masks/602_train_0_.png
#   inflating: /content/Pneumothorax/masks/6030_train_0_.png
#   inflating: /content/Pneumothorax/masks/6031_train_0_.png
#   inflating: /content/Pneumothorax/masks/6032_train_0_.png
#   inflating: /content/Pneumothorax/masks/6033_train_0_.png
#   inflating: /content/Pneumothorax/masks/6034_train_0_.png
#   inflating: /content/Pneumothorax/masks/6035_train_0_.png
#   inflating: /content/Pneumothorax/masks/6036_train_0_.png
#   inflating: /content/Pneumothorax/masks/6037_train_0_.png
#   inflating: /content/Pneumothorax/masks/6038_train_0_.png
#   inflating: /content/Pneumothorax/masks/6039_train_0_.png
#   inflating: /content/Pneumothorax/masks/603_test_0_.png
#   inflating: /content/Pneumothorax/masks/603_train_1_.png
#   inflating: /content/Pneumothorax/masks/6040_train_0_.png
#   inflating: /content/Pneumothorax/masks/6041_train_0_.png
#   inflating: /content/Pneumothorax/masks/6042_train_0_.png
#   inflating: /content/Pneumothorax/masks/6043_train_0_.png
#   inflating: /content/Pneumothorax/masks/6044_train_0_.png
#   inflating: /content/Pneumothorax/masks/6045_train_0_.png
#   inflating: /content/Pneumothorax/masks/6046_train_0_.png
#   inflating: /content/Pneumothorax/masks/6047_train_0_.png
#   inflating: /content/Pneumothorax/masks/6048_train_0_.png
#   inflating: /content/Pneumothorax/masks/6049_train_0_.png
#   inflating: /content/Pneumothorax/masks/604_test_0_.png
#   inflating: /content/Pneumothorax/masks/604_train_1_.png
#   inflating: /content/Pneumothorax/masks/6050_train_0_.png
#   inflating: /content/Pneumothorax/masks/6051_train_0_.png
#   inflating: /content/Pneumothorax/masks/6052_train_0_.png
#   inflating: /content/Pneumothorax/masks/6053_train_0_.png
#   inflating: /content/Pneumothorax/masks/6054_train_1_.png
#   inflating: /content/Pneumothorax/masks/6055_train_0_.png
#   inflating: /content/Pneumothorax/masks/6056_train_0_.png
#   inflating: /content/Pneumothorax/masks/6057_train_0_.png
#   inflating: /content/Pneumothorax/masks/6058_train_0_.png
#   inflating: /content/Pneumothorax/masks/6059_train_0_.png
#   inflating: /content/Pneumothorax/masks/605_test_1_.png
#   inflating: /content/Pneumothorax/masks/605_train_1_.png
#   inflating: /content/Pneumothorax/masks/6060_train_0_.png
#   inflating: /content/Pneumothorax/masks/6061_train_0_.png
#   inflating: /content/Pneumothorax/masks/6062_train_0_.png
#   inflating: /content/Pneumothorax/masks/6063_train_1_.png
#   inflating: /content/Pneumothorax/masks/6064_train_0_.png
#   inflating: /content/Pneumothorax/masks/6065_train_0_.png
#   inflating: /content/Pneumothorax/masks/6066_train_0_.png
#   inflating: /content/Pneumothorax/masks/6067_train_0_.png
#   inflating: /content/Pneumothorax/masks/6068_train_0_.png
#   inflating: /content/Pneumothorax/masks/6069_train_0_.png
#   inflating: /content/Pneumothorax/masks/606_test_0_.png
#   inflating: /content/Pneumothorax/masks/606_train_1_.png
#   inflating: /content/Pneumothorax/masks/6070_train_0_.png
#   inflating: /content/Pneumothorax/masks/6071_train_0_.png
#   inflating: /content/Pneumothorax/masks/6072_train_0_.png
#   inflating: /content/Pneumothorax/masks/6073_train_0_.png
#   inflating: /content/Pneumothorax/masks/6074_train_0_.png
#   inflating: /content/Pneumothorax/masks/6075_train_0_.png
#   inflating: /content/Pneumothorax/masks/6076_train_0_.png
#   inflating: /content/Pneumothorax/masks/6077_train_0_.png
#   inflating: /content/Pneumothorax/masks/6078_train_0_.png
#   inflating: /content/Pneumothorax/masks/6079_train_0_.png
#   inflating: /content/Pneumothorax/masks/607_test_0_.png
#   inflating: /content/Pneumothorax/masks/607_train_1_.png
#   inflating: /content/Pneumothorax/masks/6080_train_0_.png
#   inflating: /content/Pneumothorax/masks/6081_train_0_.png
#   inflating: /content/Pneumothorax/masks/6082_train_0_.png
#   inflating: /content/Pneumothorax/masks/6083_train_0_.png
#   inflating: /content/Pneumothorax/masks/6084_train_0_.png
#   inflating: /content/Pneumothorax/masks/6085_train_0_.png
#   inflating: /content/Pneumothorax/masks/6086_train_0_.png
#   inflating: /content/Pneumothorax/masks/6087_train_0_.png
#   inflating: /content/Pneumothorax/masks/6088_train_0_.png
#   inflating: /content/Pneumothorax/masks/6089_train_0_.png
#   inflating: /content/Pneumothorax/masks/608_test_0_.png
#   inflating: /content/Pneumothorax/masks/608_train_1_.png
#   inflating: /content/Pneumothorax/masks/6090_train_0_.png
#   inflating: /content/Pneumothorax/masks/6091_train_0_.png
#   inflating: /content/Pneumothorax/masks/6092_train_0_.png
#   inflating: /content/Pneumothorax/masks/6093_train_0_.png
#   inflating: /content/Pneumothorax/masks/6094_train_0_.png
#   inflating: /content/Pneumothorax/masks/6095_train_0_.png
#   inflating: /content/Pneumothorax/masks/6096_train_0_.png
#   inflating: /content/Pneumothorax/masks/6097_train_1_.png
#   inflating: /content/Pneumothorax/masks/6098_train_0_.png
#   inflating: /content/Pneumothorax/masks/6099_train_0_.png
#   inflating: /content/Pneumothorax/masks/609_test_0_.png
#   inflating: /content/Pneumothorax/masks/609_train_0_.png
#   inflating: /content/Pneumothorax/masks/60_test_0_.png
#   inflating: /content/Pneumothorax/masks/60_train_1_.png
#   inflating: /content/Pneumothorax/masks/6100_train_0_.png
#   inflating: /content/Pneumothorax/masks/6101_train_0_.png
#   inflating: /content/Pneumothorax/masks/6102_train_0_.png
#   inflating: /content/Pneumothorax/masks/6103_train_0_.png
#   inflating: /content/Pneumothorax/masks/6104_train_0_.png
#   inflating: /content/Pneumothorax/masks/6105_train_0_.png
#   inflating: /content/Pneumothorax/masks/6106_train_0_.png
#   inflating: /content/Pneumothorax/masks/6107_train_0_.png
#   inflating: /content/Pneumothorax/masks/6108_train_0_.png
#   inflating: /content/Pneumothorax/masks/6109_train_0_.png
#   inflating: /content/Pneumothorax/masks/610_test_0_.png
#   inflating: /content/Pneumothorax/masks/610_train_0_.png
#   inflating: /content/Pneumothorax/masks/6110_train_0_.png
#   inflating: /content/Pneumothorax/masks/6111_train_0_.png
#   inflating: /content/Pneumothorax/masks/6112_train_0_.png
#   inflating: /content/Pneumothorax/masks/6113_train_0_.png
#   inflating: /content/Pneumothorax/masks/6114_train_0_.png
#   inflating: /content/Pneumothorax/masks/6115_train_0_.png
#   inflating: /content/Pneumothorax/masks/6116_train_0_.png
#   inflating: /content/Pneumothorax/masks/6117_train_0_.png
#   inflating: /content/Pneumothorax/masks/6118_train_0_.png
#   inflating: /content/Pneumothorax/masks/6119_train_0_.png
#   inflating: /content/Pneumothorax/masks/611_test_0_.png
#   inflating: /content/Pneumothorax/masks/611_train_0_.png
#   inflating: /content/Pneumothorax/masks/6120_train_0_.png
#   inflating: /content/Pneumothorax/masks/6121_train_0_.png
#   inflating: /content/Pneumothorax/masks/6122_train_0_.png
#   inflating: /content/Pneumothorax/masks/6123_train_0_.png
#   inflating: /content/Pneumothorax/masks/6124_train_0_.png
#   inflating: /content/Pneumothorax/masks/6125_train_0_.png
#   inflating: /content/Pneumothorax/masks/6126_train_0_.png
#   inflating: /content/Pneumothorax/masks/6127_train_0_.png
#   inflating: /content/Pneumothorax/masks/6128_train_0_.png
#   inflating: /content/Pneumothorax/masks/6129_train_0_.png
#   inflating: /content/Pneumothorax/masks/612_test_0_.png
#   inflating: /content/Pneumothorax/masks/612_train_1_.png
#   inflating: /content/Pneumothorax/masks/6130_train_0_.png
#   inflating: /content/Pneumothorax/masks/6131_train_0_.png
#   inflating: /content/Pneumothorax/masks/6132_train_0_.png
#   inflating: /content/Pneumothorax/masks/6133_train_0_.png
#   inflating: /content/Pneumothorax/masks/6134_train_0_.png
#   inflating: /content/Pneumothorax/masks/6135_train_0_.png
#   inflating: /content/Pneumothorax/masks/6136_train_1_.png
#   inflating: /content/Pneumothorax/masks/6137_train_0_.png
#   inflating: /content/Pneumothorax/masks/6138_train_0_.png
#   inflating: /content/Pneumothorax/masks/6139_train_0_.png
#   inflating: /content/Pneumothorax/masks/613_test_0_.png
#   inflating: /content/Pneumothorax/masks/613_train_1_.png
#   inflating: /content/Pneumothorax/masks/6140_train_0_.png
#   inflating: /content/Pneumothorax/masks/6141_train_0_.png
#   inflating: /content/Pneumothorax/masks/6142_train_0_.png
#   inflating: /content/Pneumothorax/masks/6143_train_0_.png
#   inflating: /content/Pneumothorax/masks/6144_train_0_.png
#   inflating: /content/Pneumothorax/masks/6145_train_0_.png
#   inflating: /content/Pneumothorax/masks/6146_train_0_.png
#   inflating: /content/Pneumothorax/masks/6147_train_0_.png
#   inflating: /content/Pneumothorax/masks/6148_train_0_.png
#   inflating: /content/Pneumothorax/masks/6149_train_0_.png
#   inflating: /content/Pneumothorax/masks/614_test_0_.png
#   inflating: /content/Pneumothorax/masks/614_train_0_.png
#   inflating: /content/Pneumothorax/masks/6150_train_0_.png
#   inflating: /content/Pneumothorax/masks/6151_train_0_.png
#   inflating: /content/Pneumothorax/masks/6152_train_0_.png
#   inflating: /content/Pneumothorax/masks/6153_train_0_.png
#   inflating: /content/Pneumothorax/masks/6154_train_0_.png
#   inflating: /content/Pneumothorax/masks/6155_train_0_.png
#   inflating: /content/Pneumothorax/masks/6156_train_0_.png
#   inflating: /content/Pneumothorax/masks/6157_train_0_.png
#   inflating: /content/Pneumothorax/masks/6158_train_0_.png
#   inflating: /content/Pneumothorax/masks/6159_train_0_.png
#   inflating: /content/Pneumothorax/masks/615_test_0_.png
#   inflating: /content/Pneumothorax/masks/615_train_1_.png
#   inflating: /content/Pneumothorax/masks/6160_train_0_.png
#   inflating: /content/Pneumothorax/masks/6161_train_0_.png
#   inflating: /content/Pneumothorax/masks/6162_train_0_.png
#   inflating: /content/Pneumothorax/masks/6163_train_0_.png
#   inflating: /content/Pneumothorax/masks/6164_train_0_.png
#   inflating: /content/Pneumothorax/masks/6165_train_0_.png
#   inflating: /content/Pneumothorax/masks/6166_train_0_.png
#   inflating: /content/Pneumothorax/masks/6167_train_0_.png
#   inflating: /content/Pneumothorax/masks/6168_train_0_.png
#   inflating: /content/Pneumothorax/masks/6169_train_0_.png
#   inflating: /content/Pneumothorax/masks/616_test_0_.png
#   inflating: /content/Pneumothorax/masks/616_train_1_.png
#   inflating: /content/Pneumothorax/masks/6170_train_0_.png
#   inflating: /content/Pneumothorax/masks/6171_train_0_.png
#   inflating: /content/Pneumothorax/masks/6172_train_1_.png
#   inflating: /content/Pneumothorax/masks/6173_train_0_.png
#   inflating: /content/Pneumothorax/masks/6174_train_0_.png
#   inflating: /content/Pneumothorax/masks/6175_train_0_.png
#   inflating: /content/Pneumothorax/masks/6176_train_0_.png
#   inflating: /content/Pneumothorax/masks/6177_train_0_.png
#   inflating: /content/Pneumothorax/masks/6178_train_0_.png
#   inflating: /content/Pneumothorax/masks/6179_train_0_.png
#   inflating: /content/Pneumothorax/masks/617_test_0_.png
#   inflating: /content/Pneumothorax/masks/617_train_1_.png
#   inflating: /content/Pneumothorax/masks/6180_train_1_.png
#   inflating: /content/Pneumothorax/masks/6181_train_0_.png
#   inflating: /content/Pneumothorax/masks/6182_train_0_.png
#   inflating: /content/Pneumothorax/masks/6183_train_0_.png
#   inflating: /content/Pneumothorax/masks/6184_train_0_.png
#   inflating: /content/Pneumothorax/masks/6185_train_0_.png
#   inflating: /content/Pneumothorax/masks/6186_train_0_.png
#   inflating: /content/Pneumothorax/masks/6187_train_0_.png
#   inflating: /content/Pneumothorax/masks/6188_train_0_.png
#   inflating: /content/Pneumothorax/masks/6189_train_0_.png
#   inflating: /content/Pneumothorax/masks/618_test_0_.png
#   inflating: /content/Pneumothorax/masks/618_train_1_.png
#   inflating: /content/Pneumothorax/masks/6190_train_0_.png
#   inflating: /content/Pneumothorax/masks/6191_train_0_.png
#   inflating: /content/Pneumothorax/masks/6192_train_0_.png
#   inflating: /content/Pneumothorax/masks/6193_train_0_.png
#   inflating: /content/Pneumothorax/masks/6194_train_0_.png
#   inflating: /content/Pneumothorax/masks/6195_train_0_.png
#   inflating: /content/Pneumothorax/masks/6196_train_0_.png
#   inflating: /content/Pneumothorax/masks/6197_train_0_.png
#   inflating: /content/Pneumothorax/masks/6198_train_0_.png
#   inflating: /content/Pneumothorax/masks/6199_train_0_.png
#   inflating: /content/Pneumothorax/masks/619_test_0_.png
#   inflating: /content/Pneumothorax/masks/619_train_1_.png
#   inflating: /content/Pneumothorax/masks/61_test_0_.png
#   inflating: /content/Pneumothorax/masks/61_train_1_.png
#   inflating: /content/Pneumothorax/masks/6200_train_0_.png
#   inflating: /content/Pneumothorax/masks/6201_train_0_.png
#   inflating: /content/Pneumothorax/masks/6202_train_0_.png
#   inflating: /content/Pneumothorax/masks/6203_train_0_.png
#   inflating: /content/Pneumothorax/masks/6204_train_0_.png
#   inflating: /content/Pneumothorax/masks/6205_train_0_.png
#   inflating: /content/Pneumothorax/masks/6206_train_0_.png
#   inflating: /content/Pneumothorax/masks/6207_train_0_.png
#   inflating: /content/Pneumothorax/masks/6208_train_0_.png
#   inflating: /content/Pneumothorax/masks/6209_train_0_.png
#   inflating: /content/Pneumothorax/masks/620_test_0_.png
#   inflating: /content/Pneumothorax/masks/620_train_1_.png
#   inflating: /content/Pneumothorax/masks/6210_train_0_.png
#   inflating: /content/Pneumothorax/masks/6211_train_0_.png
#   inflating: /content/Pneumothorax/masks/6212_train_0_.png
#   inflating: /content/Pneumothorax/masks/6213_train_0_.png
#   inflating: /content/Pneumothorax/masks/6214_train_0_.png
#   inflating: /content/Pneumothorax/masks/6215_train_0_.png
#   inflating: /content/Pneumothorax/masks/6216_train_0_.png
#   inflating: /content/Pneumothorax/masks/6217_train_0_.png
#   inflating: /content/Pneumothorax/masks/6218_train_0_.png
#   inflating: /content/Pneumothorax/masks/6219_train_0_.png
#   inflating: /content/Pneumothorax/masks/621_test_0_.png
#   inflating: /content/Pneumothorax/masks/621_train_1_.png
#   inflating: /content/Pneumothorax/masks/6220_train_0_.png
#   inflating: /content/Pneumothorax/masks/6221_train_0_.png
#   inflating: /content/Pneumothorax/masks/6222_train_0_.png
#   inflating: /content/Pneumothorax/masks/6223_train_0_.png
#   inflating: /content/Pneumothorax/masks/6224_train_0_.png
#   inflating: /content/Pneumothorax/masks/6225_train_0_.png
#   inflating: /content/Pneumothorax/masks/6226_train_0_.png
#   inflating: /content/Pneumothorax/masks/6227_train_0_.png
#   inflating: /content/Pneumothorax/masks/6228_train_0_.png
#   inflating: /content/Pneumothorax/masks/6229_train_0_.png
#   inflating: /content/Pneumothorax/masks/622_test_0_.png
#   inflating: /content/Pneumothorax/masks/622_train_0_.png
#   inflating: /content/Pneumothorax/masks/6230_train_0_.png
#   inflating: /content/Pneumothorax/masks/6231_train_0_.png
#   inflating: /content/Pneumothorax/masks/6232_train_0_.png
#   inflating: /content/Pneumothorax/masks/6233_train_0_.png
#   inflating: /content/Pneumothorax/masks/6234_train_0_.png
#   inflating: /content/Pneumothorax/masks/6235_train_0_.png
#   inflating: /content/Pneumothorax/masks/6236_train_0_.png
#   inflating: /content/Pneumothorax/masks/6237_train_0_.png
#   inflating: /content/Pneumothorax/masks/6238_train_0_.png
#   inflating: /content/Pneumothorax/masks/6239_train_0_.png
#   inflating: /content/Pneumothorax/masks/623_test_1_.png
#   inflating: /content/Pneumothorax/masks/623_train_1_.png
#   inflating: /content/Pneumothorax/masks/6240_train_0_.png
#   inflating: /content/Pneumothorax/masks/6241_train_0_.png
#   inflating: /content/Pneumothorax/masks/6242_train_0_.png
#   inflating: /content/Pneumothorax/masks/6243_train_0_.png
#   inflating: /content/Pneumothorax/masks/6244_train_0_.png
#   inflating: /content/Pneumothorax/masks/6245_train_0_.png
#   inflating: /content/Pneumothorax/masks/6246_train_0_.png
#   inflating: /content/Pneumothorax/masks/6247_train_0_.png
#   inflating: /content/Pneumothorax/masks/6248_train_1_.png
#   inflating: /content/Pneumothorax/masks/6249_train_0_.png
#   inflating: /content/Pneumothorax/masks/624_test_0_.png
#   inflating: /content/Pneumothorax/masks/624_train_0_.png
#   inflating: /content/Pneumothorax/masks/6250_train_0_.png
#   inflating: /content/Pneumothorax/masks/6251_train_0_.png
#   inflating: /content/Pneumothorax/masks/6252_train_0_.png
#   inflating: /content/Pneumothorax/masks/6253_train_0_.png
#   inflating: /content/Pneumothorax/masks/6254_train_0_.png
#   inflating: /content/Pneumothorax/masks/6255_train_0_.png
#   inflating: /content/Pneumothorax/masks/6256_train_0_.png
#   inflating: /content/Pneumothorax/masks/6257_train_0_.png
#   inflating: /content/Pneumothorax/masks/6258_train_0_.png
#   inflating: /content/Pneumothorax/masks/6259_train_0_.png
#   inflating: /content/Pneumothorax/masks/625_test_0_.png
#   inflating: /content/Pneumothorax/masks/625_train_0_.png
#   inflating: /content/Pneumothorax/masks/6260_train_0_.png
#   inflating: /content/Pneumothorax/masks/6261_train_0_.png
#   inflating: /content/Pneumothorax/masks/6262_train_0_.png
#   inflating: /content/Pneumothorax/masks/6263_train_0_.png
#   inflating: /content/Pneumothorax/masks/6264_train_0_.png
#   inflating: /content/Pneumothorax/masks/6265_train_0_.png
#   inflating: /content/Pneumothorax/masks/6266_train_0_.png
#   inflating: /content/Pneumothorax/masks/6267_train_0_.png
#   inflating: /content/Pneumothorax/masks/6268_train_0_.png
#   inflating: /content/Pneumothorax/masks/6269_train_0_.png
#   inflating: /content/Pneumothorax/masks/626_test_0_.png
#   inflating: /content/Pneumothorax/masks/626_train_0_.png
#   inflating: /content/Pneumothorax/masks/6270_train_0_.png
#   inflating: /content/Pneumothorax/masks/6271_train_0_.png
#   inflating: /content/Pneumothorax/masks/6272_train_0_.png
#   inflating: /content/Pneumothorax/masks/6273_train_0_.png
#   inflating: /content/Pneumothorax/masks/6274_train_1_.png
#   inflating: /content/Pneumothorax/masks/6275_train_0_.png
#   inflating: /content/Pneumothorax/masks/6276_train_0_.png
#   inflating: /content/Pneumothorax/masks/6277_train_0_.png
#   inflating: /content/Pneumothorax/masks/6278_train_0_.png
#   inflating: /content/Pneumothorax/masks/6279_train_0_.png
#   inflating: /content/Pneumothorax/masks/627_test_0_.png
#   inflating: /content/Pneumothorax/masks/627_train_0_.png
#   inflating: /content/Pneumothorax/masks/6280_train_0_.png
#   inflating: /content/Pneumothorax/masks/6281_train_0_.png
#   inflating: /content/Pneumothorax/masks/6282_train_0_.png
#   inflating: /content/Pneumothorax/masks/6283_train_1_.png
#   inflating: /content/Pneumothorax/masks/6284_train_0_.png
#   inflating: /content/Pneumothorax/masks/6285_train_0_.png
#   inflating: /content/Pneumothorax/masks/6286_train_0_.png
#   inflating: /content/Pneumothorax/masks/6287_train_0_.png
#   inflating: /content/Pneumothorax/masks/6288_train_0_.png
#   inflating: /content/Pneumothorax/masks/6289_train_0_.png
#   inflating: /content/Pneumothorax/masks/628_test_0_.png
#   inflating: /content/Pneumothorax/masks/628_train_1_.png
#   inflating: /content/Pneumothorax/masks/6290_train_0_.png
#   inflating: /content/Pneumothorax/masks/6291_train_0_.png
#   inflating: /content/Pneumothorax/masks/6292_train_0_.png
#   inflating: /content/Pneumothorax/masks/6293_train_0_.png
#   inflating: /content/Pneumothorax/masks/6294_train_0_.png
#   inflating: /content/Pneumothorax/masks/6295_train_0_.png
#   inflating: /content/Pneumothorax/masks/6296_train_0_.png
#   inflating: /content/Pneumothorax/masks/6297_train_0_.png
#   inflating: /content/Pneumothorax/masks/6298_train_0_.png
#   inflating: /content/Pneumothorax/masks/6299_train_0_.png
#   inflating: /content/Pneumothorax/masks/629_test_0_.png
#   inflating: /content/Pneumothorax/masks/629_train_1_.png
#   inflating: /content/Pneumothorax/masks/62_test_0_.png
#   inflating: /content/Pneumothorax/masks/62_train_1_.png
#   inflating: /content/Pneumothorax/masks/6300_train_0_.png
#   inflating: /content/Pneumothorax/masks/6301_train_0_.png
#   inflating: /content/Pneumothorax/masks/6302_train_0_.png
#   inflating: /content/Pneumothorax/masks/6303_train_0_.png
#   inflating: /content/Pneumothorax/masks/6304_train_0_.png
#   inflating: /content/Pneumothorax/masks/6305_train_0_.png
#   inflating: /content/Pneumothorax/masks/6306_train_0_.png
#   inflating: /content/Pneumothorax/masks/6307_train_0_.png
#   inflating: /content/Pneumothorax/masks/6308_train_0_.png
#   inflating: /content/Pneumothorax/masks/6309_train_0_.png
#   inflating: /content/Pneumothorax/masks/630_test_1_.png
#   inflating: /content/Pneumothorax/masks/630_train_1_.png
#   inflating: /content/Pneumothorax/masks/6310_train_0_.png
#   inflating: /content/Pneumothorax/masks/6311_train_0_.png
#   inflating: /content/Pneumothorax/masks/6312_train_0_.png
#   inflating: /content/Pneumothorax/masks/6313_train_0_.png
#   inflating: /content/Pneumothorax/masks/6314_train_0_.png
#   inflating: /content/Pneumothorax/masks/6315_train_0_.png
#   inflating: /content/Pneumothorax/masks/6316_train_0_.png
#   inflating: /content/Pneumothorax/masks/6317_train_0_.png
#   inflating: /content/Pneumothorax/masks/6318_train_0_.png
#   inflating: /content/Pneumothorax/masks/6319_train_0_.png
#   inflating: /content/Pneumothorax/masks/631_test_1_.png
#   inflating: /content/Pneumothorax/masks/631_train_0_.png
#   inflating: /content/Pneumothorax/masks/6320_train_0_.png
#   inflating: /content/Pneumothorax/masks/6321_train_0_.png
#   inflating: /content/Pneumothorax/masks/6322_train_0_.png
#   inflating: /content/Pneumothorax/masks/6323_train_0_.png
#   inflating: /content/Pneumothorax/masks/6324_train_0_.png
#   inflating: /content/Pneumothorax/masks/6325_train_0_.png
#   inflating: /content/Pneumothorax/masks/6326_train_0_.png
#   inflating: /content/Pneumothorax/masks/6327_train_0_.png
#   inflating: /content/Pneumothorax/masks/6328_train_0_.png
#   inflating: /content/Pneumothorax/masks/6329_train_0_.png
#   inflating: /content/Pneumothorax/masks/632_test_0_.png
#   inflating: /content/Pneumothorax/masks/632_train_1_.png
#   inflating: /content/Pneumothorax/masks/6330_train_0_.png
#   inflating: /content/Pneumothorax/masks/6331_train_0_.png
#   inflating: /content/Pneumothorax/masks/6332_train_0_.png
#   inflating: /content/Pneumothorax/masks/6333_train_0_.png
#   inflating: /content/Pneumothorax/masks/6334_train_0_.png
#   inflating: /content/Pneumothorax/masks/6335_train_0_.png
#   inflating: /content/Pneumothorax/masks/6336_train_0_.png
#   inflating: /content/Pneumothorax/masks/6337_train_0_.png
#   inflating: /content/Pneumothorax/masks/6338_train_0_.png
#   inflating: /content/Pneumothorax/masks/6339_train_0_.png
#   inflating: /content/Pneumothorax/masks/633_test_0_.png
#   inflating: /content/Pneumothorax/masks/633_train_1_.png
#   inflating: /content/Pneumothorax/masks/6340_train_0_.png
#   inflating: /content/Pneumothorax/masks/6341_train_0_.png
#   inflating: /content/Pneumothorax/masks/6342_train_0_.png
#   inflating: /content/Pneumothorax/masks/6343_train_0_.png
#   inflating: /content/Pneumothorax/masks/6344_train_0_.png
#   inflating: /content/Pneumothorax/masks/6345_train_0_.png
#   inflating: /content/Pneumothorax/masks/6346_train_0_.png
#   inflating: /content/Pneumothorax/masks/6347_train_0_.png
#   inflating: /content/Pneumothorax/masks/6348_train_0_.png
#   inflating: /content/Pneumothorax/masks/6349_train_0_.png
#   inflating: /content/Pneumothorax/masks/634_test_1_.png
#   inflating: /content/Pneumothorax/masks/634_train_1_.png
#   inflating: /content/Pneumothorax/masks/6350_train_0_.png
#   inflating: /content/Pneumothorax/masks/6351_train_0_.png
#   inflating: /content/Pneumothorax/masks/6352_train_0_.png
#   inflating: /content/Pneumothorax/masks/6353_train_0_.png
#   inflating: /content/Pneumothorax/masks/6354_train_0_.png
#   inflating: /content/Pneumothorax/masks/6355_train_0_.png
#   inflating: /content/Pneumothorax/masks/6356_train_0_.png
#   inflating: /content/Pneumothorax/masks/6357_train_0_.png
#   inflating: /content/Pneumothorax/masks/6358_train_0_.png
#   inflating: /content/Pneumothorax/masks/6359_train_0_.png
#   inflating: /content/Pneumothorax/masks/635_test_0_.png
#   inflating: /content/Pneumothorax/masks/635_train_1_.png
#   inflating: /content/Pneumothorax/masks/6360_train_0_.png
#   inflating: /content/Pneumothorax/masks/6361_train_0_.png
#   inflating: /content/Pneumothorax/masks/6362_train_0_.png
#   inflating: /content/Pneumothorax/masks/6363_train_0_.png
#   inflating: /content/Pneumothorax/masks/6364_train_0_.png
#   inflating: /content/Pneumothorax/masks/6365_train_0_.png
#   inflating: /content/Pneumothorax/masks/6366_train_0_.png
#   inflating: /content/Pneumothorax/masks/6367_train_0_.png
#   inflating: /content/Pneumothorax/masks/6368_train_0_.png
#   inflating: /content/Pneumothorax/masks/6369_train_0_.png
#   inflating: /content/Pneumothorax/masks/636_test_0_.png
#   inflating: /content/Pneumothorax/masks/636_train_0_.png
#   inflating: /content/Pneumothorax/masks/6370_train_0_.png
#   inflating: /content/Pneumothorax/masks/6371_train_1_.png
#   inflating: /content/Pneumothorax/masks/6372_train_0_.png
#   inflating: /content/Pneumothorax/masks/6373_train_0_.png
#   inflating: /content/Pneumothorax/masks/6374_train_0_.png
#   inflating: /content/Pneumothorax/masks/6375_train_0_.png
#   inflating: /content/Pneumothorax/masks/6376_train_0_.png
#   inflating: /content/Pneumothorax/masks/6377_train_0_.png
#   inflating: /content/Pneumothorax/masks/6378_train_0_.png
#   inflating: /content/Pneumothorax/masks/6379_train_0_.png
#   inflating: /content/Pneumothorax/masks/637_test_0_.png
#   inflating: /content/Pneumothorax/masks/637_train_1_.png
#   inflating: /content/Pneumothorax/masks/6380_train_0_.png
#   inflating: /content/Pneumothorax/masks/6381_train_0_.png
#   inflating: /content/Pneumothorax/masks/6382_train_0_.png
#   inflating: /content/Pneumothorax/masks/6383_train_0_.png
#   inflating: /content/Pneumothorax/masks/6384_train_0_.png
#   inflating: /content/Pneumothorax/masks/6385_train_0_.png
#   inflating: /content/Pneumothorax/masks/6386_train_1_.png
#   inflating: /content/Pneumothorax/masks/6387_train_1_.png
#   inflating: /content/Pneumothorax/masks/6388_train_0_.png
#   inflating: /content/Pneumothorax/masks/6389_train_0_.png
#   inflating: /content/Pneumothorax/masks/638_test_0_.png
#   inflating: /content/Pneumothorax/masks/638_train_0_.png
#   inflating: /content/Pneumothorax/masks/6390_train_0_.png
#   inflating: /content/Pneumothorax/masks/6391_train_0_.png
#   inflating: /content/Pneumothorax/masks/6392_train_0_.png
#   inflating: /content/Pneumothorax/masks/6393_train_0_.png
#   inflating: /content/Pneumothorax/masks/6394_train_0_.png
#   inflating: /content/Pneumothorax/masks/6395_train_0_.png
#   inflating: /content/Pneumothorax/masks/6396_train_0_.png
#   inflating: /content/Pneumothorax/masks/6397_train_0_.png
#   inflating: /content/Pneumothorax/masks/6398_train_0_.png
#   inflating: /content/Pneumothorax/masks/6399_train_0_.png
#   inflating: /content/Pneumothorax/masks/639_test_0_.png
#   inflating: /content/Pneumothorax/masks/639_train_1_.png
#   inflating: /content/Pneumothorax/masks/63_test_0_.png
#   inflating: /content/Pneumothorax/masks/63_train_1_.png
#   inflating: /content/Pneumothorax/masks/6400_train_0_.png
#   inflating: /content/Pneumothorax/masks/6401_train_0_.png
#   inflating: /content/Pneumothorax/masks/6402_train_0_.png
#   inflating: /content/Pneumothorax/masks/6403_train_0_.png
#   inflating: /content/Pneumothorax/masks/6404_train_0_.png
#   inflating: /content/Pneumothorax/masks/6405_train_0_.png
#   inflating: /content/Pneumothorax/masks/6406_train_0_.png
#   inflating: /content/Pneumothorax/masks/6407_train_0_.png
#   inflating: /content/Pneumothorax/masks/6408_train_0_.png
#   inflating: /content/Pneumothorax/masks/6409_train_0_.png
#   inflating: /content/Pneumothorax/masks/640_test_1_.png
#   inflating: /content/Pneumothorax/masks/640_train_0_.png
#   inflating: /content/Pneumothorax/masks/6410_train_0_.png
#   inflating: /content/Pneumothorax/masks/6411_train_0_.png
#   inflating: /content/Pneumothorax/masks/6412_train_0_.png
#   inflating: /content/Pneumothorax/masks/6413_train_0_.png
#   inflating: /content/Pneumothorax/masks/6414_train_0_.png
#   inflating: /content/Pneumothorax/masks/6415_train_0_.png
#   inflating: /content/Pneumothorax/masks/6416_train_0_.png
#   inflating: /content/Pneumothorax/masks/6417_train_0_.png
#   inflating: /content/Pneumothorax/masks/6418_train_0_.png
#   inflating: /content/Pneumothorax/masks/6419_train_0_.png
#   inflating: /content/Pneumothorax/masks/641_test_1_.png
#   inflating: /content/Pneumothorax/masks/641_train_0_.png
#   inflating: /content/Pneumothorax/masks/6420_train_0_.png
#   inflating: /content/Pneumothorax/masks/6421_train_0_.png
#   inflating: /content/Pneumothorax/masks/6422_train_0_.png
#   inflating: /content/Pneumothorax/masks/6423_train_0_.png
#   inflating: /content/Pneumothorax/masks/6424_train_0_.png
#   inflating: /content/Pneumothorax/masks/6425_train_0_.png
#   inflating: /content/Pneumothorax/masks/6426_train_1_.png
#   inflating: /content/Pneumothorax/masks/6427_train_0_.png
#   inflating: /content/Pneumothorax/masks/6428_train_0_.png
#   inflating: /content/Pneumothorax/masks/6429_train_0_.png
#   inflating: /content/Pneumothorax/masks/642_test_0_.png
#   inflating: /content/Pneumothorax/masks/642_train_1_.png
#   inflating: /content/Pneumothorax/masks/6430_train_0_.png
#   inflating: /content/Pneumothorax/masks/6431_train_0_.png
#   inflating: /content/Pneumothorax/masks/6432_train_0_.png
#   inflating: /content/Pneumothorax/masks/6433_train_0_.png
#   inflating: /content/Pneumothorax/masks/6434_train_0_.png
#   inflating: /content/Pneumothorax/masks/6435_train_0_.png
#   inflating: /content/Pneumothorax/masks/6436_train_0_.png
#   inflating: /content/Pneumothorax/masks/6437_train_0_.png
#   inflating: /content/Pneumothorax/masks/6438_train_0_.png
#   inflating: /content/Pneumothorax/masks/6439_train_0_.png
#   inflating: /content/Pneumothorax/masks/643_test_0_.png
#   inflating: /content/Pneumothorax/masks/643_train_0_.png
#   inflating: /content/Pneumothorax/masks/6440_train_0_.png
#   inflating: /content/Pneumothorax/masks/6441_train_0_.png
#   inflating: /content/Pneumothorax/masks/6442_train_0_.png
#   inflating: /content/Pneumothorax/masks/6443_train_0_.png
#   inflating: /content/Pneumothorax/masks/6444_train_1_.png
#   inflating: /content/Pneumothorax/masks/6445_train_0_.png
#   inflating: /content/Pneumothorax/masks/6446_train_0_.png
#   inflating: /content/Pneumothorax/masks/6447_train_0_.png
#   inflating: /content/Pneumothorax/masks/6448_train_0_.png
#   inflating: /content/Pneumothorax/masks/6449_train_0_.png
#   inflating: /content/Pneumothorax/masks/644_test_0_.png
#   inflating: /content/Pneumothorax/masks/644_train_1_.png
#   inflating: /content/Pneumothorax/masks/6450_train_0_.png
#   inflating: /content/Pneumothorax/masks/6451_train_0_.png
#   inflating: /content/Pneumothorax/masks/6452_train_0_.png
#   inflating: /content/Pneumothorax/masks/6453_train_0_.png
#   inflating: /content/Pneumothorax/masks/6454_train_0_.png
#   inflating: /content/Pneumothorax/masks/6455_train_0_.png
#   inflating: /content/Pneumothorax/masks/6456_train_0_.png
#   inflating: /content/Pneumothorax/masks/6457_train_0_.png
#   inflating: /content/Pneumothorax/masks/6458_train_0_.png
#   inflating: /content/Pneumothorax/masks/6459_train_0_.png
#   inflating: /content/Pneumothorax/masks/645_test_1_.png
#   inflating: /content/Pneumothorax/masks/645_train_1_.png
#   inflating: /content/Pneumothorax/masks/6460_train_0_.png
#   inflating: /content/Pneumothorax/masks/6461_train_0_.png
#   inflating: /content/Pneumothorax/masks/6462_train_0_.png
#   inflating: /content/Pneumothorax/masks/6463_train_0_.png
#   inflating: /content/Pneumothorax/masks/6464_train_0_.png
#   inflating: /content/Pneumothorax/masks/6465_train_1_.png
#   inflating: /content/Pneumothorax/masks/6466_train_0_.png
#   inflating: /content/Pneumothorax/masks/6467_train_0_.png
#   inflating: /content/Pneumothorax/masks/6468_train_0_.png
#   inflating: /content/Pneumothorax/masks/6469_train_0_.png
#   inflating: /content/Pneumothorax/masks/646_test_0_.png
#   inflating: /content/Pneumothorax/masks/646_train_1_.png
#   inflating: /content/Pneumothorax/masks/6470_train_0_.png
#   inflating: /content/Pneumothorax/masks/6471_train_0_.png
#   inflating: /content/Pneumothorax/masks/6472_train_0_.png
#   inflating: /content/Pneumothorax/masks/6473_train_0_.png
#   inflating: /content/Pneumothorax/masks/6474_train_0_.png
#   inflating: /content/Pneumothorax/masks/6475_train_0_.png
#   inflating: /content/Pneumothorax/masks/6476_train_0_.png
#   inflating: /content/Pneumothorax/masks/6477_train_0_.png
#   inflating: /content/Pneumothorax/masks/6478_train_0_.png
#   inflating: /content/Pneumothorax/masks/6479_train_0_.png
#   inflating: /content/Pneumothorax/masks/647_test_0_.png
#   inflating: /content/Pneumothorax/masks/647_train_1_.png
#   inflating: /content/Pneumothorax/masks/6480_train_0_.png
#   inflating: /content/Pneumothorax/masks/6481_train_0_.png
#   inflating: /content/Pneumothorax/masks/6482_train_0_.png
#   inflating: /content/Pneumothorax/masks/6483_train_0_.png
#   inflating: /content/Pneumothorax/masks/6484_train_0_.png
#   inflating: /content/Pneumothorax/masks/6485_train_0_.png
#   inflating: /content/Pneumothorax/masks/6486_train_0_.png
#   inflating: /content/Pneumothorax/masks/6487_train_0_.png
#   inflating: /content/Pneumothorax/masks/6488_train_0_.png
#   inflating: /content/Pneumothorax/masks/6489_train_0_.png
#   inflating: /content/Pneumothorax/masks/648_test_0_.png
#   inflating: /content/Pneumothorax/masks/648_train_1_.png
#   inflating: /content/Pneumothorax/masks/6490_train_0_.png
#   inflating: /content/Pneumothorax/masks/6491_train_0_.png
#   inflating: /content/Pneumothorax/masks/6492_train_0_.png
#   inflating: /content/Pneumothorax/masks/6493_train_0_.png
#   inflating: /content/Pneumothorax/masks/6494_train_0_.png
#   inflating: /content/Pneumothorax/masks/6495_train_0_.png
#   inflating: /content/Pneumothorax/masks/6496_train_0_.png
#   inflating: /content/Pneumothorax/masks/6497_train_0_.png
#   inflating: /content/Pneumothorax/masks/6498_train_0_.png
#   inflating: /content/Pneumothorax/masks/6499_train_0_.png
#   inflating: /content/Pneumothorax/masks/649_test_0_.png
#   inflating: /content/Pneumothorax/masks/649_train_1_.png
#   inflating: /content/Pneumothorax/masks/64_test_1_.png
#   inflating: /content/Pneumothorax/masks/64_train_1_.png
#   inflating: /content/Pneumothorax/masks/6500_train_0_.png
#   inflating: /content/Pneumothorax/masks/6501_train_0_.png
#   inflating: /content/Pneumothorax/masks/6502_train_0_.png
#   inflating: /content/Pneumothorax/masks/6503_train_0_.png
#   inflating: /content/Pneumothorax/masks/6504_train_0_.png
#   inflating: /content/Pneumothorax/masks/6505_train_0_.png
#   inflating: /content/Pneumothorax/masks/6506_train_0_.png
#   inflating: /content/Pneumothorax/masks/6507_train_0_.png
#   inflating: /content/Pneumothorax/masks/6508_train_0_.png
#   inflating: /content/Pneumothorax/masks/6509_train_0_.png
#   inflating: /content/Pneumothorax/masks/650_test_0_.png
#   inflating: /content/Pneumothorax/masks/650_train_0_.png
#   inflating: /content/Pneumothorax/masks/6510_train_0_.png
#   inflating: /content/Pneumothorax/masks/6511_train_0_.png
#   inflating: /content/Pneumothorax/masks/6512_train_0_.png
#   inflating: /content/Pneumothorax/masks/6513_train_0_.png
#   inflating: /content/Pneumothorax/masks/6514_train_0_.png
#   inflating: /content/Pneumothorax/masks/6515_train_0_.png
#   inflating: /content/Pneumothorax/masks/6516_train_0_.png
#   inflating: /content/Pneumothorax/masks/6517_train_0_.png
#   inflating: /content/Pneumothorax/masks/6518_train_0_.png
#   inflating: /content/Pneumothorax/masks/6519_train_0_.png
#   inflating: /content/Pneumothorax/masks/651_test_0_.png
#   inflating: /content/Pneumothorax/masks/651_train_0_.png
#   inflating: /content/Pneumothorax/masks/6520_train_0_.png
#   inflating: /content/Pneumothorax/masks/6521_train_0_.png
#   inflating: /content/Pneumothorax/masks/6522_train_0_.png
#   inflating: /content/Pneumothorax/masks/6523_train_0_.png
#   inflating: /content/Pneumothorax/masks/6524_train_0_.png
#   inflating: /content/Pneumothorax/masks/6525_train_0_.png
#   inflating: /content/Pneumothorax/masks/6526_train_0_.png
#   inflating: /content/Pneumothorax/masks/6527_train_0_.png
#   inflating: /content/Pneumothorax/masks/6528_train_0_.png
#   inflating: /content/Pneumothorax/masks/6529_train_0_.png
#   inflating: /content/Pneumothorax/masks/652_test_0_.png
#   inflating: /content/Pneumothorax/masks/652_train_0_.png
#   inflating: /content/Pneumothorax/masks/6530_train_0_.png
#   inflating: /content/Pneumothorax/masks/6531_train_0_.png
#   inflating: /content/Pneumothorax/masks/6532_train_0_.png
#   inflating: /content/Pneumothorax/masks/6533_train_0_.png
#   inflating: /content/Pneumothorax/masks/6534_train_0_.png
#   inflating: /content/Pneumothorax/masks/6535_train_0_.png
#   inflating: /content/Pneumothorax/masks/6536_train_0_.png
#   inflating: /content/Pneumothorax/masks/6537_train_0_.png
#   inflating: /content/Pneumothorax/masks/6538_train_0_.png
#   inflating: /content/Pneumothorax/masks/6539_train_0_.png
#   inflating: /content/Pneumothorax/masks/653_test_1_.png
#   inflating: /content/Pneumothorax/masks/653_train_1_.png
#   inflating: /content/Pneumothorax/masks/6540_train_0_.png
#   inflating: /content/Pneumothorax/masks/6541_train_0_.png
#   inflating: /content/Pneumothorax/masks/6542_train_0_.png
#   inflating: /content/Pneumothorax/masks/6543_train_0_.png
#   inflating: /content/Pneumothorax/masks/6544_train_0_.png
#   inflating: /content/Pneumothorax/masks/6545_train_0_.png
#   inflating: /content/Pneumothorax/masks/6546_train_0_.png
#   inflating: /content/Pneumothorax/masks/6547_train_0_.png
#   inflating: /content/Pneumothorax/masks/6548_train_0_.png
#   inflating: /content/Pneumothorax/masks/6549_train_0_.png
#   inflating: /content/Pneumothorax/masks/654_test_1_.png
#   inflating: /content/Pneumothorax/masks/654_train_1_.png
#   inflating: /content/Pneumothorax/masks/6550_train_0_.png
#   inflating: /content/Pneumothorax/masks/6551_train_0_.png
#   inflating: /content/Pneumothorax/masks/6552_train_0_.png
#   inflating: /content/Pneumothorax/masks/6553_train_0_.png
#   inflating: /content/Pneumothorax/masks/6554_train_0_.png
#   inflating: /content/Pneumothorax/masks/6555_train_0_.png
#   inflating: /content/Pneumothorax/masks/6556_train_0_.png
#   inflating: /content/Pneumothorax/masks/6557_train_0_.png
#   inflating: /content/Pneumothorax/masks/6558_train_0_.png
# ...
#   inflating: /content/Pneumothorax/masks/978_test_0_.png
#   inflating: /content/Pneumothorax/masks/978_train_0_.png
#   inflating: /content/Pneumothorax/masks/9790_train_0_.png
#   inflating: /content/Pneumothorax/masks/9791_train_0_.png
#   inflating: /content/Pneumothorax/masks/9792_train_0_.png
#   inflating: /content/Pneumothorax/masks/9793_train_0_.png
#   inflating: /content/Pneumothorax/masks/9794_train_0_.png
#   inflating: /content/Pneumothorax/masks/9795_train_0_.png
#   inflating: /content/Pneumothorax/masks/9796_train_0_.png
#   inflating: /content/Pneumothorax/masks/9797_train_0_.png
#   inflating: /content/Pneumothorax/masks/9798_train_0_.png
#   inflating: /content/Pneumothorax/masks/9799_train_0_.png
#   inflating: /content/Pneumothorax/masks/979_test_0_.png
#   inflating: /content/Pneumothorax/masks/979_train_1_.png
#   inflating: /content/Pneumothorax/masks/97_test_0_.png
#   inflating: /content/Pneumothorax/masks/97_train_1_.png
#   inflating: /content/Pneumothorax/masks/9800_train_0_.png
#   inflating: /content/Pneumothorax/masks/9801_train_0_.png
#   inflating: /content/Pneumothorax/masks/9802_train_0_.png
#   inflating: /content/Pneumothorax/masks/9803_train_0_.png
#   inflating: /content/Pneumothorax/masks/9804_train_0_.png
#   inflating: /content/Pneumothorax/masks/9805_train_0_.png
#   inflating: /content/Pneumothorax/masks/9806_train_0_.png
#   inflating: /content/Pneumothorax/masks/9807_train_0_.png
#   inflating: /content/Pneumothorax/masks/9808_train_0_.png
#   inflating: /content/Pneumothorax/masks/9809_train_0_.png
#   inflating: /content/Pneumothorax/masks/980_test_0_.png
#   inflating: /content/Pneumothorax/masks/980_train_1_.png
#   inflating: /content/Pneumothorax/masks/9810_train_0_.png
#   inflating: /content/Pneumothorax/masks/9811_train_0_.png
#   inflating: /content/Pneumothorax/masks/9812_train_0_.png
#   inflating: /content/Pneumothorax/masks/9813_train_0_.png
#   inflating: /content/Pneumothorax/masks/9814_train_0_.png
#   inflating: /content/Pneumothorax/masks/9815_train_0_.png
#   inflating: /content/Pneumothorax/masks/9816_train_0_.png
#   inflating: /content/Pneumothorax/masks/9817_train_0_.png
#   inflating: /content/Pneumothorax/masks/9818_train_0_.png
#   inflating: /content/Pneumothorax/masks/9819_train_0_.png
#   inflating: /content/Pneumothorax/masks/981_test_0_.png
#   inflating: /content/Pneumothorax/masks/981_train_1_.png
#   inflating: /content/Pneumothorax/masks/9820_train_0_.png
#   inflating: /content/Pneumothorax/masks/9821_train_0_.png
#   inflating: /content/Pneumothorax/masks/9822_train_0_.png
#   inflating: /content/Pneumothorax/masks/9823_train_0_.png
#   inflating: /content/Pneumothorax/masks/9824_train_0_.png
#   inflating: /content/Pneumothorax/masks/9825_train_0_.png
#   inflating: /content/Pneumothorax/masks/9826_train_0_.png
#   inflating: /content/Pneumothorax/masks/9827_train_0_.png
#   inflating: /content/Pneumothorax/masks/9828_train_0_.png
#   inflating: /content/Pneumothorax/masks/9829_train_0_.png
#   inflating: /content/Pneumothorax/masks/982_test_1_.png
#   inflating: /content/Pneumothorax/masks/982_train_0_.png
#   inflating: /content/Pneumothorax/masks/9830_train_0_.png
#   inflating: /content/Pneumothorax/masks/9831_train_0_.png
#   inflating: /content/Pneumothorax/masks/9832_train_0_.png
#   inflating: /content/Pneumothorax/masks/9833_train_0_.png
#   inflating: /content/Pneumothorax/masks/9834_train_0_.png
#   inflating: /content/Pneumothorax/masks/9835_train_0_.png
#   inflating: /content/Pneumothorax/masks/9836_train_0_.png
#   inflating: /content/Pneumothorax/masks/9837_train_0_.png
#   inflating: /content/Pneumothorax/masks/9838_train_0_.png
#   inflating: /content/Pneumothorax/masks/9839_train_0_.png
#   inflating: /content/Pneumothorax/masks/983_test_0_.png
#   inflating: /content/Pneumothorax/masks/983_train_1_.png
#   inflating: /content/Pneumothorax/masks/9840_train_0_.png
#   inflating: /content/Pneumothorax/masks/9841_train_0_.png
#   inflating: /content/Pneumothorax/masks/9842_train_0_.png
#   inflating: /content/Pneumothorax/masks/9843_train_0_.png
#   inflating: /content/Pneumothorax/masks/9844_train_0_.png
#   inflating: /content/Pneumothorax/masks/9845_train_0_.png
#   inflating: /content/Pneumothorax/masks/9846_train_0_.png
#   inflating: /content/Pneumothorax/masks/9847_train_0_.png
#   inflating: /content/Pneumothorax/masks/9848_train_0_.png
#   inflating: /content/Pneumothorax/masks/9849_train_0_.png
#   inflating: /content/Pneumothorax/masks/984_test_0_.png
#   inflating: /content/Pneumothorax/masks/984_train_1_.png
#   inflating: /content/Pneumothorax/masks/9850_train_0_.png
#   inflating: /content/Pneumothorax/masks/9851_train_0_.png
#   inflating: /content/Pneumothorax/masks/9852_train_0_.png
#   inflating: /content/Pneumothorax/masks/9853_train_0_.png
#   inflating: /content/Pneumothorax/masks/9854_train_0_.png
#   inflating: /content/Pneumothorax/masks/9855_train_0_.png
#   inflating: /content/Pneumothorax/masks/9856_train_0_.png
#   inflating: /content/Pneumothorax/masks/9857_train_0_.png
#   inflating: /content/Pneumothorax/masks/9858_train_0_.png
#   inflating: /content/Pneumothorax/masks/9859_train_0_.png
#   inflating: /content/Pneumothorax/masks/985_test_1_.png
#   inflating: /content/Pneumothorax/masks/985_train_0_.png
#   inflating: /content/Pneumothorax/masks/9860_train_0_.png
#   inflating: /content/Pneumothorax/masks/9861_train_0_.png
#   inflating: /content/Pneumothorax/masks/9862_train_0_.png
#   inflating: /content/Pneumothorax/masks/9863_train_0_.png
#   inflating: /content/Pneumothorax/masks/9864_train_0_.png
#   inflating: /content/Pneumothorax/masks/9865_train_0_.png
#   inflating: /content/Pneumothorax/masks/9866_train_0_.png
#   inflating: /content/Pneumothorax/masks/9867_train_0_.png
#   inflating: /content/Pneumothorax/masks/9868_train_0_.png
#   inflating: /content/Pneumothorax/masks/9869_train_0_.png
#   inflating: /content/Pneumothorax/masks/986_test_1_.png
#   inflating: /content/Pneumothorax/masks/986_train_1_.png
#   inflating: /content/Pneumothorax/masks/9870_train_0_.png
#   inflating: /content/Pneumothorax/masks/9871_train_0_.png
#   inflating: /content/Pneumothorax/masks/9872_train_0_.png
#   inflating: /content/Pneumothorax/masks/9873_train_0_.png
#   inflating: /content/Pneumothorax/masks/9874_train_0_.png
#   inflating: /content/Pneumothorax/masks/9875_train_0_.png
#   inflating: /content/Pneumothorax/masks/9876_train_0_.png
#   inflating: /content/Pneumothorax/masks/9877_train_0_.png
#   inflating: /content/Pneumothorax/masks/9878_train_0_.png
#   inflating: /content/Pneumothorax/masks/9879_train_0_.png
#   inflating: /content/Pneumothorax/masks/987_test_0_.png
#   inflating: /content/Pneumothorax/masks/987_train_1_.png
#   inflating: /content/Pneumothorax/masks/9880_train_0_.png
#   inflating: /content/Pneumothorax/masks/9881_train_0_.png
#   inflating: /content/Pneumothorax/masks/9882_train_0_.png
#   inflating: /content/Pneumothorax/masks/9883_train_0_.png
#   inflating: /content/Pneumothorax/masks/9884_train_0_.png
#   inflating: /content/Pneumothorax/masks/9885_train_0_.png
#   inflating: /content/Pneumothorax/masks/9886_train_0_.png
#   inflating: /content/Pneumothorax/masks/9887_train_0_.png
#   inflating: /content/Pneumothorax/masks/9888_train_0_.png
#   inflating: /content/Pneumothorax/masks/9889_train_0_.png
#   inflating: /content/Pneumothorax/masks/988_test_1_.png
#   inflating: /content/Pneumothorax/masks/988_train_1_.png
#   inflating: /content/Pneumothorax/masks/9890_train_0_.png
#   inflating: /content/Pneumothorax/masks/9891_train_0_.png
#   inflating: /content/Pneumothorax/masks/9892_train_0_.png
#   inflating: /content/Pneumothorax/masks/9893_train_0_.png
#   inflating: /content/Pneumothorax/masks/9894_train_0_.png
#   inflating: /content/Pneumothorax/masks/9895_train_0_.png
#   inflating: /content/Pneumothorax/masks/9896_train_0_.png
#   inflating: /content/Pneumothorax/masks/9897_train_0_.png
#   inflating: /content/Pneumothorax/masks/9898_train_0_.png
#   inflating: /content/Pneumothorax/masks/9899_train_0_.png
#   inflating: /content/Pneumothorax/masks/989_test_0_.png
#   inflating: /content/Pneumothorax/masks/989_train_1_.png
#   inflating: /content/Pneumothorax/masks/98_test_1_.png
#   inflating: /content/Pneumothorax/masks/98_train_0_.png
#   inflating: /content/Pneumothorax/masks/9900_train_0_.png
#   inflating: /content/Pneumothorax/masks/9901_train_0_.png
#   inflating: /content/Pneumothorax/masks/9902_train_0_.png
#   inflating: /content/Pneumothorax/masks/9903_train_0_.png
#   inflating: /content/Pneumothorax/masks/9904_train_0_.png
#   inflating: /content/Pneumothorax/masks/9905_train_0_.png
#   inflating: /content/Pneumothorax/masks/9906_train_0_.png
#   inflating: /content/Pneumothorax/masks/9907_train_0_.png
#   inflating: /content/Pneumothorax/masks/9908_train_0_.png
#   inflating: /content/Pneumothorax/masks/9909_train_0_.png
#   inflating: /content/Pneumothorax/masks/990_test_1_.png
#   inflating: /content/Pneumothorax/masks/990_train_1_.png
#   inflating: /content/Pneumothorax/masks/9910_train_0_.png
#   inflating: /content/Pneumothorax/masks/9911_train_0_.png
#   inflating: /content/Pneumothorax/masks/9912_train_0_.png
#   inflating: /content/Pneumothorax/masks/9913_train_0_.png
#   inflating: /content/Pneumothorax/masks/9914_train_0_.png
#   inflating: /content/Pneumothorax/masks/9915_train_0_.png
#   inflating: /content/Pneumothorax/masks/9916_train_0_.png
#   inflating: /content/Pneumothorax/masks/9917_train_0_.png
#   inflating: /content/Pneumothorax/masks/9918_train_0_.png
#   inflating: /content/Pneumothorax/masks/9919_train_0_.png
#   inflating: /content/Pneumothorax/masks/991_test_0_.png
#   inflating: /content/Pneumothorax/masks/991_train_1_.png
#   inflating: /content/Pneumothorax/masks/9920_train_0_.png
#   inflating: /content/Pneumothorax/masks/9921_train_0_.png
#   inflating: /content/Pneumothorax/masks/9922_train_0_.png
#   inflating: /content/Pneumothorax/masks/9923_train_0_.png
#   inflating: /content/Pneumothorax/masks/9924_train_0_.png
#   inflating: /content/Pneumothorax/masks/9925_train_0_.png
#   inflating: /content/Pneumothorax/masks/9926_train_0_.png
#   inflating: /content/Pneumothorax/masks/9927_train_0_.png
#   inflating: /content/Pneumothorax/masks/9928_train_0_.png
#   inflating: /content/Pneumothorax/masks/9929_train_0_.png
#   inflating: /content/Pneumothorax/masks/992_test_0_.png
#   inflating: /content/Pneumothorax/masks/992_train_1_.png
#   inflating: /content/Pneumothorax/masks/9930_train_0_.png
#   inflating: /content/Pneumothorax/masks/9931_train_0_.png
#   inflating: /content/Pneumothorax/masks/9932_train_0_.png
#   inflating: /content/Pneumothorax/masks/9933_train_0_.png
#   inflating: /content/Pneumothorax/masks/9934_train_0_.png
#   inflating: /content/Pneumothorax/masks/9935_train_0_.png
#   inflating: /content/Pneumothorax/masks/9936_train_0_.png
#   inflating: /content/Pneumothorax/masks/9937_train_0_.png
#   inflating: /content/Pneumothorax/masks/9938_train_0_.png
#   inflating: /content/Pneumothorax/masks/9939_train_0_.png
#   inflating: /content/Pneumothorax/masks/993_test_0_.png
#   inflating: /content/Pneumothorax/masks/993_train_0_.png
#   inflating: /content/Pneumothorax/masks/9940_train_0_.png
#   inflating: /content/Pneumothorax/masks/9941_train_0_.png
#   inflating: /content/Pneumothorax/masks/9942_train_0_.png
#   inflating: /content/Pneumothorax/masks/9943_train_0_.png
#   inflating: /content/Pneumothorax/masks/9944_train_0_.png
#   inflating: /content/Pneumothorax/masks/9945_train_0_.png
#   inflating: /content/Pneumothorax/masks/9946_train_0_.png
#   inflating: /content/Pneumothorax/masks/9947_train_0_.png
#   inflating: /content/Pneumothorax/masks/9948_train_0_.png
#   inflating: /content/Pneumothorax/masks/9949_train_0_.png
#   inflating: /content/Pneumothorax/masks/994_test_0_.png
#   inflating: /content/Pneumothorax/masks/994_train_1_.png
#   inflating: /content/Pneumothorax/masks/9950_train_0_.png
#   inflating: /content/Pneumothorax/masks/9951_train_0_.png
#   inflating: /content/Pneumothorax/masks/9952_train_0_.png
#   inflating: /content/Pneumothorax/masks/9953_train_0_.png
#   inflating: /content/Pneumothorax/masks/9954_train_0_.png
#   inflating: /content/Pneumothorax/masks/9955_train_0_.png
#   inflating: /content/Pneumothorax/masks/9956_train_0_.png
#   inflating: /content/Pneumothorax/masks/9957_train_0_.png
#   inflating: /content/Pneumothorax/masks/9958_train_0_.png
#   inflating: /content/Pneumothorax/masks/9959_train_0_.png
#   inflating: /content/Pneumothorax/masks/995_test_0_.png
#   inflating: /content/Pneumothorax/masks/995_train_1_.png
#   inflating: /content/Pneumothorax/masks/9960_train_0_.png
#   inflating: /content/Pneumothorax/masks/9961_train_0_.png
#   inflating: /content/Pneumothorax/masks/9962_train_0_.png
#   inflating: /content/Pneumothorax/masks/9963_train_0_.png
#   inflating: /content/Pneumothorax/masks/9964_train_0_.png
#   inflating: /content/Pneumothorax/masks/9965_train_0_.png
#   inflating: /content/Pneumothorax/masks/9966_train_0_.png
#   inflating: /content/Pneumothorax/masks/9967_train_0_.png
#   inflating: /content/Pneumothorax/masks/9968_train_0_.png
#   inflating: /content/Pneumothorax/masks/9969_train_0_.png
#   inflating: /content/Pneumothorax/masks/996_test_0_.png
#   inflating: /content/Pneumothorax/masks/996_train_0_.png
#   inflating: /content/Pneumothorax/masks/9970_train_0_.png
#   inflating: /content/Pneumothorax/masks/9971_train_0_.png
#   inflating: /content/Pneumothorax/masks/9972_train_0_.png
#   inflating: /content/Pneumothorax/masks/9973_train_0_.png
#   inflating: /content/Pneumothorax/masks/9974_train_0_.png
#   inflating: /content/Pneumothorax/masks/9975_train_0_.png
#   inflating: /content/Pneumothorax/masks/9976_train_0_.png
#   inflating: /content/Pneumothorax/masks/9977_train_0_.png
#   inflating: /content/Pneumothorax/masks/9978_train_0_.png
#   inflating: /content/Pneumothorax/masks/9979_train_0_.png
#   inflating: /content/Pneumothorax/masks/997_test_0_.png
#   inflating: /content/Pneumothorax/masks/997_train_0_.png
#   inflating: /content/Pneumothorax/masks/9980_train_0_.png
#   inflating: /content/Pneumothorax/masks/9981_train_0_.png
#   inflating: /content/Pneumothorax/masks/9982_train_0_.png
#   inflating: /content/Pneumothorax/masks/9983_train_0_.png
#   inflating: /content/Pneumothorax/masks/9984_train_0_.png
#   inflating: /content/Pneumothorax/masks/9985_train_0_.png
#   inflating: /content/Pneumothorax/masks/9986_train_0_.png
#   inflating: /content/Pneumothorax/masks/9987_train_0_.png
#   inflating: /content/Pneumothorax/masks/9988_train_0_.png
#   inflating: /content/Pneumothorax/masks/9989_train_0_.png
#   inflating: /content/Pneumothorax/masks/998_test_0_.png
#   inflating: /content/Pneumothorax/masks/998_train_0_.png
#   inflating: /content/Pneumothorax/masks/9990_train_0_.png
#   inflating: /content/Pneumothorax/masks/9991_train_0_.png
#   inflating: /content/Pneumothorax/masks/9992_train_0_.png
#   inflating: /content/Pneumothorax/masks/9993_train_0_.png
#   inflating: /content/Pneumothorax/masks/9994_train_0_.png
#   inflating: /content/Pneumothorax/masks/9995_train_0_.png
#   inflating: /content/Pneumothorax/masks/9996_train_0_.png
#   inflating: /content/Pneumothorax/masks/9997_train_0_.png
#   inflating: /content/Pneumothorax/masks/9998_train_0_.png
#   inflating: /content/Pneumothorax/masks/9999_train_0_.png
#   inflating: /content/Pneumothorax/masks/999_test_0_.png
#   inflating: /content/Pneumothorax/masks/999_train_1_.png
#   inflating: /content/Pneumothorax/masks/99_test_1_.png
#   inflating: /content/Pneumothorax/masks/99_train_0_.png
#   inflating: /content/Pneumothorax/masks/9_test_0_.png
#   inflating: /content/Pneumothorax/masks/9_train_0_.png
#   inflating: /content/Pneumothorax/train.txt
#   inflating: /content/Pneumothorax/val.txt

# %%
import os
import random
import time
import datetime
import numpy as np
import albumentations as A
import cv2
from glob import glob
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from text2embed import Text2Embed
from utils import seeding, create_dir, print_and_save, shuffling, epoch_time, calculate_metrics, mask_to_bbox
from metrics import DiceLoss, DiceBCELoss, MultiClassBCE, FocalLoss
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import timm
import torch.nn.functional as F
import warnings
import torch.cuda.amp as amp
import torch.nn.init as init

class conv2d(nn.Module):
    def __init__(self, in_c, out_c, kernel_size=3, padding=1, dilation=1, act=True):
        super().__init__()
        self.act = act

        self.conv = nn.Sequential(
            nn.Conv2d(in_c, out_c, kernel_size, padding=padding, dilation=dilation, bias=False),
            nn.BatchNorm2d(out_c)
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        if self.act == True:
            x = self.relu(x)
        return x

class channel_attention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(channel_attention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x0 = x
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return x0 * self.sigmoid(out)


class spatial_attention(nn.Module):
    def __init__(self, kernel_size=7):
        super(spatial_attention, self).__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x0 = x
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return x0 * self.sigmoid(x)

class dilated_conv(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        self.c1 = nn.Sequential(conv2d(in_c, out_c, kernel_size=1, padding=0), channel_attention(out_c))
        self.c2 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=6, dilation=6), channel_attention(out_c))
        self.c3 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=12, dilation=12), channel_attention(out_c))
        self.c4 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=18, dilation=18), channel_attention(out_c))
        self.c5 = conv2d(out_c*4, out_c, kernel_size=3, padding=1, act=False)
        self.c6 = conv2d(in_c, out_c, kernel_size=1, padding=0, act=False)
        self.sa = spatial_attention()

    def forward(self, x):
        x1 = self.c1(x)
        x2 = self.c2(x)
        x3 = self.c3(x)
        x4 = self.c4(x)
        xc = torch.cat([x1, x2, x3, x4], axis=1)
        xc = self.c5(xc)
        xs = self.c6(x)
        x = self.relu(xc+xs)
        x = self.sa(x)
        return x

class label_attention(nn.Module):
    def __init__(self, in_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        """ Channel Attention """
        self.c1 = nn.Sequential(
            nn.Conv2d(in_c[1], in_c[0], kernel_size=1, padding=0, bias=False),
            nn.ReLU(),
            nn.Conv2d(in_c[0], in_c[0], kernel_size=1, padding=0, bias=False)
        )

    def forward(self, feats, label):
        """ Channel Attention """
        b, c = label.shape
        label = label.reshape(b, c, 1, 1)
        ch_attn = self.c1(label)
        ch_map = torch.sigmoid(ch_attn)
        feats = feats * ch_map

        ch_attn = ch_attn.reshape(ch_attn.shape[0], ch_attn.shape[1])
        return ch_attn, feats

class decoder_block(nn.Module):
    def __init__(self, in_c, out_c, scale=2):
        super().__init__()
        self.scale = scale
        self.relu = nn.ReLU(inplace=True)

        self.up = nn.Upsample(scale_factor=scale, mode="bilinear", align_corners=True)
        self.c1 = conv2d(in_c + out_c, out_c, kernel_size=1, padding=0)  # Adjust input channels
        self.c2 = conv2d(out_c, out_c, act=False)
        self.c3 = conv2d(out_c, out_c, act=False)
        self.c4 = conv2d(out_c, out_c, kernel_size=1, padding=0, act=False)
        self.ca = channel_attention(out_c)
        self.sa = spatial_attention()

    def forward(self, x, skip):
        x = self.up(x)

        # Ensure spatial dimensions match
        if x.shape[2:] != skip.shape[2:]:
            x = F.interpolate(x, size=skip.shape[2:], mode="bilinear", align_corners=True)

        x = torch.cat([x, skip], dim=1)  # Concatenate along the channel dimension
        x = self.c1(x)

        s1 = x
        x = self.c2(x)
        x = self.relu(x + s1)

        s2 = x
        x = self.c3(x)
        x = self.relu(x + s2 + s1)

        s3 = x
        x = self.c4(x)
        x = self.relu(x + s3 + s2 + s1)

        x = self.ca(x)
        x = self.sa(x)
        return x

class output_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.c1 = nn.Conv2d(in_c, out_c, kernel_size=1, padding=0)

    def forward(self, x):
        x = self.up(x)
        x = self.c1(x)
        return x

class text_classifier(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Sequential(
            nn.Linear(in_c, in_c//8, bias=False), nn.ReLU(),
            nn.Linear(in_c//8, out_c[0], bias=False)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(in_c, in_c//8, bias=False), nn.ReLU(),
            nn.Linear(in_c//8, out_c[1], bias=False)
        )

    def forward(self, feats):
        pool = self.avg_pool(feats).view(feats.shape[0], feats.shape[1])
        num_lesions = self.fc1(pool)
        lesion_sizes = self.fc2(pool)
        # print(f"num_lesions shape: {num_lesions.shape}")
        # print(f"lesion_sizes shape: {lesion_sizes.shape}")
        return num_lesions, lesion_sizes

class embedding_feature_fusion(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.fc = nn.Sequential(
            nn.Conv2d((in_c[0]+in_c[1])*in_c[2], out_c, 1, bias=False), nn.ReLU(),
            nn.Conv2d(out_c, out_c, 1, bias=False), nn.ReLU()
        )

    def forward(self, num_lesions, lesion_sizes, label):
        # print(f"num_lesions shape: {num_lesions.shape}")
        # print(f"lesion_sizes shape: {lesion_sizes.shape}")
        num_lesions_prob = torch.softmax(num_lesions, axis=1)
        lesion_sizes_prob = torch.softmax(lesion_sizes, axis=1)
        # print(f"num_lesions_classes", num_lesions_prob.shape)
        # print(f"lesions_size_classes", lesion_sizes_prob.shape)
        prob = torch.cat([num_lesions_prob, lesion_sizes_prob], axis=1)
        # print(f"prob shape: {prob.shape}")
        prob = prob.view(prob.shape[0], prob.shape[1], 1)
        if label.shape[1] != prob.shape[1]:
          raise ValueError(
              f"Shape mismatch: label channels ({label.shape[1]}) != prob channels ({prob.shape[1]})"
          )
        # print(f"x shape before fc: {x.shape}")
        x = label * prob
        x = x.view(x.shape[0], -1, 1, 1)
        if x.shape[1] != 1800:
            # x = torch.nn.functional.adaptive_avg_pool2d(x, (1, 1))  # Adjust spatial dimensions
            device = x.device  # Get the device of the input tensor
            conv_layer = torch.nn.Conv2d(x.shape[1], 1800, kernel_size=1).to(device)
            x = conv_layer(x)

        # print(f"x shape after fc: {x.shape}")
        x = self.fc(x)
        x = x.view(x.shape[0], -1)
        return x

class multiscale_feature_aggregation(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        self.up_2x2 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.up_4x4 = nn.Upsample(scale_factor=4, mode="bilinear", align_corners=True)
        self.up_8x8 = nn.Upsample(scale_factor=8, mode="bilinear", align_corners=True)  # Add upsampling for layer4 features

        self.c11 = conv2d(in_c[0], out_c, kernel_size=1, padding=0)
        self.c12 = conv2d(in_c[1], out_c, kernel_size=1, padding=0)
        self.c13 = conv2d(in_c[2], out_c, kernel_size=1, padding=0)
        self.c14 = conv2d(in_c[3], out_c, kernel_size=1, padding=0)  # Add for layer4 features
        self.c15 = conv2d(out_c * 4, out_c, kernel_size=1, padding=0)  # Update to handle 4 inputs

        self.c2 = conv2d(out_c, out_c, act=False)
        self.c3 = conv2d(out_c, out_c, act=False)

    def forward(self, x1, x2, x3, x4):  # Add x4 for layer4 features
        # Upsample all feature maps to the same spatial resolution (128x128)
        x1 = self.up_8x8(x1)  # Upsample x1 (from layer4) by 8x
        x2 = self.up_4x4(x2)  # Upsample x2 (from layer3) by 4x
        x3 = self.up_2x2(x3)  # Upsample x3 (from layer2) by 2x
        x4 = F.interpolate(x4, size=(128, 128), mode="bilinear", align_corners=True)  # Upsample x4 (from layer1) to 128x128

        x1 = self.c11(x1)
        x2 = self.c12(x2)
        x3 = self.c13(x3)
        x4 = self.c14(x4)  # Process x4

        x = torch.cat([x1, x2, x3, x4], dim=1)  # Concatenate all 4 inputs
        x = self.c15(x)

        s1 = x
        x = self.c2(x)
        x = self.relu(x + s1)

        s2 = x
        x = self.c3(x)
        x = self.relu(x + s2 + s1)

        return x

class ProgressiveDenoisingAttention1(nn.Module):
    def __init__(self, channels, num_iterations=3):
        super(ProgressiveDenoisingAttention1, self).__init__()
        self.num_iterations = num_iterations
        self.channels = channels

        # Convolution layers for refining attention
        self.conv_layers = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(channels, channels, kernel_size=3, padding=1, bias=False),
                nn.BatchNorm2d(channels),
                nn.ReLU(inplace=True)
            ) for _ in range(num_iterations)
        ])

        # Final attention map generation
        self.final_conv = nn.Conv2d(channels, 1, kernel_size=1, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # Initial attention map
        attention_map = x

        # Progressive denoising
        for conv in self.conv_layers:
            attention_map = conv(attention_map)

        # Final attention map
        attention_map = self.final_conv(attention_map)
        attention_map = self.sigmoid(attention_map)

        # Apply attention to input features
        return x * attention_map

class UNetDenoise(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.Conv2d(64, out_channels, kernel_size=3, padding=1),
            nn.ReLU(),
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

class TGAlesionSeg(nn.Module):
    def __init__(self):
        super().__init__()

        """ Backbone: SE-ResNeXt50 """
        backbone = timm.create_model('seresnext50_32x4d', pretrained=True)

        # Extract the layers from the backbone
        self.layer0 = nn.Sequential(
            backbone.conv1,
            backbone.bn1,
            backbone.act1,
            backbone.maxpool
        )
        self.layer1 = backbone.layer1
        self.layer2 = backbone.layer2
        self.layer3 = backbone.layer3
        self.layer4 = backbone.layer4  # Add layer4

        self.text_classifier = text_classifier(2048, [3, 3])  # Update input channels to 2048 for layer4
        self.label_fc = embedding_feature_fusion([3, 3, 300], 128)

        """ Dilated Conv """
        self.s1 = dilated_conv(64, 128)  # Input channels: 64 (from layer0)
        self.s2 = dilated_conv(256, 128)  # Input channels: 256 (from layer1)
        self.s3 = dilated_conv(512, 128)  # Input channels: 512 (from layer2)
        self.s4 = dilated_conv(1024, 128)  # Input channels: 1024 (from layer3)
        self.s5 = dilated_conv(2048, 128)  # Input channels: 2048 (from layer4)

        """ Progressive Denoising Attention """
        self.pda1 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda2 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda3 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda4 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda5 = ProgressiveDenoisingAttention1(128, num_iterations=3)  # Add PDA for layer4 features

        """ U-Net Denoising Modules """
        self.denoise1 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise2 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise3 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise4 = UNetDenoise(in_channels=128, out_channels=128)  # Add denoising for layer4 features

        """ Decoder """
        self.d1 = decoder_block(128, 128, scale=2)
        self.a1 = label_attention([128, 128])

        self.d2 = decoder_block(128, 128, scale=2)
        self.a2 = label_attention([128, 128])

        self.d3 = decoder_block(128, 128, scale=2)
        self.a3 = label_attention([128, 128])

        self.d4 = decoder_block(128, 128, scale=2)  # Add decoder block for layer4 features
        self.a4 = label_attention([128, 128])

        self.ag = multiscale_feature_aggregation([128, 128, 128, 128], 128)  # Update to include layer4 features

        self.y1 = output_block(128, 1)

    def forward(self, image, label):
        """ Backbone: SE-ResNeXt50 """
        x0 = image
        x1 = self.layer0(x0)    ## [-1, 64, h/2, w/2]
        x2 = self.layer1(x1)    ## [-1, 256, h/4, w/4]
        x3 = self.layer2(x2)    ## [-1, 512, h/8, w/8]
        x4 = self.layer3(x3)    ## [-1, 1024, h/16, w/16]
        x5 = self.layer4(x4)    ## [-1, 2048, h/32, w/32]  # Add layer4 output

        num_lesions, lesion_sizes = self.text_classifier(x5)  # Use x5 (layer4 features)
        f0 = self.label_fc(num_lesions, lesion_sizes, label)

        """ Dilated Conv + PDA """
        s1 = self.pda1(self.s1(x1))
        s2 = self.pda2(self.s2(x2))
        s3 = self.pda3(self.s3(x3))
        s4 = self.pda4(self.s4(x4))
        s5 = self.pda5(self.s5(x5))  # Add PDA for layer4 features

        """ Decoder + Denoising """
        # Stage 1
        d1 = self.d1(s5, s4)  # Use s5 (layer4 features) as input to the first decoder block
        f1, a1 = self.a1(d1, f0)
        a1_denoised = self.denoise1(a1)

        # Stage 2
        d2 = self.d2(a1_denoised, s3)
        f = f0 + f1
        f2, a2 = self.a2(d2, f)
        a2_denoised = self.denoise2(a2)

        # Stage 3
        d3 = self.d3(a2_denoised, s2)
        f = f0 + f1 + f2
        f3, a3 = self.a3(d3, f)
        a3_denoised = self.denoise3(a3)

        # Stage 4
        d4 = self.d4(a3_denoised, s1)
        f = f0 + f1 + f2 + f3
        f4, a4 = self.a4(d4, f)
        a4_denoised = self.denoise4(a4)

        ag = self.ag(a1_denoised, a2_denoised, a3_denoised, a4_denoised)  # Include layer4 features
        y1 = self.y1(ag)

        return y1, num_lesions, lesion_sizes
def prepare_input(res):
    x1 = torch.FloatTensor(1, 3, 256, 256).cuda()
    x2 = torch.FloatTensor(1, 5, 300).cuda()
    return dict(x = [x1, x2])

### --------------------------------------------------------------------------------------------------------------------------------------------------------

def load_names(path, file_path):
    f = open(file_path, "r")
    data = f.read().split("\n")[:-1]
    images = [os.path.join(path,"images", name) + ".png" for name in data]
    masks = [os.path.join(path,"masks", name) + ".png" for name in data]
    return images, masks

def label_dictionary():
    label_dict = {}
    label_dict["lesion"] = ["zero", "one", "multiple", "small", "medium", "large"]
    return label_dict

def load_data(path):
    train_names_path = f"{path}/train.txt"
    valid_names_path = f"{path}/val.txt"

    train_x, train_y = load_names(path, train_names_path)
    valid_x, valid_y = load_names(path, valid_names_path)

    label_dict = label_dictionary()
    print(label_dict)
    train_label = len(train_x) * [label_dict["lesion"]]
    valid_label = len(valid_x) * [label_dict["lesion"]]

    return (train_x, train_y, train_label), (valid_x, valid_y, valid_label)

class DATASET(Dataset):
    def __init__(self, images_path, labels_path, masks_path, size, transform=None):
        super().__init__()
        self.images_path = images_path
        self.labels_path = labels_path
        self.masks_path = masks_path
        self.size = size  # Ensure size is stored as an instance attribute
        self.transform = transform
        self.n_samples = len(images_path)

        self.embed = Text2Embed()

    def visualize_bbox_on_mask(self, image, mask, bboxes, title="Mask with BBoxes"):
        """Visualize the mask and bounding boxes overlaid on the mask."""
        if len(image.shape) != 3 or image.shape[2] != 3:
            raise ValueError(f"Expected a color image with 3 channels, but got shape {image.shape}")

        fig, ax = plt.subplots(1, 2, figsize=(12, 6))

        # Show original image
        ax[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        ax[0].set_title("Original Image")
        ax[0].axis("off")

        # Show mask with bounding boxes
        mask_with_bbox = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
        for bbox in bboxes:
            x1, y1, x2, y2 = bbox
            mask_with_bbox = cv2.rectangle(mask_with_bbox, (x1, y1), (x2, y2), (255, 0, 0), 2)

        ax[1].imshow(cv2.cvtColor(mask_with_bbox, cv2.COLOR_BGR2RGB))
        ax[1].set_title(title)
        ax[1].axis("off")

        plt.tight_layout()
        plt.show()


    def mask_to_text(self, mask, image=None):
        bboxes = mask_to_bbox(mask)
        lesion_sizes = 0
        num_lesions = 0

        # Calculate sizes and number of lesions
        for bbox in bboxes:
            x1, y1, x2, y2 = bbox
            h = (y2 - y1)
            w = (x2 - x1)
            area = (h * w) / (mask.shape[0] * mask.shape[1])

            if area < 0.007:
                lesion_sizes = 0
            elif 0.007 <= area < 0.04:
                lesion_sizes = 1
            elif area >= 0.04:
                lesion_sizes = 2

        if(len(bboxes) == 0):
          num_lesions = 0
        elif(len(bboxes) == 1):
          num_lesions = 1
        elif(len(bboxes) >= 2):
          num_lesions = 2

        # visualization
        if image is None:
            self.visualize_bbox_on_mask(image, mask, bboxes, title="Mask with Bounding Boxes")

        return np.array(num_lesions), np.array(lesion_sizes)


    def __getitem__(self, index):
      image = cv2.imread(self.images_path[index], cv2.IMREAD_COLOR)
      mask = cv2.imread(self.masks_path[index], cv2.IMREAD_GRAYSCALE)

      if image is None or mask is None:
          raise FileNotFoundError(f"Could not read image or mask at index {index}. Check the file paths.")

      if self.transform is not None:
          augmentations = self.transform(image=image, mask=mask)
          image = augmentations["image"]
          mask = augmentations["mask"]

      image = cv2.resize(image, self.size)
      if len(image.shape) != 3 or image.shape[2] != 3:
          raise ValueError(f"Expected a color image with 3 channels after resizing, but got shape {image.shape}")

      image = np.transpose(image, (2, 0, 1))
      image = image / 255.0

      mask = cv2.resize(mask, self.size)
      mask_copy = mask
      mask = np.expand_dims(mask, axis=0)
      mask = mask / 255.0

      visual_image = (image.transpose(1, 2, 0) * 255).astype(np.uint8)
      num_lesions, lesion_sizes = self.mask_to_text(mask_copy, visual_image)

      label = []
      words = self.labels_path[index]
      for word in words:
          word_embed = self.embed.to_embed(word)[0]
          label.append(word_embed)
      label = np.array(label)
      return (image, label), (mask, num_lesions, lesion_sizes)

    def __len__(self):
        return self.n_samples


def train(model, loader, optimizer, loss_fn, device):
    model.train()
    epoch_loss = 0.0
    epoch_jac = 0.0
    epoch_f1 = 0.0
    epoch_recall = 0.0
    epoch_precision = 0.0
    # scaler = amp.GradScaler()  # Define scaler before training

    for i, ((x, l), (y1, y2, y3)) in enumerate(loader):
        x = x.to(device, dtype=torch.float32)
        l = l.to(device, dtype=torch.float32)
        y1 = y1.to(device, dtype=torch.float32)
        y2 = y2.to(device, dtype=torch.long)
        y3 = y3.to(device, dtype=torch.long)


        optimizer.zero_grad()

        p1, p2, p3 = model(x, l)
        p2 = torch.softmax(p2, dim=1)
        p3 = torch.softmax(p3, dim=1)

        loss1 = loss_fn[0](p1, y1)
        loss2 = loss_fn[1](p2, y2)
        loss3 = loss_fn[2](p3, y3)

        loss = loss1 + loss2 + loss3

        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

        batch_jac = []
        batch_f1 = []
        batch_recall = []
        batch_precision = []

        for yt, yp in zip(y1, p1):
            score = calculate_metrics(yt, yp)
            batch_jac.append(score[0])
            batch_f1.append(score[1])
            batch_recall.append(score[2])
            batch_precision.append(score[3])

        epoch_jac += np.mean(batch_jac)
        epoch_f1 += np.mean(batch_f1)
        epoch_recall += np.mean(batch_recall)
        epoch_precision += np.mean(batch_precision)

    epoch_loss = epoch_loss / len(loader)
    epoch_jac = epoch_jac / len(loader)
    epoch_f1 = epoch_f1 / len(loader)
    epoch_recall = epoch_recall / len(loader)
    epoch_precision = epoch_precision / len(loader)

    return epoch_loss, [epoch_jac, epoch_f1, epoch_recall, epoch_precision]

def evaluate(model, loader, loss_fn, device):
    model.eval()

    epoch_loss = 0.0
    epoch_jac = 0.0
    epoch_f1 = 0.0
    epoch_recall = 0.0
    epoch_precision = 0.0

    with torch.no_grad():
        for i, ((x, l), (y1, y2, y3)) in enumerate(loader):
            x = x.to(device, dtype=torch.float32)
            l = l.to(device, dtype=torch.float32)
            y1 = y1.to(device, dtype=torch.float32)
            y2 = y2.to(device, dtype=torch.long)
            y3 = y3.to(device, dtype=torch.long)

            p1, p2, p3 = model(x, l)
            p2 = torch.softmax(p2, dim=1)
            p3 = torch.softmax(p3, dim=1)

            loss1 = loss_fn[0](p1, y1)
            loss2 = loss_fn[1](p2, y2)
            loss3 = loss_fn[2](p3, y3)

            loss = loss1 + loss2 + loss3

            epoch_loss += loss.item()

            batch_jac = []
            batch_f1 = []
            batch_recall = []
            batch_precision = []

            for yt, yp in zip(y1, p1):
                score = calculate_metrics(yt, yp)
                batch_jac.append(score[0])
                batch_f1.append(score[1])
                batch_recall.append(score[2])
                batch_precision.append(score[3])

            epoch_jac += np.mean(batch_jac)
            epoch_f1 += np.mean(batch_f1)
            epoch_recall += np.mean(batch_recall)
            epoch_precision += np.mean(batch_precision)

    epoch_loss = epoch_loss / len(loader)
    epoch_jac = epoch_jac / len(loader)
    epoch_f1 = epoch_f1 / len(loader)
    epoch_recall = epoch_recall / len(loader)
    epoch_precision = epoch_precision / len(loader)

    return epoch_loss, [epoch_jac, epoch_f1, epoch_recall, epoch_precision]

if __name__ == "__main__":
    """ Seeding """
    seeding(42)

    """ Directories """
    create_dir("files")

    """ Training logfile """
    train_log_path = "files/train_log.txt"
    if os.path.exists(train_log_path):
        print("Log file exists")
    else:
        train_log = open("files/train_log.txt", "w")
        train_log.write("\n")
        train_log.close()

    """ Record Date & Time """
    datetime_object = str(datetime.datetime.now())
    print_and_save(train_log_path, datetime_object)
    print("")

    """ Hyperparameters """
    image_size = 256
    size = (image_size, image_size)
    batch_size = 16
    num_epochs = 70
    lr = 1e-5
    early_stopping_patience = 70
    checkpoint_path = "/content/checkpoint1 (15) (2).pth"
    path = "/content/Pneumothorax"

    data_str = f"Image Size: {size}\nBatch Size: {batch_size}\nLR: {lr}\nEpochs: {num_epochs}\n"
    data_str += f"Early Stopping Patience: {early_stopping_patience}\n"
    print_and_save(train_log_path, data_str)

    """ Data augmentation: Transforms """
    transform = A.Compose([
        A.Rotate(limit=15, p=0.5),  # Moderate rotations
        A.HorizontalFlip(p=0.5),    # Horizontal flipping
        A.VerticalFlip(p=0.2),      # Vertical flipping
        A.RandomBrightnessContrast(p=0.3),  # Adjust brightness and contrast
        A.CLAHE(p=0.3),  # Contrast Limited Adaptive Histogram Equalization
        A.ElasticTransform(alpha=1, sigma=50, p=0.3),  # Elastic transformations
        A.CoarseDropout(num_holes_range=(2, 5), hole_height_range=(5, 20), hole_width_range=(5, 20), fill="inpaint_ns", p=0.5)  # Coarse dropout
    ])

    """ Dataset """
    (train_x, train_y, train_label), (valid_x, valid_y, valid_label) = load_data(path)
    train_x, train_y, train_label = shuffling(train_x, train_y, train_label)
    data_str = f"Dataset Size:\nTrain: {len(train_x)} - Valid: {len(valid_x)}\n"
    print_and_save(train_log_path, data_str)

    """ Dataset and loader """
    train_dataset = DATASET(train_x, train_label, train_y, (image_size, image_size), transform=transform)
    valid_dataset = DATASET(valid_x, valid_label, valid_y, (image_size, image_size), transform=None)

    train_loader = DataLoader(
        dataset=train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4
    )

    valid_loader = DataLoader(
        dataset=valid_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4
    )

    """ Model """
    device = torch.device('cuda')
    model = TGAlesionSeg()
    model = model.to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6)
    # loss_fn = [DiceBCELoss(), nn.CrossEntropyLoss(), nn.CrossEntropyLoss()]
    # Using Focal Loss for num_lesions & lesion_sizes
    loss_fn = [DiceBCELoss(), FocalLoss(alpha=0.25, gamma=2), FocalLoss(alpha=0.25, gamma=2)]

    loss_name = "BCE Dice Loss"
    data_str = f"Optimizer: AdamW\nLoss: {loss_name}\n"
    print_and_save(train_log_path, data_str)


    try:
        model.load_state_dict(torch.load(checkpoint_path))
        print(f"Checkpoint loaded successfully from {checkpoint_path}. Resuming training.")
    except Exception as e:
        print(f"Error loading checkpoint: {e}")

    """ Training the model """
    best_valid_metrics = 0.835  ## update the last metric you have accordingly
    early_stopping_count = 0

    # Logging
    data_str = f"Resuming training from checkpoint.\nOptimizer: Adam\nLoss: {loss_name}\n"
    print_and_save(train_log_path, data_str)

    # Resume training
    for epoch in range(num_epochs):  # Update resume_epoch appropriately
        start_time = time.time()

        train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn, device)
        valid_loss, valid_metrics = evaluate(model, valid_loader, loss_fn, device)
        scheduler.step(valid_loss)

        if valid_metrics[1] > best_valid_metrics:
            data_str = f"Valid F1 improved from {best_valid_metrics:2.4f} to {valid_metrics[1]:2.4f}. Saving checkpoint: {checkpoint_path}"
            print_and_save(train_log_path, data_str)

            best_valid_metrics = valid_metrics[1]
            torch.save(model.state_dict(), checkpoint_path)
            early_stopping_count = 0

        elif valid_metrics[1] < best_valid_metrics:
            early_stopping_count += 1

        end_time = time.time()
        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        data_str = f"Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s\n"
        data_str += f"\tTrain Loss: {train_loss:.4f} - Jaccard: {train_metrics[0]:.4f} - F1: {train_metrics[1]:.4f} - Recall: {train_metrics[2]:.4f} - Precision: {train_metrics[3]:.4f}\n"
        data_str += f"\t Val. Loss: {valid_loss:.4f} - Jaccard: {valid_metrics[0]:.4f} - F1: {valid_metrics[1]:.4f} - Recall: {valid_metrics[2]:.4f} - Precision: {valid_metrics[3]:.4f}\n"
        print_and_save(train_log_path, data_str)

        if early_stopping_count == early_stopping_patience:
            data_str = f"Early stopping: validation loss stops improving from last {early_stopping_patience} continuously.\n"
            print_and_save(train_log_path, data_str)
            break
# Out:
# Log file exists
# 2025-03-06 23:02:06.232472
#
# Image Size: (256, 256)
# Batch Size: 16
# LR: 1e-05
# Epochs: 70
# Early Stopping Patience: 70
#
# {'polyp': ['zero', 'one', 'multiple', 'small', 'medium', 'large']}
# Dataset Size:
# Train: 9636 - Valid: 2409
#
# Optimizer: AdamW
# Loss: BCE Dice Loss
# <ipython-input-4-84eaf6b8801a>:815: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path))
# Checkpoint loaded successfully from /content/checkpoint1 (15) (2).pth. Resuming training.
# Resuming training from checkpoint.
# Optimizer: Adam
# Loss: BCE Dice Loss
#
# Epoch: 01 | Epoch Time: 8m 50s
# 	Train Loss: 0.4883 - Jaccard: 0.8447 - F1: 0.8664 - Recall: 0.8889 - Precision: 0.9324
# 	 Val. Loss: 0.6643 - Jaccard: 0.8131 - F1: 0.8317 - Recall: 0.8672 - Precision: 0.9194
#
# Epoch: 02 | Epoch Time: 8m 51s
# 	Train Loss: 0.5006 - Jaccard: 0.8404 - F1: 0.8625 - Recall: 0.8890 - Precision: 0.9268
# 	 Val. Loss: 0.6414 - Jaccard: 0.8127 - F1: 0.8323 - Recall: 0.8754 - Precision: 0.9108
#
# Epoch: 03 | Epoch Time: 8m 51s
# 	Train Loss: 0.4855 - Jaccard: 0.8445 - F1: 0.8669 - Recall: 0.8918 - Precision: 0.9279
# 	 Val. Loss: 0.6360 - Jaccard: 0.8099 - F1: 0.8298 - Recall: 0.8769 - Precision: 0.9037
#
# Epoch: 04 | Epoch Time: 8m 51s
# 	Train Loss: 0.4897 - Jaccard: 0.8448 - F1: 0.8662 - Recall: 0.8871 - Precision: 0.9350
# 	 Val. Loss: 0.6498 - Jaccard: 0.8112 - F1: 0.8303 - Recall: 0.8741 - Precision: 0.9106
#
# Epoch: 05 | Epoch Time: 8m 51s
# 	Train Loss: 0.4878 - Jaccard: 0.8438 - F1: 0.8657 - Recall: 0.8904 - Precision: 0.9302
# 	 Val. Loss: 0.6419 - Jaccard: 0.8083 - F1: 0.8280 - Recall: 0.8755 - Precision: 0.9045
#
# Epoch: 06 | Epoch Time: 8m 51s
# 	Train Loss: 0.4892 - Jaccard: 0.8427 - F1: 0.8649 - Recall: 0.8895 - Precision: 0.9275
# 	 Val. Loss: 0.6672 - Jaccard: 0.8164 - F1: 0.8339 - Recall: 0.8648 - Precision: 0.9280
#
# Epoch: 07 | Epoch Time: 8m 51s
# 	Train Loss: 0.4810 - Jaccard: 0.8481 - F1: 0.8696 - Recall: 0.8878 - Precision: 0.9378
# 	 Val. Loss: 0.6628 - Jaccard: 0.8162 - F1: 0.8341 - Recall: 0.8654 - Precision: 0.9268
#
# Epoch: 08 | Epoch Time: 8m 51s
# 	Train Loss: 0.4703 - Jaccard: 0.8501 - F1: 0.8711 - Recall: 0.8873 - Precision: 0.9421
# 	 Val. Loss: 0.6519 - Jaccard: 0.8136 - F1: 0.8325 - Recall: 0.8720 - Precision: 0.9163
#
# Epoch: 09 | Epoch Time: 8m 51s
# 	Train Loss: 0.4880 - Jaccard: 0.8488 - F1: 0.8699 - Recall: 0.8876 - Precision: 0.9392
# 	 Val. Loss: 0.6498 - Jaccard: 0.8106 - F1: 0.8299 - Recall: 0.8754 - Precision: 0.9079
#
# Epoch: 10 | Epoch Time: 8m 51s
# 	Train Loss: 0.4755 - Jaccard: 0.8503 - F1: 0.8718 - Recall: 0.8902 - Precision: 0.9384
# 	 Val. Loss: 0.6582 - Jaccard: 0.8138 - F1: 0.8321 - Recall: 0.8671 - Precision: 0.9219
#
# Epoch: 11 | Epoch Time: 8m 51s
# 	Train Loss: 0.4787 - Jaccard: 0.8510 - F1: 0.8729 - Recall: 0.8918 - Precision: 0.9366
# 	 Val. Loss: 0.6491 - Jaccard: 0.8123 - F1: 0.8316 - Recall: 0.8746 - Precision: 0.9114
#
# Epoch: 12 | Epoch Time: 8m 51s
# 	Train Loss: 0.4773 - Jaccard: 0.8488 - F1: 0.8703 - Recall: 0.8897 - Precision: 0.9365
# 	 Val. Loss: 0.6536 - Jaccard: 0.8139 - F1: 0.8328 - Recall: 0.8689 - Precision: 0.9202
#
# Epoch: 13 | Epoch Time: 8m 51s
# 	Train Loss: 0.4816 - Jaccard: 0.8492 - F1: 0.8711 - Recall: 0.8920 - Precision: 0.9340
# 	 Val. Loss: 0.6494 - Jaccard: 0.8118 - F1: 0.8312 - Recall: 0.8735 - Precision: 0.9127
#
# Epoch: 14 | Epoch Time: 8m 51s
# 	Train Loss: 0.4785 - Jaccard: 0.8502 - F1: 0.8723 - Recall: 0.8914 - Precision: 0.9360
# 	 Val. Loss: 0.6538 - Jaccard: 0.8149 - F1: 0.8337 - Recall: 0.8709 - Precision: 0.9181
#
# Epoch: 15 | Epoch Time: 8m 51s
# 	Train Loss: 0.4700 - Jaccard: 0.8504 - F1: 0.8722 - Recall: 0.8923 - Precision: 0.9342
# 	 Val. Loss: 0.6505 - Jaccard: 0.8114 - F1: 0.8306 - Recall: 0.8727 - Precision: 0.9130
#
# Epoch: 16 | Epoch Time: 8m 51s
# 	Train Loss: 0.4842 - Jaccard: 0.8483 - F1: 0.8702 - Recall: 0.8918 - Precision: 0.9346
# 	 Val. Loss: 0.6507 - Jaccard: 0.8125 - F1: 0.8318 - Recall: 0.8731 - Precision: 0.9133
#
# Epoch: 17 | Epoch Time: 8m 51s
# 	Train Loss: 0.4922 - Jaccard: 0.8478 - F1: 0.8696 - Recall: 0.8913 - Precision: 0.9336
# 	 Val. Loss: 0.6487 - Jaccard: 0.8099 - F1: 0.8295 - Recall: 0.8760 - Precision: 0.9066
#
# Epoch: 18 | Epoch Time: 8m 51s
# 	Train Loss: 0.4837 - Jaccard: 0.8493 - F1: 0.8713 - Recall: 0.8925 - Precision: 0.9344
# 	 Val. Loss: 0.6516 - Jaccard: 0.8138 - F1: 0.8327 - Recall: 0.8724 - Precision: 0.9160
#
# Epoch: 19 | Epoch Time: 8m 51s
# 	Train Loss: 0.4803 - Jaccard: 0.8499 - F1: 0.8716 - Recall: 0.8916 - Precision: 0.9369
# 	 Val. Loss: 0.6507 - Jaccard: 0.8099 - F1: 0.8293 - Recall: 0.8743 - Precision: 0.9086
#
# Epoch: 20 | Epoch Time: 8m 51s
# 	Train Loss: 0.4799 - Jaccard: 0.8503 - F1: 0.8717 - Recall: 0.8903 - Precision: 0.9377
# 	 Val. Loss: 0.6498 - Jaccard: 0.8107 - F1: 0.8298 - Recall: 0.8725 - Precision: 0.9109
#
# Epoch: 21 | Epoch Time: 8m 51s
# 	Train Loss: 0.4810 - Jaccard: 0.8495 - F1: 0.8714 - Recall: 0.8920 - Precision: 0.9348
# 	 Val. Loss: 0.6497 - Jaccard: 0.8111 - F1: 0.8304 - Recall: 0.8733 - Precision: 0.9115
#
# Epoch: 22 | Epoch Time: 8m 51s
# 	Train Loss: 0.4775 - Jaccard: 0.8497 - F1: 0.8718 - Recall: 0.8932 - Precision: 0.9342
# 	 Val. Loss: 0.6509 - Jaccard: 0.8097 - F1: 0.8291 - Recall: 0.8742 - Precision: 0.9097
#
# Epoch: 23 | Epoch Time: 8m 51s
# 	Train Loss: 0.4694 - Jaccard: 0.8488 - F1: 0.8705 - Recall: 0.8923 - Precision: 0.9341
# 	 Val. Loss: 0.6462 - Jaccard: 0.8106 - F1: 0.8302 - Recall: 0.8756 - Precision: 0.9077
#
# Epoch: 24 | Epoch Time: 8m 51s
# 	Train Loss: 0.4852 - Jaccard: 0.8481 - F1: 0.8701 - Recall: 0.8903 - Precision: 0.9343
# 	 Val. Loss: 0.6499 - Jaccard: 0.8140 - F1: 0.8330 - Recall: 0.8722 - Precision: 0.9157
#
# Epoch: 25 | Epoch Time: 8m 51s
# 	Train Loss: 0.4706 - Jaccard: 0.8504 - F1: 0.8723 - Recall: 0.8918 - Precision: 0.9373
# 	 Val. Loss: 0.6533 - Jaccard: 0.8128 - F1: 0.8317 - Recall: 0.8703 - Precision: 0.9165
#
# Epoch: 26 | Epoch Time: 8m 51s
# 	Train Loss: 0.4882 - Jaccard: 0.8493 - F1: 0.8713 - Recall: 0.8922 - Precision: 0.9336
# 	 Val. Loss: 0.6446 - Jaccard: 0.8106 - F1: 0.8303 - Recall: 0.8792 - Precision: 0.9048
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-84eaf6b8801a> in <cell line: 0>()
#     830         start_time = time.time()
#     831
# --> 832         train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn, device)
#     833         valid_loss, valid_metrics = evaluate(model, valid_loader, loss_fn, device)
#     834         scheduler.step(valid_loss)
#
# <ipython-input-4-84eaf6b8801a> in train(model, loader, optimizer, loss_fn, device)
#     644         loss.backward()
#     645         optimizer.step()
# --> 646         epoch_loss += loss.item()
#     647
#     648         batch_jac = []
#
# KeyboardInterrupt:

# %%
# Log file exists
# 2025-03-04 18:49:08.021780

# Image Size: (256, 256)
# Batch Size: 16
# LR: 0.0001
# Epochs: 70
# Early Stopping Patience: 50

# {'lesion': ['zero', 'one', 'multiple', 'small', 'medium', 'large']}
# Dataset Size:
# Train: 9636 - Valid: 2409

# Optimizer: AdamW
# Loss: BCE Dice Loss

# Valid F1 improved from 0.0000 to 0.7648. Saving checkpoint: files/checkpoint1.pth
# Epoch: 01 | Epoch Time: 8m 50s
# 	Train Loss: 1.0457 - Jaccard: 0.6437 - F1: 0.6527 - Recall: 0.8131 - Precision: 0.7769
# 	 Val. Loss: 0.8658 - Jaccard: 0.7490 - F1: 0.7648 - Recall: 0.8488 - Precision: 0.8517

# Epoch: 02 | Epoch Time: 8m 48s
# 	Train Loss: 0.8626 - Jaccard: 0.7035 - F1: 0.7201 - Recall: 0.8435 - Precision: 0.8104
# 	 Val. Loss: 0.8967 - Jaccard: 0.6419 - F1: 0.6620 - Recall: 0.8943 - Precision: 0.6917

# Valid F1 improved from 0.7648 to 0.8106. Saving checkpoint: files/checkpoint1.pth
# Epoch: 03 | Epoch Time: 8m 49s
# 	Train Loss: 0.8022 - Jaccard: 0.7359 - F1: 0.7533 - Recall: 0.8493 - Precision: 0.8432
# 	 Val. Loss: 0.8014 - Jaccard: 0.7962 - F1: 0.8106 - Recall: 0.8408 - Precision: 0.9285

# Epoch: 04 | Epoch Time: 8m 48s
# 	Train Loss: 0.7560 - Jaccard: 0.7466 - F1: 0.7654 - Recall: 0.8551 - Precision: 0.8493
# 	 Val. Loss: 0.7356 - Jaccard: 0.7814 - F1: 0.7991 - Recall: 0.8614 - Precision: 0.8833

# Epoch: 05 | Epoch Time: 8m 49s
# 	Train Loss: 0.7527 - Jaccard: 0.7381 - F1: 0.7572 - Recall: 0.8558 - Precision: 0.8392
# 	 Val. Loss: 0.7579 - Jaccard: 0.7933 - F1: 0.8092 - Recall: 0.8484 - Precision: 0.9162

# Epoch: 06 | Epoch Time: 8m 49s
# 	Train Loss: 0.7210 - Jaccard: 0.7614 - F1: 0.7803 - Recall: 0.8575 - Precision: 0.8654
# 	 Val. Loss: 0.7591 - Jaccard: 0.6885 - F1: 0.7118 - Recall: 0.8953 - Precision: 0.7447

# Valid F1 improved from 0.8106 to 0.8183. Saving checkpoint: files/checkpoint1.pth
# Epoch: 07 | Epoch Time: 8m 49s
# 	Train Loss: 0.7110 - Jaccard: 0.7655 - F1: 0.7850 - Recall: 0.8612 - Precision: 0.8664
# 	 Val. Loss: 0.7249 - Jaccard: 0.8005 - F1: 0.8183 - Recall: 0.8634 - Precision: 0.9092

# Epoch: 08 | Epoch Time: 8m 49s
# 	Train Loss: 0.6799 - Jaccard: 0.7759 - F1: 0.7956 - Recall: 0.8641 - Precision: 0.8752
# 	 Val. Loss: 0.7066 - Jaccard: 0.7976 - F1: 0.8161 - Recall: 0.8668 - Precision: 0.9013

# Epoch: 09 | Epoch Time: 8m 48s
# 	Train Loss: 0.6758 - Jaccard: 0.7760 - F1: 0.7960 - Recall: 0.8651 - Precision: 0.8759
# 	 Val. Loss: 0.6908 - Jaccard: 0.7829 - F1: 0.8029 - Recall: 0.8730 - Precision: 0.8731

# Epoch: 10 | Epoch Time: 8m 49s
# 	Train Loss: 0.6796 - Jaccard: 0.7723 - F1: 0.7918 - Recall: 0.8624 - Precision: 0.8743
# 	 Val. Loss: 0.6963 - Jaccard: 0.7930 - F1: 0.8129 - Recall: 0.8746 - Precision: 0.8827

# Valid F1 improved from 0.8183 to 0.8188. Saving checkpoint: files/checkpoint1.pth
# Epoch: 11 | Epoch Time: 8m 49s
# 	Train Loss: 0.6454 - Jaccard: 0.7916 - F1: 0.8113 - Recall: 0.8659 - Precision: 0.8934
# 	 Val. Loss: 0.6828 - Jaccard: 0.7994 - F1: 0.8188 - Recall: 0.8757 - Precision: 0.8919

# Epoch: 12 | Epoch Time: 8m 48s
# 	Train Loss: 0.6580 - Jaccard: 0.7888 - F1: 0.8091 - Recall: 0.8681 - Precision: 0.8870
# 	 Val. Loss: 0.7341 - Jaccard: 0.7880 - F1: 0.8062 - Recall: 0.8611 - Precision: 0.8969

# Epoch: 13 | Epoch Time: 8m 48s
# 	Train Loss: 0.6451 - Jaccard: 0.7789 - F1: 0.7995 - Recall: 0.8682 - Precision: 0.8743
# 	 Val. Loss: 0.6762 - Jaccard: 0.7473 - F1: 0.7695 - Recall: 0.8825 - Precision: 0.8219

# Epoch: 14 | Epoch Time: 8m 48s
# 	Train Loss: 0.6304 - Jaccard: 0.7969 - F1: 0.8176 - Recall: 0.8702 - Precision: 0.8933
# 	 Val. Loss: 0.6900 - Jaccard: 0.7759 - F1: 0.7950 - Recall: 0.8756 - Precision: 0.8702

# Valid F1 improved from 0.8188 to 0.8219. Saving checkpoint: files/checkpoint1.pth
# Epoch: 15 | Epoch Time: 8m 49s
# 	Train Loss: 0.6258 - Jaccard: 0.7975 - F1: 0.8176 - Recall: 0.8696 - Precision: 0.8983
# 	 Val. Loss: 0.7451 - Jaccard: 0.8059 - F1: 0.8219 - Recall: 0.8578 - Precision: 0.9235

# Epoch: 16 | Epoch Time: 8m 49s
# 	Train Loss: 0.6616 - Jaccard: 0.7919 - F1: 0.8110 - Recall: 0.8649 - Precision: 0.8955
# 	 Val. Loss: 0.6994 - Jaccard: 0.7774 - F1: 0.7980 - Recall: 0.8811 - Precision: 0.8547

# Epoch: 17 | Epoch Time: 8m 48s
# 	Train Loss: 0.6376 - Jaccard: 0.7915 - F1: 0.8118 - Recall: 0.8712 - Precision: 0.8862
# 	 Val. Loss: 0.6703 - Jaccard: 0.7834 - F1: 0.8047 - Recall: 0.8835 - Precision: 0.8598

# Epoch: 18 | Epoch Time: 8m 48s
# 	Train Loss: 0.6265 - Jaccard: 0.7900 - F1: 0.8105 - Recall: 0.8713 - Precision: 0.8874
# 	 Val. Loss: 0.7101 - Jaccard: 0.7988 - F1: 0.8144 - Recall: 0.8555 - Precision: 0.9216

# Epoch: 19 | Epoch Time: 8m 49s
# 	Train Loss: 0.6350 - Jaccard: 0.7847 - F1: 0.8043 - Recall: 0.8667 - Precision: 0.8889
# 	 Val. Loss: 0.6936 - Jaccard: 0.7995 - F1: 0.8174 - Recall: 0.8668 - Precision: 0.9093

# Epoch: 20 | Epoch Time: 8m 48s
# 	Train Loss: 0.6111 - Jaccard: 0.7983 - F1: 0.8189 - Recall: 0.8735 - Precision: 0.8945
# 	 Val. Loss: 0.6642 - Jaccard: 0.7867 - F1: 0.8073 - Recall: 0.8742 - Precision: 0.8769

# Epoch: 21 | Epoch Time: 8m 48s
# 	Train Loss: 0.6099 - Jaccard: 0.8012 - F1: 0.8222 - Recall: 0.8744 - Precision: 0.8942
# 	 Val. Loss: 0.6786 - Jaccard: 0.7988 - F1: 0.8177 - Recall: 0.8637 - Precision: 0.9048

# Epoch: 22 | Epoch Time: 8m 48s
# 	Train Loss: 0.5996 - Jaccard: 0.8032 - F1: 0.8242 - Recall: 0.8754 - Precision: 0.8985
# 	 Val. Loss: 0.6903 - Jaccard: 0.7842 - F1: 0.8046 - Recall: 0.8741 - Precision: 0.8770

# Epoch: 23 | Epoch Time: 8m 48s
# 	Train Loss: 0.5972 - Jaccard: 0.8019 - F1: 0.8229 - Recall: 0.8756 - Precision: 0.8969
# 	 Val. Loss: 0.6759 - Jaccard: 0.7568 - F1: 0.7799 - Recall: 0.8945 - Precision: 0.8229

# Valid F1 improved from 0.8219 to 0.8235. Saving checkpoint: files/checkpoint1.pth
# Epoch: 24 | Epoch Time: 8m 49s
# 	Train Loss: 0.6012 - Jaccard: 0.8063 - F1: 0.8272 - Recall: 0.8761 - Precision: 0.9001
# 	 Val. Loss: 0.6708 - Jaccard: 0.8043 - F1: 0.8235 - Recall: 0.8779 - Precision: 0.8972

# Epoch: 25 | Epoch Time: 8m 48s
# 	Train Loss: 0.5761 - Jaccard: 0.8119 - F1: 0.8330 - Recall: 0.8766 - Precision: 0.9065
# 	 Val. Loss: 0.6732 - Jaccard: 0.7831 - F1: 0.8042 - Recall: 0.8758 - Precision: 0.8683

# Epoch: 26 | Epoch Time: 8m 49s
# 	Train Loss: 0.5771 - Jaccard: 0.8098 - F1: 0.8314 - Recall: 0.8797 - Precision: 0.9004
# 	 Val. Loss: 0.6822 - Jaccard: 0.7955 - F1: 0.8150 - Recall: 0.8675 - Precision: 0.8963

# Valid F1 improved from 0.8235 to 0.8279. Saving checkpoint: files/checkpoint1.pth
# Epoch: 27 | Epoch Time: 8m 49s
# 	Train Loss: 0.5567 - Jaccard: 0.8155 - F1: 0.8368 - Recall: 0.8794 - Precision: 0.9085
# 	 Val. Loss: 0.6613 - Jaccard: 0.8089 - F1: 0.8279 - Recall: 0.8676 - Precision: 0.9143

# Epoch: 28 | Epoch Time: 8m 48s
# 	Train Loss: 0.5464 - Jaccard: 0.8221 - F1: 0.8434 - Recall: 0.8801 - Precision: 0.9133
# 	 Val. Loss: 0.6515 - Jaccard: 0.8060 - F1: 0.8256 - Recall: 0.8719 - Precision: 0.9063

# Valid F1 improved from 0.8279 to 0.8292. Saving checkpoint: files/checkpoint1.pth
# Epoch: 29 | Epoch Time: 8m 49s
# 	Train Loss: 0.5354 - Jaccard: 0.8200 - F1: 0.8423 - Recall: 0.8853 - Precision: 0.9083
# 	 Val. Loss: 0.6520 - Jaccard: 0.8105 - F1: 0.8292 - Recall: 0.8691 - Precision: 0.9169

# Valid F1 improved from 0.8292 to 0.8298. Saving checkpoint: files/checkpoint1.pth
# Epoch: 30 | Epoch Time: 8m 49s
# 	Train Loss: 0.5301 - Jaccard: 0.8289 - F1: 0.8504 - Recall: 0.8814 - Precision: 0.9215
# 	 Val. Loss: 0.6510 - Jaccard: 0.8107 - F1: 0.8298 - Recall: 0.8688 - Precision: 0.9173

# Epoch: 31 | Epoch Time: 8m 48s
# 	Train Loss: 0.5266 - Jaccard: 0.8303 - F1: 0.8527 - Recall: 0.8878 - Precision: 0.9152
# 	 Val. Loss: 0.6489 - Jaccard: 0.8028 - F1: 0.8226 - Recall: 0.8731 - Precision: 0.9017

# Valid F1 improved from 0.8298 to 0.8300. Saving checkpoint: files/checkpoint1.pth
# Epoch: 32 | Epoch Time: 8m 49s
# 	Train Loss: 0.5084 - Jaccard: 0.8337 - F1: 0.8558 - Recall: 0.8859 - Precision: 0.9216
# 	 Val. Loss: 0.6672 - Jaccard: 0.8124 - F1: 0.8300 - Recall: 0.8643 - Precision: 0.9258

# Epoch: 33 | Epoch Time: 8m 48s
# 	Train Loss: 0.5126 - Jaccard: 0.8367 - F1: 0.8584 - Recall: 0.8852 - Precision: 0.9263
# 	 Val. Loss: 0.6753 - Jaccard: 0.8128 - F1: 0.8296 - Recall: 0.8601 - Precision: 0.9302

# Valid F1 improved from 0.8300 to 0.8301. Saving checkpoint: files/checkpoint1.pth
# Epoch: 34 | Epoch Time: 8m 49s
# 	Train Loss: 0.5211 - Jaccard: 0.8371 - F1: 0.8586 - Recall: 0.8849 - Precision: 0.9270
# 	 Val. Loss: 0.6675 - Jaccard: 0.8123 - F1: 0.8301 - Recall: 0.8661 - Precision: 0.9219

# Valid F1 improved from 0.8301 to 0.8303. Saving checkpoint: files/checkpoint1.pth
# Epoch: 35 | Epoch Time: 8m 49s
# 	Train Loss: 0.5252 - Jaccard: 0.8376 - F1: 0.8594 - Recall: 0.8847 - Precision: 0.9278
# 	 Val. Loss: 0.6453 - Jaccard: 0.8112 - F1: 0.8303 - Recall: 0.8759 - Precision: 0.9095

# Valid F1 improved from 0.8303 to 0.8318. Saving checkpoint: files/checkpoint1.pth
# Epoch: 36 | Epoch Time: 8m 49s
# 	Train Loss: 0.5114 - Jaccard: 0.8401 - F1: 0.8617 - Recall: 0.8868 - Precision: 0.9286
# 	 Val. Loss: 0.6584 - Jaccard: 0.8136 - F1: 0.8318 - Recall: 0.8696 - Precision: 0.9200

# Valid F1 improved from 0.8318 to 0.8322. Saving checkpoint: files/checkpoint1.pth
# Epoch: 37 | Epoch Time: 8m 49s
# 	Train Loss: 0.5149 - Jaccard: 0.8392 - F1: 0.8617 - Recall: 0.8908 - Precision: 0.9228
# 	 Val. Loss: 0.6599 - Jaccard: 0.8146 - F1: 0.8322 - Recall: 0.8634 - Precision: 0.9286

# Epoch: 38 | Epoch Time: 8m 49s
# 	Train Loss: 0.5036 - Jaccard: 0.8395 - F1: 0.8616 - Recall: 0.8885 - Precision: 0.9240
# 	 Val. Loss: 0.6449 - Jaccard: 0.8082 - F1: 0.8266 - Recall: 0.8731 - Precision: 0.9096

# Epoch: 39 | Epoch Time: 8m 48s
# 	Train Loss: 0.5044 - Jaccard: 0.8391 - F1: 0.8613 - Recall: 0.8885 - Precision: 0.9253
# 	 Val. Loss: 0.6503 - Jaccard: 0.8147 - F1: 0.8320 - Recall: 0.8644 - Precision: 0.9271

# Epoch: 40 | Epoch Time: 8m 48s
# 	Train Loss: 0.4962 - Jaccard: 0.8407 - F1: 0.8631 - Recall: 0.8914 - Precision: 0.9225
# 	 Val. Loss: 0.6431 - Jaccard: 0.8072 - F1: 0.8265 - Recall: 0.8739 - Precision: 0.9058

# Epoch: 41 | Epoch Time: 8m 48s
# 	Train Loss: 0.5069 - Jaccard: 0.8386 - F1: 0.8614 - Recall: 0.8907 - Precision: 0.9200
# 	 Val. Loss: 0.6388 - Jaccard: 0.8054 - F1: 0.8250 - Recall: 0.8771 - Precision: 0.9020

# Valid F1 improved from 0.8322 to 0.8325. Saving checkpoint: files/checkpoint1.pth
# Epoch: 42 | Epoch Time: 8m 49s
# 	Train Loss: 0.4853 - Jaccard: 0.8426 - F1: 0.8654 - Recall: 0.8906 - Precision: 0.9263
# 	 Val. Loss: 0.6655 - Jaccard: 0.8150 - F1: 0.8325 - Recall: 0.8608 - Precision: 0.9302

# Epoch: 43 | Epoch Time: 8m 48s
# 	Train Loss: 0.5040 - Jaccard: 0.8423 - F1: 0.8648 - Recall: 0.8898 - Precision: 0.9261
# 	 Val. Loss: 0.6525 - Jaccard: 0.8128 - F1: 0.8315 - Recall: 0.8687 - Precision: 0.9199

# Epoch: 44 | Epoch Time: 8m 49s
# 	Train Loss: 0.5020 - Jaccard: 0.8405 - F1: 0.8631 - Recall: 0.8922 - Precision: 0.9236
# 	 Val. Loss: 0.6392 - Jaccard: 0.7978 - F1: 0.8185 - Recall: 0.8792 - Precision: 0.8887

# Epoch: 45 | Epoch Time: 8m 48s
# 	Train Loss: 0.4916 - Jaccard: 0.8409 - F1: 0.8636 - Recall: 0.8908 - Precision: 0.9254
# 	 Val. Loss: 0.6414 - Jaccard: 0.8091 - F1: 0.8286 - Recall: 0.8746 - Precision: 0.9082

# Valid F1 improved from 0.8325 to 0.8398. Saving checkpoint: files/checkpoint1.pth
# Epoch: 46 | Epoch Time: 8m 49s
# 	Train Loss: 0.4863 - Jaccard: 0.8450 - F1: 0.8682 - Recall: 0.8929 - Precision: 0.9261
# 	 Val. Loss: 0.6526 - Jaccard: 0.8194 - F1: 0.8398 - Recall: 0.8656 - Precision: 0.9290

# Epoch: 47 | Epoch Time: 8m 48s
# 	Train Loss: 0.4857 - Jaccard: 0.8435 - F1: 0.8665 - Recall: 0.8927 - Precision: 0.9252
# 	 Val. Loss: 0.6395 - Jaccard: 0.8071 - F1: 0.8266 - Recall: 0.8773 - Precision: 0.9030

# Epoch: 48 | Epoch Time: 8m 48s
# 	Train Loss: 0.4904 - Jaccard: 0.8447 - F1: 0.8675 - Recall: 0.8935 - Precision: 0.9256
# 	 Val. Loss: 0.6395 - Jaccard: 0.8133 - F1: 0.8325 - Recall: 0.8741 - Precision: 0.9128

# Epoch: 49 | Epoch Time: 8m 48s
# 	Train Loss: 0.4750 - Jaccard: 0.8469 - F1: 0.8695 - Recall: 0.8931 - Precision: 0.9280
# 	 Val. Loss: 0.6381 - Jaccard: 0.8102 - F1: 0.8295 - Recall: 0.8761 - Precision: 0.9080

# Epoch: 50 | Epoch Time: 8m 48s
# 	Train Loss: 0.4780 - Jaccard: 0.8453 - F1: 0.8677 - Recall: 0.8920 - Precision: 0.9285
# 	 Val. Loss: 0.6537 - Jaccard: 0.8179 - F1: 0.8355 - Recall: 0.8653 - Precision: 0.9297

# Epoch: 51 | Epoch Time: 8m 49s
# 	Train Loss: 0.4754 - Jaccard: 0.8491 - F1: 0.8715 - Recall: 0.8909 - Precision: 0.9340
# 	 Val. Loss: 0.6527 - Jaccard: 0.8158 - F1: 0.8339 - Recall: 0.8669 - Precision: 0.9245

# Epoch: 52 | Epoch Time: 8m 48s
# 	Train Loss: 0.4751 - Jaccard: 0.8504 - F1: 0.8724 - Recall: 0.8896 - Precision: 0.9362
# 	 Val. Loss: 0.6480 - Jaccard: 0.8144 - F1: 0.8329 - Recall: 0.8696 - Precision: 0.9201

# Epoch: 53 | Epoch Time: 8m 48s
# 	Train Loss: 0.4858 - Jaccard: 0.8466 - F1: 0.8685 - Recall: 0.8899 - Precision: 0.9336
# 	 Val. Loss: 0.6540 - Jaccard: 0.8149 - F1: 0.8327 - Recall: 0.8673 - Precision: 0.9234

# %%
import os
import random
import time
import datetime
import numpy as np
import albumentations as A
import cv2
from glob import glob
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from text2embed import Text2Embed
from utils import seeding, create_dir, print_and_save, shuffling, epoch_time, calculate_metrics, mask_to_bbox
from metrics import DiceLoss, DiceBCELoss, MultiClassBCE, FocalLoss, CascadingLoss
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import timm
# from resnet import seresnext50_32x4d
import torch.nn.functional as F
# from torch.amp import autocast, GradScaler
import warnings
import torch.cuda.amp as amp
import torch.nn.init as init

class conv2d(nn.Module):
    def __init__(self, in_c, out_c, kernel_size=3, padding=1, dilation=1, act=True):
        super().__init__()
        self.act = act

        self.conv = nn.Sequential(
            nn.Conv2d(in_c, out_c, kernel_size, padding=padding, dilation=dilation, bias=False),
            nn.BatchNorm2d(out_c)
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        if self.act == True:
            x = self.relu(x)
        return x

class channel_attention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(channel_attention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x0 = x
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return x0 * self.sigmoid(out)


class spatial_attention(nn.Module):
    def __init__(self, kernel_size=7):
        super(spatial_attention, self).__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x0 = x
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return x0 * self.sigmoid(x)

class dilated_conv(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        self.c1 = nn.Sequential(conv2d(in_c, out_c, kernel_size=1, padding=0), channel_attention(out_c))
        self.c2 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=6, dilation=6), channel_attention(out_c))
        self.c3 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=12, dilation=12), channel_attention(out_c))
        self.c4 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=18, dilation=18), channel_attention(out_c))
        self.c5 = conv2d(out_c*4, out_c, kernel_size=3, padding=1, act=False)
        self.c6 = conv2d(in_c, out_c, kernel_size=1, padding=0, act=False)
        self.sa = spatial_attention()

    def forward(self, x):
        x1 = self.c1(x)
        x2 = self.c2(x)
        x3 = self.c3(x)
        x4 = self.c4(x)
        xc = torch.cat([x1, x2, x3, x4], axis=1)
        xc = self.c5(xc)
        xs = self.c6(x)
        x = self.relu(xc+xs)
        x = self.sa(x)
        return x

class label_attention(nn.Module):
    def __init__(self, in_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        """ Channel Attention """
        self.c1 = nn.Sequential(
            nn.Conv2d(in_c[1], in_c[0], kernel_size=1, padding=0, bias=False),
            nn.ReLU(),
            nn.Conv2d(in_c[0], in_c[0], kernel_size=1, padding=0, bias=False)
        )

    def forward(self, feats, label):
        """ Channel Attention """
        b, c = label.shape
        label = label.reshape(b, c, 1, 1)
        ch_attn = self.c1(label)
        ch_map = torch.sigmoid(ch_attn)
        feats = feats * ch_map

        ch_attn = ch_attn.reshape(ch_attn.shape[0], ch_attn.shape[1])
        return ch_attn, feats

class decoder_block(nn.Module):
    def __init__(self, in_c, out_c, scale=2):
        super().__init__()
        self.scale = scale
        self.relu = nn.ReLU(inplace=True)

        self.up = nn.Upsample(scale_factor=scale, mode="bilinear", align_corners=True)
        self.c1 = conv2d(in_c + out_c, out_c, kernel_size=1, padding=0)  # Adjust input channels
        self.c2 = conv2d(out_c, out_c, act=False)
        self.c3 = conv2d(out_c, out_c, act=False)
        self.c4 = conv2d(out_c, out_c, kernel_size=1, padding=0, act=False)
        self.ca = channel_attention(out_c)
        self.sa = spatial_attention()

    def forward(self, x, skip):
        x = self.up(x)

        # Ensure spatial dimensions match
        if x.shape[2:] != skip.shape[2:]:
            x = F.interpolate(x, size=skip.shape[2:], mode="bilinear", align_corners=True)

        x = torch.cat([x, skip], dim=1)  # Concatenate along the channel dimension
        x = self.c1(x)

        s1 = x
        x = self.c2(x)
        x = self.relu(x + s1)

        s2 = x
        x = self.c3(x)
        x = self.relu(x + s2 + s1)

        s3 = x
        x = self.c4(x)
        x = self.relu(x + s3 + s2 + s1)

        x = self.ca(x)
        x = self.sa(x)
        return x

class output_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.c1 = nn.Conv2d(in_c, out_c, kernel_size=1, padding=0)

    def forward(self, x):
        x = self.up(x)
        x = self.c1(x)
        return x

class text_classifier(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Sequential(
            nn.Linear(in_c, in_c//8, bias=False), nn.ReLU(),
            nn.Linear(in_c//8, out_c[0], bias=False)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(in_c, in_c//8, bias=False), nn.ReLU(),
            nn.Linear(in_c//8, out_c[1], bias=False)
        )

    def forward(self, feats):
        pool = self.avg_pool(feats).view(feats.shape[0], feats.shape[1])
        num_lesions = self.fc1(pool)
        lesion_sizes = self.fc2(pool)
        # print(f"num_lesions shape: {num_lesions.shape}")
        # print(f"lesion_sizes shape: {lesion_sizes.shape}")
        return num_lesions, lesion_sizes

class embedding_feature_fusion(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.fc = nn.Sequential(
            nn.Conv2d((in_c[0]+in_c[1])*in_c[2], out_c, 1, bias=False), nn.ReLU(),
            nn.Conv2d(out_c, out_c, 1, bias=False), nn.ReLU()
        )

    def forward(self, num_lesions, lesion_sizes, label):
        # print(f"num_lesions shape: {num_lesions.shape}")
        # print(f"lesion_sizes shape: {lesion_sizes.shape}")
        num_lesions_prob = torch.softmax(num_lesions, axis=1)
        lesion_sizes_prob = torch.softmax(lesion_sizes, axis=1)
        # print(f"num_lesions_classes", num_lesions_prob.shape)
        # print(f"lesions_size_classes", lesion_sizes_prob.shape)
        prob = torch.cat([num_lesions_prob, lesion_sizes_prob], axis=1)
        # print(f"prob shape: {prob.shape}")
        prob = prob.view(prob.shape[0], prob.shape[1], 1)
        if label.shape[1] != prob.shape[1]:
          raise ValueError(
              f"Shape mismatch: label channels ({label.shape[1]}) != prob channels ({prob.shape[1]})"
          )
        # print(f"x shape before fc: {x.shape}")
        x = label * prob
        x = x.view(x.shape[0], -1, 1, 1)
        if x.shape[1] != 1800:
            # x = torch.nn.functional.adaptive_avg_pool2d(x, (1, 1))  # Adjust spatial dimensions
            device = x.device  # Get the device of the input tensor
            conv_layer = torch.nn.Conv2d(x.shape[1], 1800, kernel_size=1).to(device)
            x = conv_layer(x)

        # print(f"x shape after fc: {x.shape}")
        x = self.fc(x)
        x = x.view(x.shape[0], -1)
        return x

class multiscale_feature_aggregation(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        self.up_2x2 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.up_4x4 = nn.Upsample(scale_factor=4, mode="bilinear", align_corners=True)
        self.up_8x8 = nn.Upsample(scale_factor=8, mode="bilinear", align_corners=True)  # Add upsampling for layer4 features

        self.c11 = conv2d(in_c[0], out_c, kernel_size=1, padding=0)
        self.c12 = conv2d(in_c[1], out_c, kernel_size=1, padding=0)
        self.c13 = conv2d(in_c[2], out_c, kernel_size=1, padding=0)
        self.c14 = conv2d(in_c[3], out_c, kernel_size=1, padding=0)  # Add for layer4 features
        self.c15 = conv2d(out_c * 4, out_c, kernel_size=1, padding=0)  # Update to handle 4 inputs

        self.c2 = conv2d(out_c, out_c, act=False)
        self.c3 = conv2d(out_c, out_c, act=False)

    def forward(self, x1, x2, x3, x4):  # Add x4 for layer4 features
        # Upsample all feature maps to the same spatial resolution (128x128)
        x1 = self.up_8x8(x1)  # Upsample x1 (from layer4) by 8x
        x2 = self.up_4x4(x2)  # Upsample x2 (from layer3) by 4x
        x3 = self.up_2x2(x3)  # Upsample x3 (from layer2) by 2x
        x4 = F.interpolate(x4, size=(128, 128), mode="bilinear", align_corners=True)  # Upsample x4 (from layer1) to 128x128

        x1 = self.c11(x1)
        x2 = self.c12(x2)
        x3 = self.c13(x3)
        x4 = self.c14(x4)  # Process x4

        x = torch.cat([x1, x2, x3, x4], dim=1)  # Concatenate all 4 inputs
        x = self.c15(x)

        s1 = x
        x = self.c2(x)
        x = self.relu(x + s1)

        s2 = x
        x = self.c3(x)
        x = self.relu(x + s2 + s1)

        return x

class ProgressiveDenoisingAttention1(nn.Module):
    def __init__(self, channels, num_iterations=3):
        super(ProgressiveDenoisingAttention1, self).__init__()
        self.num_iterations = num_iterations
        self.channels = channels

        # Convolution layers for refining attention
        self.conv_layers = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(channels, channels, kernel_size=3, padding=1, bias=False),
                nn.BatchNorm2d(channels),
                nn.ReLU(inplace=True)
            ) for _ in range(num_iterations)
        ])

        # Final attention map generation
        self.final_conv = nn.Conv2d(channels, 1, kernel_size=1, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # Initial attention map
        attention_map = x

        # Progressive denoising
        for conv in self.conv_layers:
            attention_map = conv(attention_map)

        # Final attention map
        attention_map = self.final_conv(attention_map)
        attention_map = self.sigmoid(attention_map)

        # Apply attention to input features
        return x * attention_map

class UNetDenoise(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.Conv2d(64, out_channels, kernel_size=3, padding=1),
            nn.ReLU(),
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

class EnhancedDilatedConv(nn.Module):
    def __init__(self, in_c, out_c, neg_weight=0.3):
        super().__init__()
        self.neg_weight = neg_weight
        self.main_conv = dilated_conv(in_c, out_c)
        self.negative_conv = nn.Sequential(
            nn.Conv2d(in_c, out_c, kernel_size=3, padding=6, dilation=6),
            channel_attention(out_c),
            spatial_attention()
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        pos_features = self.main_conv(x)
        neg_features = self.negative_conv(1 - x)
        return self.relu(pos_features + self.neg_weight * neg_features)


class TGAlesionSeg(nn.Module):
    def __init__(self):
        super().__init__()

        """ Backbone: SE-ResNeXt50 """
        backbone = timm.create_model('seresnext50_32x4d', pretrained=True)

        # Extract the layers from the backbone
        self.layer0 = nn.Sequential(
            backbone.conv1,
            backbone.bn1,
            backbone.act1,
            backbone.maxpool
        )
        self.layer1 = backbone.layer1
        self.layer2 = backbone.layer2
        self.layer3 = backbone.layer3
        self.layer4 = backbone.layer4  # Add layer4

        self.text_classifier = text_classifier(2048, [3, 3])  # Update input channels to 2048 for layer4
        self.label_fc = embedding_feature_fusion([3, 3, 300], 128)

        """ Dilated Conv """
        self.s1 = EnhancedDilatedConv(64, 128)
        self.s2 = EnhancedDilatedConv(256, 128)
        self.s3 = EnhancedDilatedConv(512, 128)
        self.s4 = EnhancedDilatedConv(1024, 128)
        self.s5 = EnhancedDilatedConv(2048, 128)


        """ Progressive Denoising Attention """
        self.pda1 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda2 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda3 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda4 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda5 = ProgressiveDenoisingAttention1(128, num_iterations=3)  # Add PDA for layer4 features

        """ U-Net Denoising Modules """
        self.denoise1 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise2 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise3 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise4 = UNetDenoise(in_channels=128, out_channels=128)  # Add denoising for layer4 features

        """ Decoder """
        self.d1 = decoder_block(128, 128, scale=2)
        self.a1 = label_attention([128, 128])

        self.d2 = decoder_block(128, 128, scale=2)
        self.a2 = label_attention([128, 128])

        self.d3 = decoder_block(128, 128, scale=2)
        self.a3 = label_attention([128, 128])

        self.d4 = decoder_block(128, 128, scale=2)  # Add decoder block for layer4 features
        self.a4 = label_attention([128, 128])

        self.ag = multiscale_feature_aggregation([128, 128, 128, 128], 128)  # Update to include layer4 features

        self.y1 = output_block(128, 1)

    def forward(self, image, label):
        """ Backbone: SE-ResNeXt50 """
        x0 = image
        x1 = self.layer0(x0)    ## [-1, 64, h/2, w/2]
        x2 = self.layer1(x1)    ## [-1, 256, h/4, w/4]
        x3 = self.layer2(x2)    ## [-1, 512, h/8, w/8]
        x4 = self.layer3(x3)    ## [-1, 1024, h/16, w/16]
        x5 = self.layer4(x4)    ## [-1, 2048, h/32, w/32]  # Add layer4 output

        num_lesions, lesion_sizes = self.text_classifier(x5)  # Use x5 (layer4 features)
        f0 = self.label_fc(num_lesions, lesion_sizes, label)

        """ Dilated Conv + PDA """
        s1 = self.pda1(self.s1(x1))
        s2 = self.pda2(self.s2(x2))
        s3 = self.pda3(self.s3(x3))
        s4 = self.pda4(self.s4(x4))
        s5 = self.pda5(self.s5(x5))  # Add PDA for layer4 features

        """ Decoder + Denoising """
        # Stage 1
        d1 = self.d1(s5, s4)  # Use s5 (layer4 features) as input to the first decoder block
        f1, a1 = self.a1(d1, f0)
        a1_denoised = self.denoise1(a1)

        # Stage 2
        d2 = self.d2(a1_denoised, s3)
        f = f0 + f1
        f2, a2 = self.a2(d2, f)
        a2_denoised = self.denoise2(a2)

        # Stage 3
        d3 = self.d3(a2_denoised, s2)
        f = f0 + f1 + f2
        f3, a3 = self.a3(d3, f)
        a3_denoised = self.denoise3(a3)

        # Stage 4
        d4 = self.d4(a3_denoised, s1)
        f = f0 + f1 + f2 + f3
        f4, a4 = self.a4(d4, f)
        a4_denoised = self.denoise4(a4)

        ag = self.ag(a1_denoised, a2_denoised, a3_denoised, a4_denoised)  # Include layer4 features
        y1 = self.y1(ag)

        return y1, num_lesions, lesion_sizes

def prepare_input(res):
    x1 = torch.FloatTensor(1, 3, 256, 256).cuda()
    x2 = torch.FloatTensor(1, 5, 300).cuda()
    return dict(x = [x1, x2])

### --------------------------------------------------------------------------------------------------------------------------------------------------------

def load_names(path, file_path):
    f = open(file_path, "r")
    data = f.read().split("\n")[:-1]
    images = [os.path.join(path,"images", name) + ".png" for name in data]
    masks = [os.path.join(path,"masks", name) + ".png" for name in data]
    return images, masks

def label_dictionary():
    label_dict = {}
    label_dict["lesion"] = ["zero", "one", "multiple", "small", "medium", "large"]
    return label_dict

def load_data(path):
    train_names_path = f"{path}/train.txt"
    valid_names_path = f"{path}/val.txt"

    train_x, train_y = load_names(path, train_names_path)
    valid_x, valid_y = load_names(path, valid_names_path)

    label_dict = label_dictionary()
    print(label_dict)
    train_label = len(train_x) * [label_dict["lesion"]]
    valid_label = len(valid_x) * [label_dict["lesion"]]

    return (train_x, train_y, train_label), (valid_x, valid_y, valid_label)

class DATASET(Dataset):
    def __init__(self, images_path, labels_path, masks_path, size, transform=None):
        super().__init__()
        self.images_path = images_path
        self.labels_path = labels_path
        self.masks_path = masks_path
        self.size = size  # Ensure size is stored as an instance attribute
        self.transform = transform
        self.n_samples = len(images_path)

        self.embed = Text2Embed()

    def visualize_bbox_on_mask(self, image, mask, bboxes, title="Mask with BBoxes"):
        """Visualize the mask and bounding boxes overlaid on the mask."""
        if len(image.shape) != 3 or image.shape[2] != 3:
            raise ValueError(f"Expected a color image with 3 channels, but got shape {image.shape}")

        fig, ax = plt.subplots(1, 2, figsize=(12, 6))

        # Show original image
        ax[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        ax[0].set_title("Original Image")
        ax[0].axis("off")

        # Show mask with bounding boxes
        mask_with_bbox = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
        for bbox in bboxes:
            x1, y1, x2, y2 = bbox
            mask_with_bbox = cv2.rectangle(mask_with_bbox, (x1, y1), (x2, y2), (255, 0, 0), 2)

        ax[1].imshow(cv2.cvtColor(mask_with_bbox, cv2.COLOR_BGR2RGB))
        ax[1].set_title(title)
        ax[1].axis("off")

        plt.tight_layout()
        plt.show()


    def mask_to_text(self, mask, image=None):
        bboxes = mask_to_bbox(mask)
        lesion_sizes = 0
        num_lesions = 0

        # Calculate sizes and number of lesions
        for bbox in bboxes:
            x1, y1, x2, y2 = bbox
            h = (y2 - y1)
            w = (x2 - x1)
            area = (h * w) / (mask.shape[0] * mask.shape[1])

            if area < 0.007:
                lesion_sizes = 0
            elif 0.007 <= area < 0.04:
                lesion_sizes = 1
            elif area >= 0.04:
                lesion_sizes = 2

        if(len(bboxes) == 0):
          num_lesions = 0
        elif(len(bboxes) == 1):
          num_lesions = 1
        elif(len(bboxes) >= 2):
          num_lesions = 2

        # visualization
        if image is None:
            self.visualize_bbox_on_mask(image, mask, bboxes, title="Mask with Bounding Boxes")

        return np.array(num_lesions), np.array(lesion_sizes)


    def __getitem__(self, index):
      image = cv2.imread(self.images_path[index], cv2.IMREAD_COLOR)
      mask = cv2.imread(self.masks_path[index], cv2.IMREAD_GRAYSCALE)

      if image is None or mask is None:
          raise FileNotFoundError(f"Could not read image or mask at index {index}. Check the file paths.")

      if self.transform is not None:
          augmentations = self.transform(image=image, mask=mask)
          image = augmentations["image"]
          mask = augmentations["mask"]

      image = cv2.resize(image, self.size)
      if len(image.shape) != 3 or image.shape[2] != 3:
          raise ValueError(f"Expected a color image with 3 channels after resizing, but got shape {image.shape}")

      image = np.transpose(image, (2, 0, 1))
      image = image / 255.0

      mask = cv2.resize(mask, self.size)
      mask_copy = mask
      mask = np.expand_dims(mask, axis=0)
      mask = mask / 255.0

      visual_image = (image.transpose(1, 2, 0) * 255).astype(np.uint8)
      num_lesions, lesion_sizes = self.mask_to_text(mask_copy, visual_image)

      # print(f"image = {self.images_path[index]}\n")
      # print(f"mask = {self.masks_path[index]}\n"print(np.unique(labels))  # Confirm number and range of classes.
      label = []
      words = self.labels_path[index]
      for word in words:
          word_embed = self.embed.to_embed(word)[0]
          label.append(word_embed)
      label = np.array(label)
      # print(f"label shape: {label.shape}")
      # print(np.unique(label))  # Confirm number and range of classes.

      return (image, label), (mask, num_lesions, lesion_sizes)

    def __len__(self):
        return self.n_samples


def train(model, loader, optimizer, loss_fn, device):
    model.train()
    epoch_loss = 0.0
    epoch_jac = 0.0
    epoch_f1 = 0.0
    epoch_recall = 0.0
    epoch_precision = 0.0
    # scaler = amp.GradScaler()  # Define scaler before training

    for i, ((x, l), (y1, y2, y3)) in enumerate(loader):
        x = x.to(device, dtype=torch.float32)
        l = l.to(device, dtype=torch.float32)
        y1 = y1.to(device, dtype=torch.float32)
        y2 = y2.to(device, dtype=torch.long)
        y3 = y3.to(device, dtype=torch.long)

        optimizer.zero_grad()

        p1, p2, p3 = model(x, l)
        p2 = torch.softmax(p2, dim=1)
        p3 = torch.softmax(p3, dim=1)

        loss1 = loss_fn[0](p1, y1, p2, y2)  # Segmentation loss
        loss2 = loss_fn[1](p2, y2)
        loss3 = loss_fn[2](p3, y3)

        loss = loss1 + loss2 + loss3

        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

        batch_jac = []
        batch_f1 = []
        batch_recall = []
        batch_precision = []

        for yt, yp in zip(y1, p1):
            score = calculate_metrics(yt, yp)
            batch_jac.append(score[0])
            batch_f1.append(score[1])
            batch_recall.append(score[2])
            batch_precision.append(score[3])

        epoch_jac += np.mean(batch_jac)
        epoch_f1 += np.mean(batch_f1)
        epoch_recall += np.mean(batch_recall)
        epoch_precision += np.mean(batch_precision)

    epoch_loss = epoch_loss / len(loader)
    epoch_jac = epoch_jac / len(loader)
    epoch_f1 = epoch_f1 / len(loader)
    epoch_recall = epoch_recall / len(loader)
    epoch_precision = epoch_precision / len(loader)

    return epoch_loss, [epoch_jac, epoch_f1, epoch_recall, epoch_precision]

def evaluate(model, loader, loss_fn, device):
    model.eval()

    epoch_loss = 0.0
    epoch_jac = 0.0
    epoch_f1 = 0.0
    epoch_recall = 0.0
    epoch_precision = 0.0

    with torch.no_grad():
        for i, ((x, l), (y1, y2, y3)) in enumerate(loader):
            x = x.to(device, dtype=torch.float32)
            l = l.to(device, dtype=torch.float32)
            y1 = y1.to(device, dtype=torch.float32)
            y2 = y2.to(device, dtype=torch.long)
            y3 = y3.to(device, dtype=torch.long)

            p1, p2, p3 = model(x, l)
            p2 = torch.softmax(p2, dim=1)
            p3 = torch.softmax(p3, dim=1)

            loss1 = loss_fn[0](p1, y1)
            loss2 = loss_fn[1](p2, y2)
            loss3 = loss_fn[2](p3, y3)

            loss = loss1 + loss2 + loss3

            epoch_loss += loss.item()

            batch_jac = []
            batch_f1 = []
            batch_recall = []
            batch_precision = []

            for yt, yp in zip(y1, p1):
                score = calculate_metrics(yt, yp)
                batch_jac.append(score[0])
                batch_f1.append(score[1])
                batch_recall.append(score[2])
                batch_precision.append(score[3])

            epoch_jac += np.mean(batch_jac)
            epoch_f1 += np.mean(batch_f1)
            epoch_recall += np.mean(batch_recall)
            epoch_precision += np.mean(batch_precision)

    epoch_loss = epoch_loss / len(loader)
    epoch_jac = epoch_jac / len(loader)
    epoch_f1 = epoch_f1 / len(loader)
    epoch_recall = epoch_recall / len(loader)
    epoch_precision = epoch_precision / len(loader)

    return epoch_loss, [epoch_jac, epoch_f1, epoch_recall, epoch_precision]


if __name__ == "__main__":
    """ Seeding """
    seeding(42)

    """ Directories """
    create_dir("files")

    """ Training logfile """
    train_log_path = "files/train_log.txt"
    if os.path.exists(train_log_path):
        print("Log file exists")
    else:
        train_log = open("files/train_log.txt", "w")
        train_log.write("\n")
        train_log.close()

    """ Record Date & Time """
    datetime_object = str(datetime.datetime.now())
    print_and_save(train_log_path, datetime_object)
    print("")

    """ Hyperparameters """
    image_size = 256
    size = (image_size, image_size)
    batch_size = 16
    num_epochs = 70
    lr = 1e-5
    early_stopping_patience = 50
    checkpoint_path = "files/checkpoint1.pth"
    path = "/content/Pneumothorax"

    data_str = f"Image Size: {size}\nBatch Size: {batch_size}\nLR: {lr}\nEpochs: {num_epochs}\n"
    data_str += f"Early Stopping Patience: {early_stopping_patience}\n"
    print_and_save(train_log_path, data_str)

    """ Data augmentation: Transforms """
    transform = A.Compose([
        A.Rotate(limit=15, p=0.5),  # Moderate rotations
        A.HorizontalFlip(p=0.5),    # Horizontal flipping
        A.VerticalFlip(p=0.2),      # Vertical flipping
        A.RandomBrightnessContrast(p=0.5),  # Adjust brightness and contrast
        A.CLAHE(p=0.6),  # Contrast Limited Adaptive Histogram Equalization
        A.ElasticTransform(alpha=1, sigma=50, p=0.3),  # Elastic transformations
        A.CoarseDropout(num_holes_range=(2, 5), hole_height_range=(5, 20), hole_width_range=(5, 20), fill="inpaint_ns", p=0.5)  # Coarse dropout
    ])

    """ Dataset """
    (train_x, train_y, train_label), (valid_x, valid_y, valid_label) = load_data(path)
    train_x, train_y, train_label = shuffling(train_x, train_y, train_label)
    data_str = f"Dataset Size:\nTrain: {len(train_x)} - Valid: {len(valid_x)}\n"
    print_and_save(train_log_path, data_str)

    """ Dataset and loader """
    train_dataset = DATASET(train_x, train_label, train_y, (image_size, image_size), transform=transform)
    valid_dataset = DATASET(valid_x, valid_label, valid_y, (image_size, image_size), transform=None)

    train_loader = DataLoader(
        dataset=train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4
    )

    valid_loader = DataLoader(
        dataset=valid_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4
    )

    """ Model """
    device = torch.device('cuda')
    model = TGAlesionSeg()
    # model.apply(initialize_weights)
    model = model.to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6)
    scheduler = torch.optim.lr_scheduler.CyclicLR(
        optimizer,
        base_lr=1e-5,
        max_lr=1e-4,
        step_size_up=len(train_loader)*2,  # 2 epochs up, 2 epochs down
        mode='triangular',
        cycle_momentum=False
    )


    # Using Focal Loss for num_lesions & lesion_sizes
    loss_fn = [
        CascadingLoss(beta_dice=8, beta_focal=7),  # Primary segmentation loss
        FocalLoss(alpha=0.25, gamma=2),  # Num lesions classification
        FocalLoss(alpha=0.25, gamma=2)   # lesion size classification
    ]

    loss_name = "BCE Dice Loss"
    data_str = f"Optimizer: AdamW\nLoss: {loss_name}\n"
    print_and_save(train_log_path, data_str)

    """ Training the model """
    best_valid_metrics = 0.0
    early_stopping_count = 0

    for epoch in range(num_epochs):
        start_time = time.time()

        train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn, device)
        valid_loss, valid_metrics = evaluate(model, valid_loader, loss_fn, device)
        scheduler.step(valid_loss)

        if valid_metrics[1] > best_valid_metrics:
            data_str = f"Valid F1 improved from {best_valid_metrics:2.4f} to {valid_metrics[1]:2.4f}. Saving checkpoint: {checkpoint_path}"
            print_and_save(train_log_path, data_str)

            best_valid_metrics = valid_metrics[1]
            torch.save(model.state_dict(), checkpoint_path)
            early_stopping_count = 0

        elif valid_metrics[1] < best_valid_metrics:
            early_stopping_count += 1

        end_time = time.time()
        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        data_str = f"Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s\n"
        data_str += f"\tTrain Loss: {train_loss:.4f} - Jaccard: {train_metrics[0]:.4f} - F1: {train_metrics[1]:.4f} - Recall: {train_metrics[2]:.4f} - Precision: {train_metrics[3]:.4f}\n"
        data_str += f"\t Val. Loss: {valid_loss:.4f} - Jaccard: {valid_metrics[0]:.4f} - F1: {valid_metrics[1]:.4f} - Recall: {valid_metrics[2]:.4f} - Precision: {valid_metrics[3]:.4f}\n"
        print_and_save(train_log_path, data_str)

        if early_stopping_count == early_stopping_patience:
            data_str = f"Early stopping: validation loss stops improving from last {early_stopping_patience} continously.\n"
            print_and_save(train_log_path, data_str)
            break
# Out:
# 2025-03-10 22:13:27.681866
#
# Image Size: (256, 256)
# Batch Size: 16
# LR: 1e-05
# Epochs: 70
# Early Stopping Patience: 50
#
# {'polyp': ['zero', 'one', 'multiple', 'small', 'medium', 'large']}
# Dataset Size:
# Train: 9636 - Valid: 2409
#
# downloading https://nlp.h-its.org/bpemb/en/en.wiki.bpe.vs100000.model
# 100%|██████████| 1987533/1987533 [00:00<00:00, 2039043.56B/s]
# downloading https://nlp.h-its.org/bpemb/en/en.wiki.bpe.vs100000.d300.w2v.bin.tar.gz
# 100%|██████████| 112159933/112159933 [00:07<00:00, 15093736.52B/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/111M [00:00<?, ?B/s]
# Optimizer: AdamW
# Loss: BCE Dice Loss

# %%
import os
import random
import time
import datetime
import numpy as np
import albumentations as A
import cv2
from glob import glob
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from text2embed import Text2Embed
from utils import seeding, create_dir, print_and_save, shuffling, epoch_time, calculate_metrics, mask_to_bbox
from metrics import DiceLoss, DiceBCELoss, MultiClassBCE, FocalLoss
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from resnet import resnet50
import torch.nn.functional as F
# from torch.amp import autocast, GradScaler
import warnings
import torch.cuda.amp as amp
import torch.nn.init as init

class conv2d(nn.Module):
    def __init__(self, in_c, out_c, kernel_size=3, padding=1, dilation=1, act=True):
        super().__init__()
        self.act = act

        self.conv = nn.Sequential(
            nn.Conv2d(in_c, out_c, kernel_size, padding=padding, dilation=dilation, bias=False),
            nn.BatchNorm2d(out_c)
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        if self.act == True:
            x = self.relu(x)
        return x

class channel_attention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(channel_attention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x0 = x
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return x0 * self.sigmoid(out)


class spatial_attention(nn.Module):
    def __init__(self, kernel_size=7):
        super(spatial_attention, self).__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x0 = x
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return x0 * self.sigmoid(x)

class dilated_conv(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        self.c1 = nn.Sequential(conv2d(in_c, out_c, kernel_size=1, padding=0), channel_attention(out_c))
        self.c2 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=6, dilation=6), channel_attention(out_c))
        self.c3 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=12, dilation=12), channel_attention(out_c))
        self.c4 = nn.Sequential(conv2d(in_c, out_c, kernel_size=(3, 3), padding=18, dilation=18), channel_attention(out_c))
        self.c5 = conv2d(out_c*4, out_c, kernel_size=3, padding=1, act=False)
        self.c6 = conv2d(in_c, out_c, kernel_size=1, padding=0, act=False)
        self.sa = spatial_attention()

    def forward(self, x):
        x1 = self.c1(x)
        x2 = self.c2(x)
        x3 = self.c3(x)
        x4 = self.c4(x)
        xc = torch.cat([x1, x2, x3, x4], axis=1)
        xc = self.c5(xc)
        xs = self.c6(x)
        x = self.relu(xc+xs)
        x = self.sa(x)
        return x

class label_attention(nn.Module):
    def __init__(self, in_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        """ Channel Attention """
        self.c1 = nn.Sequential(
            nn.Conv2d(in_c[1], in_c[0], kernel_size=1, padding=0, bias=False),
            nn.ReLU(),
            nn.Conv2d(in_c[0], in_c[0], kernel_size=1, padding=0, bias=False)
        )

    def forward(self, feats, label):
        """ Channel Attention """
        b, c = label.shape
        label = label.reshape(b, c, 1, 1)
        ch_attn = self.c1(label)
        ch_map = torch.sigmoid(ch_attn)
        feats = feats * ch_map

        ch_attn = ch_attn.reshape(ch_attn.shape[0], ch_attn.shape[1])
        return ch_attn, feats

class decoder_block(nn.Module):
    def __init__(self, in_c, out_c, scale=2):
        super().__init__()
        self.scale = scale
        self.relu = nn.ReLU(inplace=True)

        self.up = nn.Upsample(scale_factor=scale, mode="bilinear", align_corners=True)
        self.c1 = conv2d(in_c+out_c, out_c, kernel_size=1, padding=0)
        self.c2 = conv2d(out_c, out_c, act=False)
        self.c3 = conv2d(out_c, out_c, act=False)
        self.c4 = conv2d(out_c, out_c, kernel_size=1, padding=0, act=False)
        self.ca = channel_attention(out_c)
        self.sa = spatial_attention()

    def forward(self, x, skip):
        x = self.up(x)
        x = torch.cat([x, skip], axis=1)
        x = self.c1(x)

        s1 = x
        x = self.c2(x)
        x = self.relu(x+s1)

        s2 = x
        x = self.c3(x)
        x = self.relu(x+s2+s1)

        s3 = x
        x = self.c4(x)
        x = self.relu(x+s3+s2+s1)

        x = self.ca(x)
        x = self.sa(x)
        return x

class output_block(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.up = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.c1 = nn.Conv2d(in_c, out_c, kernel_size=1, padding=0)

    def forward(self, x):
        x = self.up(x)
        x = self.c1(x)
        return x

class text_classifier(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc1 = nn.Sequential(
            nn.Linear(in_c, in_c//8, bias=False), nn.ReLU(),
            nn.Linear(in_c//8, out_c[0], bias=False)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(in_c, in_c//8, bias=False), nn.ReLU(),
            nn.Linear(in_c//8, out_c[1], bias=False)
        )

    def forward(self, feats):
        pool = self.avg_pool(feats).view(feats.shape[0], feats.shape[1])
        num_lesions = self.fc1(pool)
        lesion_sizes = self.fc2(pool)
        # print(f"num_lesions shape: {num_lesions.shape}")
        # print(f"lesion_sizes shape: {lesion_sizes.shape}")
        return num_lesions, lesion_sizes

class embedding_feature_fusion(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()

        self.fc = nn.Sequential(
            nn.Conv2d((in_c[0]+in_c[1])*in_c[2], out_c, 1, bias=False), nn.ReLU(),
            nn.Conv2d(out_c, out_c, 1, bias=False), nn.ReLU()
        )

    def forward(self, num_lesions, lesion_sizes, label):
        # print(f"num_lesions shape: {num_lesions.shape}")
        # print(f"lesion_sizes shape: {lesion_sizes.shape}")
        num_lesions_prob = torch.softmax(num_lesions, axis=1)
        lesion_sizes_prob = torch.softmax(lesion_sizes, axis=1)
        # print(f"num_lesions_classes", num_lesions_prob.shape)
        # print(f"lesions_size_classes", lesion_sizes_prob.shape)
        prob = torch.cat([num_lesions_prob, lesion_sizes_prob], axis=1)
        # print(f"prob shape: {prob.shape}")
        prob = prob.view(prob.shape[0], prob.shape[1], 1)
        if label.shape[1] != prob.shape[1]:
          raise ValueError(
              f"Shape mismatch: label channels ({label.shape[1]}) != prob channels ({prob.shape[1]})"
          )
        # print(f"x shape before fc: {x.shape}")
        x = label * prob
        x = x.view(x.shape[0], -1, 1, 1)
        if x.shape[1] != 1800:
            # x = torch.nn.functional.adaptive_avg_pool2d(x, (1, 1))  # Adjust spatial dimensions
            device = x.device  # Get the device of the input tensor
            conv_layer = torch.nn.Conv2d(x.shape[1], 1800, kernel_size=1).to(device)
            x = conv_layer(x)

        # print(f"x shape after fc: {x.shape}")
        x = self.fc(x)
        x = x.view(x.shape[0], -1)
        return x

class multiscale_feature_aggregation(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        self.up_2x2 = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        self.up_4x4 = nn.Upsample(scale_factor=4, mode="bilinear", align_corners=True)

        self.c11 = conv2d(in_c[0], out_c, kernel_size=1, padding=0)
        self.c12 = conv2d(in_c[1], out_c, kernel_size=1, padding=0)
        self.c13 = conv2d(in_c[2], out_c, kernel_size=1, padding=0)
        self.c14 = conv2d(out_c*3, out_c, kernel_size=1, padding=0)

        self.c2 = conv2d(out_c, out_c, act=False)
        self.c3 = conv2d(out_c, out_c, act=False)

    def forward(self, x1, x2, x3):
        x1 = self.up_4x4(x1)
        x2 = self.up_2x2(x2)

        x1 = self.c11(x1)
        x2 = self.c12(x2)
        x3 = self.c13(x3)
        x = torch.cat([x1, x2, x3], axis=1)
        x = self.c14(x)

        s1 = x
        x = self.c2(x)
        x = self.relu(x+s1)

        s2 = x
        x = self.c3(x)
        x = self.relu(x+s2+s1)

        return x

class ProgressiveDenoisingAttention1(nn.Module):
    def __init__(self, channels, num_iterations=3):
        super(ProgressiveDenoisingAttention1, self).__init__()
        self.num_iterations = num_iterations
        self.channels = channels

        # Convolution layers for refining attention
        self.conv_layers = nn.ModuleList([
            nn.Sequential(
                nn.Conv2d(channels, channels, kernel_size=3, padding=1, bias=False),
                nn.BatchNorm2d(channels),
                nn.ReLU(inplace=True)
            ) for _ in range(num_iterations)
        ])

        # Final attention map generation
        self.final_conv = nn.Conv2d(channels, 1, kernel_size=1, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # Initial attention map
        attention_map = x

        # Progressive denoising
        for conv in self.conv_layers:
            attention_map = conv(attention_map)

        # Final attention map
        attention_map = self.final_conv(attention_map)
        attention_map = self.sigmoid(attention_map)

        # Apply attention to input features
        return x * attention_map

class UNetDenoise(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.Conv2d(64, out_channels, kernel_size=3, padding=1),
            nn.ReLU(),
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

class TGAlesionSeg(nn.Module):
    def __init__(self):
        super().__init__()

        """ Backbone: ResNet50 """
        backbone = resnet50()
        self.layer0 = nn.Sequential(backbone.conv1, backbone.bn1, backbone.relu)
        self.layer1 = nn.Sequential(backbone.maxpool, backbone.layer1)
        self.layer2 = backbone.layer2
        self.layer3 = backbone.layer3

        self.text_classifier = text_classifier(1024, [3, 3])
        self.label_fc = embedding_feature_fusion([3, 3, 300], 128)

        """ Dilated Conv """
        self.s1 = dilated_conv(64, 128)
        self.s2 = dilated_conv(256, 128)
        self.s3 = dilated_conv(512, 128)
        self.s4 = dilated_conv(1024, 128)

        # """ Progressive Denoising Attention """
        self.pda1 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda2 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda3 = ProgressiveDenoisingAttention1(128, num_iterations=3)
        self.pda4 = ProgressiveDenoisingAttention1(128, num_iterations=3)

        """ U-Net Denoising Modules """
        self.denoise1 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise2 = UNetDenoise(in_channels=128, out_channels=128)
        self.denoise3 = UNetDenoise(in_channels=128, out_channels=128)

        """ Decoder """
        self.d1 = decoder_block(128, 128, scale=2)
        self.a1 = label_attention([128, 128])

        self.d2 = decoder_block(128, 128, scale=2)
        self.a2 = label_attention([128, 128])

        self.d3 = decoder_block(128, 128, scale=2)
        self.a3 = label_attention([128, 128])

        self.ag = multiscale_feature_aggregation([128, 128, 128], 128)

        self.y1 = output_block(128, 1)

    def forward(self, image, label):
        """ Backbone: ResNet50 """
        x0 = image
        x1 = self.layer0(x0)    ## [-1, 64, h/2, w/2]
        x2 = self.layer1(x1)    ## [-1, 256, h/4, w/4]
        x3 = self.layer2(x2)    ## [-1, 512, h/8, w/8]
        x4 = self.layer3(x3)    ## [-1, 1024, h/16, w/16]
        # print(x1.shape, x2.shape, x3.shape, x4.shape, x5.shape)

        num_lesions, lesion_sizes = self.text_classifier(x4)
        f0 = self.label_fc(num_lesions, lesion_sizes, label)

        # """ Dilated Conv + PDA """
        s1 = self.pda1(self.s1(x1))
        s2 = self.pda2(self.s2(x2))
        s3 = self.pda3(self.s3(x3))
        s4 = self.pda4(self.s4(x4))

        """ Decoder + Denoising """
        # Stage 1
        d1 = self.d1(s4, s3)
        f1, a1 = self.a1(d1, f0)
        a1_denoised = self.denoise1(a1)  # Apply PDA for a1

        # Stage 2
        d2 = self.d2(a1_denoised, s2)
        f = f0 + f1
        f2, a2 = self.a2(d2, f)
        a2_denoised = self.denoise2(a2)  # Apply PDA for a2

        # Stage 3
        d3 = self.d3(a2_denoised, s1)
        f = f0 + f1 + f2
        f3, a3 = self.a3(d3, f)
        a3_denoised = self.denoise3(a3)  # Apply PDA for a3

        ag = self.ag(a1_denoised, a2_denoised, a3_denoised)
        y1 = self.y1(ag)


        return y1, num_lesions, lesion_sizes

def prepare_input(res):
    x1 = torch.FloatTensor(1, 3, 256, 256).cuda()
    x2 = torch.FloatTensor(1, 5, 300).cuda()
    return dict(x = [x1, x2])

### --------------------------------------------------------------------------------------------------------------------------------------------------------

def load_names(path, file_path):
    f = open(file_path, "r")
    data = f.read().split("\n")[:-1]
    images = [os.path.join(path,"images", name) + ".png" for name in data]
    masks = [os.path.join(path,"masks", name) + ".png" for name in data]
    return images, masks

def label_dictionary():
    label_dict = {}
    label_dict["lesion"] = ["zero", "one", "multiple", "small", "medium", "large"]
    return label_dict

def load_data(path):
    train_names_path = f"{path}/train.txt"
    valid_names_path = f"{path}/val.txt"

    train_x, train_y = load_names(path, train_names_path)
    valid_x, valid_y = load_names(path, valid_names_path)

    label_dict = label_dictionary()
    print(label_dict)
    train_label = len(train_x) * [label_dict["lesion"]]
    valid_label = len(valid_x) * [label_dict["lesion"]]

    return (train_x, train_y, train_label), (valid_x, valid_y, valid_label)

class DATASET(Dataset):
    def __init__(self, images_path, labels_path, masks_path, size, transform=None):
        super().__init__()
        self.images_path = images_path
        self.labels_path = labels_path
        self.masks_path = masks_path
        self.size = size  # Ensure size is stored as an instance attribute
        self.transform = transform
        self.n_samples = len(images_path)

        self.embed = Text2Embed()

    def visualize_bbox_on_mask(self, image, mask, bboxes, title="Mask with BBoxes"):
        """Visualize the mask and bounding boxes overlaid on the mask."""
        if len(image.shape) != 3 or image.shape[2] != 3:
            raise ValueError(f"Expected a color image with 3 channels, but got shape {image.shape}")

        fig, ax = plt.subplots(1, 2, figsize=(12, 6))

        # Show original image
        ax[0].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        ax[0].set_title("Original Image")
        ax[0].axis("off")

        # Show mask with bounding boxes
        mask_with_bbox = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
        for bbox in bboxes:
            x1, y1, x2, y2 = bbox
            mask_with_bbox = cv2.rectangle(mask_with_bbox, (x1, y1), (x2, y2), (255, 0, 0), 2)

        ax[1].imshow(cv2.cvtColor(mask_with_bbox, cv2.COLOR_BGR2RGB))
        ax[1].set_title(title)
        ax[1].axis("off")

        plt.tight_layout()
        plt.show()


    def mask_to_text(self, mask, image=None):
        bboxes = mask_to_bbox(mask)
        lesion_sizes = 0
        num_lesions = 0

        # Calculate sizes and number of lesions
        for bbox in bboxes:
            x1, y1, x2, y2 = bbox
            h = (y2 - y1)
            w = (x2 - x1)
            area = (h * w) / (mask.shape[0] * mask.shape[1])

            if area < 0.007:
                lesion_sizes = 0
            elif 0.007 <= area < 0.04:
                lesion_sizes = 1
            elif area >= 0.04:
                lesion_sizes = 2

        if(len(bboxes) == 0):
          num_lesions = 0
        elif(len(bboxes) == 1):
          num_lesions = 1
        elif(len(bboxes) >= 2):
          num_lesions = 2

        # visualization
        if image is None:
            self.visualize_bbox_on_mask(image, mask, bboxes, title="Mask with Bounding Boxes")

        return np.array(num_lesions), np.array(lesion_sizes)


    def __getitem__(self, index):
      image = cv2.imread(self.images_path[index], cv2.IMREAD_COLOR)
      mask = cv2.imread(self.masks_path[index], cv2.IMREAD_GRAYSCALE)

      if image is None or mask is None:
          raise FileNotFoundError(f"Could not read image or mask at index {index}. Check the file paths.")

      if self.transform is not None:
          augmentations = self.transform(image=image, mask=mask)
          image = augmentations["image"]
          mask = augmentations["mask"]

      image = cv2.resize(image, self.size)
      if len(image.shape) != 3 or image.shape[2] != 3:
          raise ValueError(f"Expected a color image with 3 channels after resizing, but got shape {image.shape}")

      image = np.transpose(image, (2, 0, 1))
      image = image / 255.0

      mask = cv2.resize(mask, self.size)
      mask_copy = mask
      mask = np.expand_dims(mask, axis=0)
      mask = mask / 255.0

      visual_image = (image.transpose(1, 2, 0) * 255).astype(np.uint8)
      num_lesions, lesion_sizes = self.mask_to_text(mask_copy, visual_image)

      # print(f"image = {self.images_path[index]}\n")
      # print(f"mask = {self.masks_path[index]}\n"print(np.unique(labels))  # Confirm number and range of classes.
      label = []
      words = self.labels_path[index]
      for word in words:
          word_embed = self.embed.to_embed(word)[0]
          label.append(word_embed)
      label = np.array(label)
      # print(f"label shape: {label.shape}")
      # print(np.unique(label))  # Confirm number and range of classes.

      return (image, label), (mask, num_lesions, lesion_sizes)

    def __len__(self):
        return self.n_samples


def train(model, loader, optimizer, loss_fn, device):
    model.train()
    epoch_loss = 0.0
    epoch_jac = 0.0
    epoch_f1 = 0.0
    epoch_recall = 0.0
    epoch_precision = 0.0
    # scaler = amp.GradScaler()  # Define scaler before training

    for i, ((x, l), (y1, y2, y3)) in enumerate(loader):
        x = x.to(device, dtype=torch.float32)
        l = l.to(device, dtype=torch.float32)
        y1 = y1.to(device, dtype=torch.float32)
        y2 = y2.to(device, dtype=torch.long)
        y3 = y3.to(device, dtype=torch.long)

        optimizer.zero_grad()
     
        p1, p2, p3 = model(x, l)
        p2 = torch.softmax(p2, dim=1)
        p3 = torch.softmax(p3, dim=1)

        loss1 = loss_fn[0](p1, y1)
        loss2 = loss_fn[1](p2, y2)
        loss3 = loss_fn[2](p3, y3)

        loss = loss1 + loss2 + loss3

        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

        batch_jac = []
        batch_f1 = []
        batch_recall = []
        batch_precision = []

        for yt, yp in zip(y1, p1):
            score = calculate_metrics(yt, yp)
            batch_jac.append(score[0])
            batch_f1.append(score[1])
            batch_recall.append(score[2])
            batch_precision.append(score[3])

        epoch_jac += np.mean(batch_jac)
        epoch_f1 += np.mean(batch_f1)
        epoch_recall += np.mean(batch_recall)
        epoch_precision += np.mean(batch_precision)

    epoch_loss = epoch_loss / len(loader)
    epoch_jac = epoch_jac / len(loader)
    epoch_f1 = epoch_f1 / len(loader)
    epoch_recall = epoch_recall / len(loader)
    epoch_precision = epoch_precision / len(loader)

    return epoch_loss, [epoch_jac, epoch_f1, epoch_recall, epoch_precision]

def evaluate(model, loader, loss_fn, device):
    model.eval()

    epoch_loss = 0.0
    epoch_jac = 0.0
    epoch_f1 = 0.0
    epoch_recall = 0.0
    epoch_precision = 0.0

    with torch.no_grad():
        for i, ((x, l), (y1, y2, y3)) in enumerate(loader):
            x = x.to(device, dtype=torch.float32)
            l = l.to(device, dtype=torch.float32)
            y1 = y1.to(device, dtype=torch.float32)
            y2 = y2.to(device, dtype=torch.long)
            y3 = y3.to(device, dtype=torch.long)

            p1, p2, p3 = model(x, l)
            p2 = torch.softmax(p2, dim=1)
            p3 = torch.softmax(p3, dim=1)

            loss1 = loss_fn[0](p1, y1)
            loss2 = loss_fn[1](p2, y2)
            loss3 = loss_fn[2](p3, y3)

            loss = loss1 + loss2 + loss3

            epoch_loss += loss.item()

            batch_jac = []
            batch_f1 = []
            batch_recall = []
            batch_precision = []

            for yt, yp in zip(y1, p1):
                score = calculate_metrics(yt, yp)
                batch_jac.append(score[0])
                batch_f1.append(score[1])
                batch_recall.append(score[2])
                batch_precision.append(score[3])

            epoch_jac += np.mean(batch_jac)
            epoch_f1 += np.mean(batch_f1)
            epoch_recall += np.mean(batch_recall)
            epoch_precision += np.mean(batch_precision)

    epoch_loss = epoch_loss / len(loader)
    epoch_jac = epoch_jac / len(loader)
    epoch_f1 = epoch_f1 / len(loader)
    epoch_recall = epoch_recall / len(loader)
    epoch_precision = epoch_precision / len(loader)

    return epoch_loss, [epoch_jac, epoch_f1, epoch_recall, epoch_precision]

if __name__ == "__main__":
    """ Seeding """
    seeding(42)

    """ Directories """
    create_dir("files")

    """ Training logfile """
    train_log_path = "files/train_log.txt"
    if os.path.exists(train_log_path):
        print("Log file exists")
    else:
        train_log = open("files/train_log.txt", "w")
        train_log.write("\n")
        train_log.close()

    """ Record Date & Time """
    datetime_object = str(datetime.datetime.now())
    print_and_save(train_log_path, datetime_object)
    print("")

    """ Hyperparameters """
    image_size = 256
    size = (image_size, image_size)
    batch_size = 16
    num_epochs = 70
    lr = 1e-4
    early_stopping_patience = 70
    checkpoint_path = "/content/checkpoint1 (7).pth"
    path = "/content/Pneumothorax"

    data_str = f"Image Size: {size}\nBatch Size: {batch_size}\nLR: {lr}\nEpochs: {num_epochs}\n"
    data_str += f"Early Stopping Patience: {early_stopping_patience}\n"
    print_and_save(train_log_path, data_str)

    """ Data augmentation: Transforms """
    transform = A.Compose([
        A.Rotate(limit=15, p=0.5),  # Moderate rotations
        A.HorizontalFlip(p=0.5),    # Horizontal flipping
        A.VerticalFlip(p=0.2),      # Vertical flipping
        A.RandomBrightnessContrast(p=0.3),  # Adjust brightness and contrast
        A.CLAHE(p=0.3),  # Contrast Limited Adaptive Histogram Equalization
        A.ElasticTransform(alpha=1, sigma=50, p=0.3),  # Elastic transformations
        A.CoarseDropout(num_holes_range=(2, 5), hole_height_range=(5, 20), hole_width_range=(5, 20), fill="inpaint_ns", p=0.5)  # Coarse dropout
    ])

    """ Dataset """
    (train_x, train_y, train_label), (valid_x, valid_y, valid_label) = load_data(path)
    train_x, train_y, train_label = shuffling(train_x, train_y, train_label)
    data_str = f"Dataset Size:\nTrain: {len(train_x)} - Valid: {len(valid_x)}\n"
    print_and_save(train_log_path, data_str)

    """ Dataset and loader """
    train_dataset = DATASET(train_x, train_label, train_y, (image_size, image_size), transform=transform)
    valid_dataset = DATASET(valid_x, valid_label, valid_y, (image_size, image_size), transform=None)

    train_loader = DataLoader(
        dataset=train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4
    )

    valid_loader = DataLoader(
        dataset=valid_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4
    )

    """ Model """
    device = torch.device('cuda')
    model = TGAlesionSeg()
    model = model.to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3)
    # scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6)
    # loss_fn = [DiceBCELoss(), nn.CrossEntropyLoss(), nn.CrossEntropyLoss()]
    # Using Focal Loss for num_lesions & lesion_sizes
    loss_fn = [DiceBCELoss(), FocalLoss(alpha=0.25, gamma=2), FocalLoss(alpha=0.25, gamma=2)]

    loss_name = "BCE Dice Loss"
    data_str = f"Optimizer: AdamW\nLoss: {loss_name}\n"
    print_and_save(train_log_path, data_str)


    try:
        model.load_state_dict(torch.load(checkpoint_path))
        print(f"Checkpoint loaded successfully from {checkpoint_path}. Resuming training.")
    except Exception as e:
        print(f"Error loading checkpoint: {e}")

    """ Training the model """
    best_valid_metrics = 0.8155  ## update the last metric you have accordingly
    early_stopping_count = 0

    # Logging
    data_str = f"Resuming training from checkpoint.\nOptimizer: Adam\nLoss: {loss_name}\n"
    print_and_save(train_log_path, data_str)

    # Resume training
    for epoch in range(num_epochs):  # Update resume_epoch appropriately
        start_time = time.time()

        train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn, device)
        valid_loss, valid_metrics = evaluate(model, valid_loader, loss_fn, device)
        scheduler.step(valid_loss)

        if valid_metrics[1] > best_valid_metrics:
            data_str = f"Valid F1 improved from {best_valid_metrics:2.4f} to {valid_metrics[1]:2.4f}. Saving checkpoint: {checkpoint_path}"
            print_and_save(train_log_path, data_str)

            best_valid_metrics = valid_metrics[1]
            torch.save(model.state_dict(), checkpoint_path)
            early_stopping_count = 0

        elif valid_metrics[1] < best_valid_metrics:
            early_stopping_count += 1

        end_time = time.time()
        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        data_str = f"Epoch: {epoch+1:02} | Epoch Time: {epoch_mins}m {epoch_secs}s\n"
        data_str += f"\tTrain Loss: {train_loss:.4f} - Jaccard: {train_metrics[0]:.4f} - F1: {train_metrics[1]:.4f} - Recall: {train_metrics[2]:.4f} - Precision: {train_metrics[3]:.4f}\n"
        data_str += f"\t Val. Loss: {valid_loss:.4f} - Jaccard: {valid_metrics[0]:.4f} - F1: {valid_metrics[1]:.4f} - Recall: {valid_metrics[2]:.4f} - Precision: {valid_metrics[3]:.4f}\n"
        print_and_save(train_log_path, data_str)

        if early_stopping_count == early_stopping_patience:
            data_str = f"Early stopping: validation loss stops improving from last {early_stopping_patience} continuously.\n"
            print_and_save(train_log_path, data_str)
            break
# Out:
# 2025-02-16 09:55:12.272669
#
# Image Size: (256, 256)
# Batch Size: 16
# LR: 0.0001
# Epochs: 70
# Early Stopping Patience: 70
#
# {'polyp': ['zero', 'one', 'multiple', 'small', 'medium', 'large']}
# Dataset Size:
# Train: 9636 - Valid: 2409
#
# downloading https://nlp.h-its.org/bpemb/en/en.wiki.bpe.vs100000.model
# 100%|██████████| 1987533/1987533 [00:00<00:00, 2180635.77B/s]
# downloading https://nlp.h-its.org/bpemb/en/en.wiki.bpe.vs100000.d300.w2v.bin.tar.gz
# 100%|██████████| 112159933/112159933 [00:05<00:00, 19427886.86B/s]
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 222MB/s]
# Optimizer: AdamW
# Loss: BCE Dice Loss
#
# Checkpoint loaded successfully from /content/checkpoint1 (7).pth. Resuming training.
# Resuming training from checkpoint.
# Optimizer: Adam
# Loss: BCE Dice Loss
# <ipython-input-3-910233340c5c>:810: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path))
# Epoch: 01 | Epoch Time: 11m 57s
# 	Train Loss: 0.7596 - Jaccard: 0.7367 - F1: 0.7549 - Recall: 0.8552 - Precision: 0.8426
# 	 Val. Loss: 0.8292 - Jaccard: 0.6834 - F1: 0.7029 - Recall: 0.8864 - Precision: 0.7540
#
# Epoch: 02 | Epoch Time: 11m 58s
# 	Train Loss: 0.7639 - Jaccard: 0.7392 - F1: 0.7571 - Recall: 0.8532 - Precision: 0.8499
# 	 Val. Loss: 0.7556 - Jaccard: 0.7696 - F1: 0.7888 - Recall: 0.8697 - Precision: 0.8588
#
# Epoch: 03 | Epoch Time: 11m 58s
# 	Train Loss: 0.7489 - Jaccard: 0.7445 - F1: 0.7619 - Recall: 0.8531 - Precision: 0.8552
# 	 Val. Loss: 0.7887 - Jaccard: 0.8000 - F1: 0.8138 - Recall: 0.8439 - Precision: 0.9316
#
# Epoch: 04 | Epoch Time: 11m 59s
# 	Train Loss: 0.7352 - Jaccard: 0.7510 - F1: 0.7687 - Recall: 0.8542 - Precision: 0.8632
# 	 Val. Loss: 0.7296 - Jaccard: 0.7860 - F1: 0.8030 - Recall: 0.8540 - Precision: 0.9019
#
# Epoch: 05 | Epoch Time: 11m 58s
# 	Train Loss: 0.7357 - Jaccard: 0.7361 - F1: 0.7560 - Recall: 0.8619 - Precision: 0.8350
# 	 Val. Loss: 0.7604 - Jaccard: 0.7993 - F1: 0.8150 - Recall: 0.8555 - Precision: 0.9164
#
# Epoch: 06 | Epoch Time: 11m 58s
# 	Train Loss: 0.7427 - Jaccard: 0.7451 - F1: 0.7641 - Recall: 0.8600 - Precision: 0.8486
# 	 Val. Loss: 0.7418 - Jaccard: 0.7638 - F1: 0.7833 - Recall: 0.8784 - Precision: 0.8507
#
# Epoch: 07 | Epoch Time: 11m 58s
# 	Train Loss: 0.7451 - Jaccard: 0.7387 - F1: 0.7574 - Recall: 0.8587 - Precision: 0.8419
# 	 Val. Loss: 0.7234 - Jaccard: 0.7682 - F1: 0.7876 - Recall: 0.8666 - Precision: 0.8617
#
# Valid F1 improved from 0.8155 to 0.8168. Saving checkpoint: /content/checkpoint1 (7).pth
# Epoch: 08 | Epoch Time: 11m 59s
# 	Train Loss: 0.7201 - Jaccard: 0.7560 - F1: 0.7751 - Recall: 0.8618 - Precision: 0.8573
# 	 Val. Loss: 0.7459 - Jaccard: 0.8020 - F1: 0.8168 - Recall: 0.8469 - Precision: 0.9322
#
# Epoch: 09 | Epoch Time: 11m 58s
# 	Train Loss: 0.7056 - Jaccard: 0.7575 - F1: 0.7770 - Recall: 0.8628 - Precision: 0.8606
# 	 Val. Loss: 0.8386 - Jaccard: 0.6737 - F1: 0.6956 - Recall: 0.9047 - Precision: 0.7221
#
# Epoch: 10 | Epoch Time: 11m 58s
# 	Train Loss: 0.7027 - Jaccard: 0.7562 - F1: 0.7758 - Recall: 0.8635 - Precision: 0.8582
# 	 Val. Loss: 0.7278 - Jaccard: 0.7347 - F1: 0.7545 - Recall: 0.8749 - Precision: 0.8208
#
# Epoch: 11 | Epoch Time: 11m 58s
# 	Train Loss: 0.7231 - Jaccard: 0.7418 - F1: 0.7608 - Recall: 0.8583 - Precision: 0.8470
# 	 Val. Loss: 0.7282 - Jaccard: 0.7772 - F1: 0.7953 - Recall: 0.8649 - Precision: 0.8781
#
# Epoch: 12 | Epoch Time: 11m 58s
# 	Train Loss: 0.6636 - Jaccard: 0.7668 - F1: 0.7879 - Recall: 0.8701 - Precision: 0.8594
# 	 Val. Loss: 0.6867 - Jaccard: 0.7840 - F1: 0.8035 - Recall: 0.8737 - Precision: 0.8745
#
# Epoch: 13 | Epoch Time: 11m 58s
# 	Train Loss: 0.6449 - Jaccard: 0.7786 - F1: 0.7993 - Recall: 0.8695 - Precision: 0.8749
# 	 Val. Loss: 0.6815 - Jaccard: 0.7919 - F1: 0.8112 - Recall: 0.8720 - Precision: 0.8836
#
# Valid F1 improved from 0.8168 to 0.8197. Saving checkpoint: /content/checkpoint1 (7).pth
# Epoch: 14 | Epoch Time: 11m 59s
# 	Train Loss: 0.6567 - Jaccard: 0.7781 - F1: 0.7982 - Recall: 0.8669 - Precision: 0.8799
# 	 Val. Loss: 0.6793 - Jaccard: 0.8012 - F1: 0.8197 - Recall: 0.8677 - Precision: 0.9022
#
# Epoch: 15 | Epoch Time: 11m 58s
# 	Train Loss: 0.6480 - Jaccard: 0.7818 - F1: 0.8025 - Recall: 0.8712 - Precision: 0.8778
# 	 Val. Loss: 0.6684 - Jaccard: 0.7851 - F1: 0.8056 - Recall: 0.8799 - Precision: 0.8659
#
# Epoch: 16 | Epoch Time: 11m 58s
# 	Train Loss: 0.6392 - Jaccard: 0.7868 - F1: 0.8072 - Recall: 0.8693 - Precision: 0.8859
# 	 Val. Loss: 0.6711 - Jaccard: 0.7985 - F1: 0.8172 - Recall: 0.8692 - Precision: 0.8970
#
# Epoch: 17 | Epoch Time: 11m 58s
# 	Train Loss: 0.6234 - Jaccard: 0.7890 - F1: 0.8103 - Recall: 0.8729 - Precision: 0.8849
# 	 Val. Loss: 0.6672 - Jaccard: 0.7937 - F1: 0.8131 - Recall: 0.8762 - Precision: 0.8820
#
# Epoch: 18 | Epoch Time: 11m 58s
# 	Train Loss: 0.6276 - Jaccard: 0.7906 - F1: 0.8111 - Recall: 0.8698 - Precision: 0.8902
# 	 Val. Loss: 0.6651 - Jaccard: 0.7792 - F1: 0.8003 - Recall: 0.8851 - Precision: 0.8538
#
# Valid F1 improved from 0.8197 to 0.8200. Saving checkpoint: /content/checkpoint1 (7).pth
# Epoch: 19 | Epoch Time: 11m 59s
# 	Train Loss: 0.6273 - Jaccard: 0.7884 - F1: 0.8098 - Recall: 0.8758 - Precision: 0.8787
# 	 Val. Loss: 0.6686 - Jaccard: 0.8013 - F1: 0.8200 - Recall: 0.8680 - Precision: 0.8974
#
# Epoch: 20 | Epoch Time: 11m 58s
# 	Train Loss: 0.6258 - Jaccard: 0.7885 - F1: 0.8096 - Recall: 0.8743 - Precision: 0.8821
# 	 Val. Loss: 0.6560 - Jaccard: 0.7842 - F1: 0.8052 - Recall: 0.8818 - Precision: 0.8617
#
# Epoch: 21 | Epoch Time: 11m 58s
# 	Train Loss: 0.6222 - Jaccard: 0.7946 - F1: 0.8145 - Recall: 0.8703 - Precision: 0.8952
# 	 Val. Loss: 0.6625 - Jaccard: 0.7962 - F1: 0.8156 - Recall: 0.8722 - Precision: 0.8886
#
# Epoch: 22 | Epoch Time: 11m 58s
# 	Train Loss: 0.6135 - Jaccard: 0.7986 - F1: 0.8196 - Recall: 0.8728 - Precision: 0.8960
# 	 Val. Loss: 0.6623 - Jaccard: 0.7816 - F1: 0.8024 - Recall: 0.8829 - Precision: 0.8582
#
# Epoch: 23 | Epoch Time: 11m 58s
# 	Train Loss: 0.6107 - Jaccard: 0.7975 - F1: 0.8184 - Recall: 0.8742 - Precision: 0.8937
# 	 Val. Loss: 0.6608 - Jaccard: 0.7928 - F1: 0.8128 - Recall: 0.8787 - Precision: 0.8786
#
# Epoch: 24 | Epoch Time: 11m 58s
# 	Train Loss: 0.6089 - Jaccard: 0.7957 - F1: 0.8171 - Recall: 0.8759 - Precision: 0.8870
# 	 Val. Loss: 0.6594 - Jaccard: 0.7821 - F1: 0.8028 - Recall: 0.8803 - Precision: 0.8610
#
# Epoch: 25 | Epoch Time: 11m 58s
# 	Train Loss: 0.6073 - Jaccard: 0.7960 - F1: 0.8177 - Recall: 0.8765 - Precision: 0.8886
# 	 Val. Loss: 0.6585 - Jaccard: 0.7903 - F1: 0.8105 - Recall: 0.8765 - Precision: 0.8734
#
# Epoch: 26 | Epoch Time: 11m 58s
# 	Train Loss: 0.6083 - Jaccard: 0.8015 - F1: 0.8227 - Recall: 0.8751 - Precision: 0.8957
# 	 Val. Loss: 0.6572 - Jaccard: 0.7961 - F1: 0.8158 - Recall: 0.8751 - Precision: 0.8831
#
# Epoch: 27 | Epoch Time: 11m 58s
# 	Train Loss: 0.6245 - Jaccard: 0.7954 - F1: 0.8167 - Recall: 0.8750 - Precision: 0.8880
# 	 Val. Loss: 0.6542 - Jaccard: 0.7875 - F1: 0.8081 - Recall: 0.8803 - Precision: 0.8671
#
# Epoch: 28 | Epoch Time: 11m 58s
# 	Train Loss: 0.6092 - Jaccard: 0.8009 - F1: 0.8221 - Recall: 0.8759 - Precision: 0.8945
# 	 Val. Loss: 0.6557 - Jaccard: 0.7968 - F1: 0.8162 - Recall: 0.8744 - Precision: 0.8862
#
# Epoch: 29 | Epoch Time: 11m 58s
# 	Train Loss: 0.6092 - Jaccard: 0.7978 - F1: 0.8193 - Recall: 0.8769 - Precision: 0.8920
# 	 Val. Loss: 0.6532 - Jaccard: 0.7948 - F1: 0.8148 - Recall: 0.8775 - Precision: 0.8792
#
# Epoch: 30 | Epoch Time: 11m 58s
# 	Train Loss: 0.6016 - Jaccard: 0.8010 - F1: 0.8223 - Recall: 0.8763 - Precision: 0.8933
# 	 Val. Loss: 0.6532 - Jaccard: 0.7975 - F1: 0.8171 - Recall: 0.8752 - Precision: 0.8847
#
# Epoch: 31 | Epoch Time: 11m 58s
# 	Train Loss: 0.6045 - Jaccard: 0.8013 - F1: 0.8225 - Recall: 0.8754 - Precision: 0.8948
# 	 Val. Loss: 0.6552 - Jaccard: 0.7970 - F1: 0.8164 - Recall: 0.8740 - Precision: 0.8869
#
# Epoch: 32 | Epoch Time: 11m 59s
# 	Train Loss: 0.6026 - Jaccard: 0.8025 - F1: 0.8233 - Recall: 0.8738 - Precision: 0.8984
# 	 Val. Loss: 0.6561 - Jaccard: 0.7950 - F1: 0.8147 - Recall: 0.8753 - Precision: 0.8828
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-910233340c5c> in <cell line: 0>()
#     825         start_time = time.time()
#     826
# --> 827         train_loss, train_metrics = train(model, train_loader, optimizer, loss_fn, device)
#     828         valid_loss, valid_metrics = evaluate(model, valid_loader, loss_fn, device)
#     829         scheduler.step(valid_loss)
#
# <ipython-input-3-910233340c5c> in train(model, loader, optimizer, loss_fn, device)
#     647
#     648         for yt, yp in zip(y1, p1):
# --> 649             score = calculate_metrics(yt, yp)
#     650             batch_jac.append(score[0])
#     651             batch_f1.append(score[1])
#
# /content/utils.py in calculate_metrics(y_true, y_pred)
#      97     score_precision = precision(y_true, y_pred)
#      98     score_fbeta = F2(y_true, y_pred)
# ---> 99     score_acc = accuracy_score(y_true, y_pred)
#     100     dice = dice_score(y_true, y_pred)  # Calculate Dice Coefficient
#     101
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     226     y_true, y_pred = attach_unique(y_true, y_pred)
#     227     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# --> 228     check_consistent_length(y_true, y_pred, sample_weight)
#     229
#     230     if y_type.startswith("multilabel"):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     470     """
#     471
# --> 472     lengths = [_num_samples(X) for X in arrays if X is not None]
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     470     """
#     471
# --> 472     lengths = [_num_samples(X) for X in arrays if X is not None]
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
#
# KeyboardInterrupt:

# %% [markdown]
# Epoch: 01 | Epoch Time: 11m 57s
# 	Train Loss: 0.7596 - Jaccard: 0.7367 - F1: 0.7549 - Recall: 0.8552 - Precision: 0.8426
# 	 Val. Loss: 0.8292 - Jaccard: 0.6834 - F1: 0.7029 - Recall: 0.8864 - Precision: 0.7540
#
# Epoch: 02 | Epoch Time: 11m 58s
# 	Train Loss: 0.7639 - Jaccard: 0.7392 - F1: 0.7571 - Recall: 0.8532 - Precision: 0.8499
# 	 Val. Loss: 0.7556 - Jaccard: 0.7696 - F1: 0.7888 - Recall: 0.8697 - Precision: 0.8588
#
# Epoch: 03 | Epoch Time: 11m 58s
# 	Train Loss: 0.7489 - Jaccard: 0.7445 - F1: 0.7619 - Recall: 0.8531 - Precision: 0.8552
# 	 Val. Loss: 0.7887 - Jaccard: 0.8000 - F1: 0.8138 - Recall: 0.8439 - Precision: 0.9316
#
# Epoch: 04 | Epoch Time: 11m 59s
# 	Train Loss: 0.7352 - Jaccard: 0.7510 - F1: 0.7687 - Recall: 0.8542 - Precision: 0.8632
# 	 Val. Loss: 0.7296 - Jaccard: 0.7860 - F1: 0.8030 - Recall: 0.8540 - Precision: 0.9019
#
# Epoch: 05 | Epoch Time: 11m 58s
# 	Train Loss: 0.7357 - Jaccard: 0.7361 - F1: 0.7560 - Recall: 0.8619 - Precision: 0.8350
# 	 Val. Loss: 0.7604 - Jaccard: 0.7993 - F1: 0.8150 - Recall: 0.8555 - Precision: 0.9164
#
# Epoch: 06 | Epoch Time: 11m 58s
# 	Train Loss: 0.7427 - Jaccard: 0.7451 - F1: 0.7641 - Recall: 0.8600 - Precision: 0.8486
# 	 Val. Loss: 0.7418 - Jaccard: 0.7638 - F1: 0.7833 - Recall: 0.8784 - Precision: 0.8507
#
# Epoch: 07 | Epoch Time: 11m 58s
# 	Train Loss: 0.7451 - Jaccard: 0.7387 - F1: 0.7574 - Recall: 0.8587 - Precision: 0.8419
# 	 Val. Loss: 0.7234 - Jaccard: 0.7682 - F1: 0.7876 - Recall: 0.8666 - Precision: 0.8617
#
# Valid F1 improved from 0.8155 to 0.8168. Saving checkpoint: /content/checkpoint1 (7).pth
# Epoch: 08 | Epoch Time: 11m 59s
# 	Train Loss: 0.7201 - Jaccard: 0.7560 - F1: 0.7751 - Recall: 0.8618 - Precision: 0.8573
# 	 Val. Loss: 0.7459 - Jaccard: 0.8020 - F1: 0.8168 - Recall: 0.8469 - Precision: 0.9322
#
# Epoch: 09 | Epoch Time: 11m 58s
# 	Train Loss: 0.7056 - Jaccard: 0.7575 - F1: 0.7770 - Recall: 0.8628 - Precision: 0.8606
# 	 Val. Loss: 0.8386 - Jaccard: 0.6737 - F1: 0.6956 - Recall: 0.9047 - Precision: 0.7221
#
# Epoch: 10 | Epoch Time: 11m 58s
# 	Train Loss: 0.7027 - Jaccard: 0.7562 - F1: 0.7758 - Recall: 0.8635 - Precision: 0.8582
# 	 Val. Loss: 0.7278 - Jaccard: 0.7347 - F1: 0.7545 - Recall: 0.8749 - Precision: 0.8208
#
# Epoch: 11 | Epoch Time: 11m 58s
# 	Train Loss: 0.7231 - Jaccard: 0.7418 - F1: 0.7608 - Recall: 0.8583 - Precision: 0.8470
# 	 Val. Loss: 0.7282 - Jaccard: 0.7772 - F1: 0.7953 - Recall: 0.8649 - Precision: 0.8781
#
# Epoch: 12 | Epoch Time: 11m 58s
# 	Train Loss: 0.6636 - Jaccard: 0.7668 - F1: 0.7879 - Recall: 0.8701 - Precision: 0.8594
# 	 Val. Loss: 0.6867 - Jaccard: 0.7840 - F1: 0.8035 - Recall: 0.8737 - Precision: 0.8745
#
# Epoch: 13 | Epoch Time: 11m 58s
# 	Train Loss: 0.6449 - Jaccard: 0.7786 - F1: 0.7993 - Recall: 0.8695 - Precision: 0.8749
# 	 Val. Loss: 0.6815 - Jaccard: 0.7919 - F1: 0.8112 - Recall: 0.8720 - Precision: 0.8836
#
# Valid F1 improved from 0.8168 to 0.8197. Saving checkpoint: /content/checkpoint1 (7).pth
# Epoch: 14 | Epoch Time: 11m 59s
# 	Train Loss: 0.6567 - Jaccard: 0.7781 - F1: 0.7982 - Recall: 0.8669 - Precision: 0.8799
# 	 Val. Loss: 0.6793 - Jaccard: 0.8012 - F1: 0.8197 - Recall: 0.8677 - Precision: 0.9022
#
# Epoch: 15 | Epoch Time: 11m 58s
# 	Train Loss: 0.6480 - Jaccard: 0.7818 - F1: 0.8025 - Recall: 0.8712 - Precision: 0.8778
# 	 Val. Loss: 0.6684 - Jaccard: 0.7851 - F1: 0.8056 - Recall: 0.8799 - Precision: 0.8659
#
# Epoch: 16 | Epoch Time: 11m 58s
# 	Train Loss: 0.6392 - Jaccard: 0.7868 - F1: 0.8072 - Recall: 0.8693 - Precision: 0.8859
# 	 Val. Loss: 0.6711 - Jaccard: 0.7985 - F1: 0.8172 - Recall: 0.8692 - Precision: 0.8970
#
# Epoch: 17 | Epoch Time: 11m 58s
# 	Train Loss: 0.6234 - Jaccard: 0.7890 - F1: 0.8103 - Recall: 0.8729 - Precision: 0.8849
# 	 Val. Loss: 0.6672 - Jaccard: 0.7937 - F1: 0.8131 - Recall: 0.8762 - Precision: 0.8820
#
# Epoch: 18 | Epoch Time: 11m 58s
# 	Train Loss: 0.6276 - Jaccard: 0.7906 - F1: 0.8111 - Recall: 0.8698 - Precision: 0.8902
# 	 Val. Loss: 0.6651 - Jaccard: 0.7792 - F1: 0.8003 - Recall: 0.8851 - Precision: 0.8538
#
# Valid F1 improved from 0.8197 to 0.8200. Saving checkpoint: /content/checkpoint1 (7).pth
# Epoch: 19 | Epoch Time: 11m 59s
# 	Train Loss: 0.6273 - Jaccard: 0.7884 - F1: 0.8098 - Recall: 0.8758 - Precision: 0.8787
# 	 Val. Loss: 0.6686 - Jaccard: 0.8013 - F1: 0.8200 - Recall: 0.8680 - Precision: 0.8974
#
# Epoch: 20 | Epoch Time: 11m 58s
# 	Train Loss: 0.6258 - Jaccard: 0.7885 - F1: 0.8096 - Recall: 0.8743 - Precision: 0.8821
# 	 Val. Loss: 0.6560 - Jaccard: 0.7842 - F1: 0.8052 - Recall: 0.8818 - Precision: 0.8617
#
# Epoch: 21 | Epoch Time: 11m 58s
# 	Train Loss: 0.6222 - Jaccard: 0.7946 - F1: 0.8145 - Recall: 0.8703 - Precision: 0.8952
# 	 Val. Loss: 0.6625 - Jaccard: 0.7962 - F1: 0.8156 - Recall: 0.8722 - Precision: 0.8886
#
# Epoch: 22 | Epoch Time: 11m 58s
# 	Train Loss: 0.6135 - Jaccard: 0.7986 - F1: 0.8196 - Recall: 0.8728 - Precision: 0.8960
# 	 Val. Loss: 0.6623 - Jaccard: 0.7816 - F1: 0.8024 - Recall: 0.8829 - Precision: 0.8582
#
# Epoch: 23 | Epoch Time: 11m 58s
# 	Train Loss: 0.6107 - Jaccard: 0.7975 - F1: 0.8184 - Recall: 0.8742 - Precision: 0.8937
# 	 Val. Loss: 0.6608 - Jaccard: 0.7928 - F1: 0.8128 - Recall: 0.8787 - Precision: 0.8786
#
# Epoch: 24 | Epoch Time: 11m 58s
# 	Train Loss: 0.6089 - Jaccard: 0.7957 - F1: 0.8171 - Recall: 0.8759 - Precision: 0.8870
# 	 Val. Loss: 0.6594 - Jaccard: 0.7821 - F1: 0.8028 - Recall: 0.8803 - Precision: 0.8610
#
# Epoch: 25 | Epoch Time: 11m 58s
# 	Train Loss: 0.6073 - Jaccard: 0.7960 - F1: 0.8177 - Recall: 0.8765 - Precision: 0.8886
# 	 Val. Loss: 0.6585 - Jaccard: 0.7903 - F1: 0.8105 - Recall: 0.8765 - Precision: 0.8734
#
# Epoch: 26 | Epoch Time: 11m 58s
# 	Train Loss: 0.6083 - Jaccard: 0.8015 - F1: 0.8227 - Recall: 0.8751 - Precision: 0.8957
# 	 Val. Loss: 0.6572 - Jaccard: 0.7961 - F1: 0.8158 - Recall: 0.8751 - Precision: 0.8831
#
# Epoch: 27 | Epoch Time: 11m 58s
# 	Train Loss: 0.6245 - Jaccard: 0.7954 - F1: 0.8167 - Recall: 0.8750 - Precision: 0.8880
# 	 Val. Loss: 0.6542 - Jaccard: 0.7875 - F1: 0.8081 - Recall: 0.8803 - Precision: 0.8671
#
# Epoch: 28 | Epoch Time: 11m 58s
# 	Train Loss: 0.6092 - Jaccard: 0.8009 - F1: 0.8221 - Recall: 0.8759 - Precision: 0.8945
# 	 Val. Loss: 0.6557 - Jaccard: 0.7968 - F1: 0.8162 - Recall: 0.8744 - Precision: 0.8862
#
# Epoch: 29 | Epoch Time: 11m 58s
# 	Train Loss: 0.6092 - Jaccard: 0.7978 - F1: 0.8193 - Recall: 0.8769 - Precision: 0.8920
# 	 Val. Loss: 0.6532 - Jaccard: 0.7948 - F1: 0.8148 - Recall: 0.8775 - Precision: 0.8792
#
# Epoch: 30 | Epoch Time: 11m 58s
# 	Train Loss: 0.6016 - Jaccard: 0.8010 - F1: 0.8223 - Recall: 0.8763 - Precision: 0.8933
# 	 Val. Loss: 0.6532 - Jaccard: 0.7975 - F1: 0.8171 - Recall: 0.8752 - Precision: 0.8847
#
# Epoch: 31 | Epoch Time: 11m 58s
# 	Train Loss: 0.6045 - Jaccard: 0.8013 - F1: 0.8225 - Recall: 0.8754 - Precision: 0.8948
# 	 Val. Loss: 0.6552 - Jaccard: 0.7970 - F1: 0.8164 - Recall: 0.8740 - Precision: 0.8869
#
# Epoch: 32 | Epoch Time: 11m 59s
# 	Train Loss: 0.6026 - Jaccard: 0.8025 - F1: 0.8233 - Recall: 0.8738 - Precision: 0.8984
# 	 Val. Loss: 0.6561 - Jaccard: 0.7950 - F1: 0.8147 - Recall: 0.8753 - Precision: 0.8828
